# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dogo.results import get_results, get_experiment_details, average_scores_over_seeds

# %%
# Beta 2 - MIXED-1
MP226 = get_results("MP226")
MP227 = get_results("MP227")
MP228 = get_results("MP228")

# Beta 10 - MIXED-1
MP229 = get_results("MP229")
MP230 = get_results("MP230")
MP231 = get_results("MP231")

# Beta 2 - D3RLPY-PAP5-P0-3
MP250 = get_results("MP250")
MP251 = get_results("MP251")
MP252 = get_results("MP252")

# Beta 2 - D3RLPY-PAP5-P1-4
MP253 = get_results("MP253")
MP254 = get_results("MP254")
MP255 = get_results("MP255")

# Beta 2 - D3RLPY-MP1-P0-3
MP256 = get_results("MP256")
MP257 = get_results("MP257")
MP258 = get_results("MP258")

# No REx - D3RLPY-PAP5-P0-3
MP259 = get_results("MP259")
MP260 = get_results("MP260")
MP261 = get_results("MP261")

# No REx - D3RLPY-MP1-P0-3
MP262 = get_results("MP262")
MP263 = get_results("MP263")
MP264 = get_results("MP264")

# Beta 10 - D3RLPY-PAP5-P0-3
MP271 = get_results("MP271")
MP272 = get_results("MP272")
MP273 = get_results("MP273")

# Beta 10 - D3RLPY-MP1-P0-3
MP274 = get_results("MP274")
MP275 = get_results("MP275")
MP276 = get_results("MP276")

# %% [markdown]
# ## D3RLPY-PAP5-P0-3

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'evaluation/return-average'
for exp, rex in [
    (MP259, False ),
    (MP260, False),
    (MP261, False),
    (MP250, True),
    (MP251, True),
    (MP252, True),
    (MP271, True),
    (MP272, True),
    (MP273, True),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {exp.rex_beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'Q-avg'
for exp, rex in [
    (MP259, False ),
    (MP260, False),
    (MP261, False),
    (MP250, True),
    (MP251, True),
    (MP252, True),
    (MP271, True),
    (MP272, True),
    (MP273, True),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {exp.rex_beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'Q_loss'
for exp, rex in [
    (MP259, False ),
    (MP260, False),
    (MP261, False),
    (MP250, True),
    (MP251, True),
    (MP252, True),
    (MP271, True),
    (MP272, True),
    (MP273, True),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {exp.rex_beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %% [markdown]
# ## D3RLPY-MP1-P0-3

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'evaluation/return-average'
for exp, rex in [
    (MP262, False),
    (MP263, False),
    (MP264, False),
    (MP256, True),
    (MP257, True),
    (MP258, True),
    (MP274, True),
    (MP275, True),
    (MP276, True),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {exp.rex_beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'Q-avg'
for exp, rex in [
    (MP262, False),
    (MP263, False),
    (MP264, False),
    (MP256, True),
    (MP257, True),
    (MP258, True),
    (MP274, True),
    (MP275, True),
    (MP276, True),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {exp.rex_beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'Q_loss'
for exp, rex in [
    (MP262, False),
    (MP263, False),
    (MP264, False),
    (MP256, True),
    (MP257, True),
    (MP258, True),
    (MP274, True),
    (MP275, True),
    (MP276, True),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {exp.rex_beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %% [markdown]
# ## Beta 2 Results

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'evaluation/return-average'
for exp, rex in [
    (MP226, True),
    (MP227, True),
    (MP228, True),
    (MP250, True),
    (MP251, True),
    (MP252, True),
    (MP256, True),
    (MP257, True),
    (MP258, True),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {exp.rex_beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %% [markdown]
# ## Beta 10 Results

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'evaluation/return-average'
for exp, rex in [
    (MP229, True),
    (MP230, True),
    (MP231, True),
    (MP271, True),
    (MP272, True),
    (MP273, True),
    (MP274, True),
    (MP275, True),
    (MP276, True),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {exp.rex_beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass
