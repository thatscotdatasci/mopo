# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rc('font', size=16)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
labels = ['$\\lambda=0.0$', '$\\lambda=1.0$', '$\\lambda=5.0$']

rt_1_rl_5_mean = [1281.5201645917678, 635.8033626838757, 1.1581874485858652]
rt_1_rl_5_std = [761.0584075787921, 461.7995072425024, 19.145950053987885]

rt_4_rl_5_mean = [446.7927992805392, 262.13547585299875, 30.464297062649717]
rt_4_rl_5_std = [417.60813865155893, 144.12914199451453, 73.37480525306133]

rt_5_rl_5_mean = [595.8885113303473, 7.3072310244406395, -0.9508246455562184]
rt_5_rl_5_std = [779.6921747601591, 30.75223512541006, 2.2115341783341576]

rt_1_rl_10_mean = [970.7326816773018, 573.552373155318, -0.6576497858717922]
rt_1_rl_10_std = [665.0467538334451, 462.4228865939419, 8.784671479195588]

rt_4_rl_10_mean = [np.nan, 314.7543790881449, 51.35398313826351]
rt_4_rl_10_std = [np.nan, 190.48770697039532, 91.36693217257043]

rt_5_rl_10_mean = [348.67213303601153, 17.825246793430654, -7.153528883272428]
rt_5_rl_10_std = [417.1115459871397, 50.95789886113414, 12.232236898098257]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for mean_arr, std_err, label, c, ls in [
    (rt_1_rl_5_mean, rt_1_rl_5_std, 'Mixed - h=5', cols[0], '-'),
    (rt_4_rl_5_mean, rt_4_rl_5_std, 'Experienced - h=5', cols[1], '-'),
    (rt_5_rl_5_mean, rt_5_rl_5_std, 'Novice - h=5', cols[2], '-'),
    (rt_1_rl_10_mean, rt_1_rl_10_std, 'Mixed - h=10', cols[0], '--'),
    (rt_4_rl_10_mean, rt_4_rl_10_std, 'Experienced - h=10', cols[1], '--'),
    (rt_5_rl_10_mean, rt_5_rl_10_std, 'Novice - h=10', cols[2], '--'),
]:
    ax.errorbar(np.arange(3), mean_arr, std_err, color=c, ls=ls, label=label, capsize=10)
ax.set_xticks(np.arange(3))
ax.set_xticklabels(labels)
ax.set_title('Walker2d')
ax.set_xlabel('MOPO Penaly Coefficient')
ax.set_ylabel('Model Exploitation')
# ax.set_ylim(-150, 150)
ax.legend()
