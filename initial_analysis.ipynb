# %%
import os

import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('font', size=16)

# %% [markdown]
# # MP001-MP002 and MP013-MP015
#
# Using the D4RL `halfcheetah_medium_replay` dataset.

# %%
MP001 = "ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-11_12-43-30uimp9cp_/progress.csv"
MP002 = "ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-17_20-30-48wfqd03d0/progress.csv"

MP013 = "ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-19_08-47-3140eqztmo/progress.csv"
MP014 = "ray_mopo/halfcheetah/halfcheetah_medium_replay_local_101e3/seed:1443_2022-05-19_08-53-22d8z4ev_8/progress.csv"
MP015 = "ray_mopo/HalfCheetah/halfcheetah_medium_replay_local_101e3/seed:1443_2022-05-19_08-56-51nbkojiz2/progress.csv"

# %%
MP001_df = pd.read_csv(MP001)
MP002_df = pd.read_csv(MP002)

MP013_df = pd.read_csv(MP013)
MP014_df = pd.read_csv(MP014)
MP015_df = pd.read_csv(MP015)

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP001_df['timesteps_total'], MP001_df[feature], label='MP001 - Original')
ax.plot(MP002_df['timesteps_total'], MP002_df[feature], label='MP002 - With REx Prep')
ax.plot(MP013_df['timesteps_total'], MP013_df[feature], label='MP013 - With Initial REx')
ax.plot(MP014_df['timesteps_total'], MP014_df[feature], label='MP014 - With Initial REx + Local DS + D4RL Env')
ax.plot(MP015_df['timesteps_total'], MP015_df[feature], label='MP015 - With Initial REx + Local DS + Gym Env')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP001_df['timesteps_total'], MP001_df[feature], label='MP001 - Original')
ax.plot(MP002_df['timesteps_total'], MP002_df[feature], label='MP002 - With REx Prep')
ax.plot(MP013_df['timesteps_total'], MP013_df[feature], label='MP013 - With Initial REx')
ax.plot(MP014_df['timesteps_total'], MP014_df[feature], label='MP014 - With Initial REx + Local DS + D4RL Env')
ax.plot(MP015_df['timesteps_total'], MP015_df[feature], label='MP015 - With Initial REx + Local DS + Gym Env')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP001_df['timesteps_total'], MP001_df[feature], label='MP001 - Original')
ax.plot(MP002_df['timesteps_total'], MP002_df[feature], label='MP002 - With REx Prep')
ax.plot(MP013_df['timesteps_total'], MP013_df[feature], label='MP013 - With Initial REx')
ax.plot(MP014_df['timesteps_total'], MP014_df[feature], label='MP014 - With Initial REx + Local DS + D4RL Env')
ax.plot(MP015_df['timesteps_total'], MP015_df[feature], label='MP015 - With Initial REx + Local DS + Gym Env')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'alpha'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP001_df['timesteps_total'], MP001_df[feature], label='MP001 - Original')
ax.plot(MP002_df['timesteps_total'], MP002_df[feature], label='MP002 - With REx Prep')
ax.plot(MP013_df['timesteps_total'], MP013_df[feature], label='MP013 - With Initial REx')
ax.plot(MP014_df['timesteps_total'], MP014_df[feature], label='MP014 - With Initial REx + Local DS + D4RL Env')
ax.plot(MP015_df['timesteps_total'], MP015_df[feature], label='MP015 - With Initial REx + Local DS + Gym Env')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
MP013_MODEL_LOSS_PATH = "ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-19_08-47-3140eqztmo/model_loss_history.txt"
MP013_MODEL_HO_LOSS_PATH = "ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-19_08-47-3140eqztmo/model_holdout_loss_history.txt"

# %%
MP013_loss_df = pd.read_csv(MP013_MODEL_LOSS_PATH)
MP013_ho_loss_df = pd.read_csv(MP013_MODEL_HO_LOSS_PATH)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP013_loss_df)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP013_ho_loss_df)
ax.set_xlabel('Epochs')
ax.set_ylabel('Holdout Loss')
pass

# %% [markdown]
# # MP003-MP008 and MP017
#
# Using `HalfCheetah-v2` dataset containing transitions from a selection of policies.

# %%
MP003_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_diverse_polocies_101e3/seed:1443_2022-05-18_13-45-23z7h1m8fc/progress.csv"
MP005_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_diverse_polocies_101e3/seed:1443_2022-05-18_15-00-09659nw038/progress.csv"
MP006_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_diverse_polocies_101e3/seed:1443_2022-05-18_15-22-202hfcimhc/progress.csv"
MP007_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_diverse_polocies_101e3/seed:1443_2022-05-18_15-31-51vc8iug3b/progress.csv"

MP017_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_diverse_polocies_101e3/seed:1443_2022-05-19_10-46-325l2baubp/progress.csv"

# %%
MP003_df = pd.read_csv(MP003_PROGRESS_PATH)
MP005_df = pd.read_csv(MP005_PROGRESS_PATH)
MP006_df = pd.read_csv(MP006_PROGRESS_PATH)
MP007_df = pd.read_csv(MP007_PROGRESS_PATH)

MP017_df = pd.read_csv(MP017_PROGRESS_PATH)

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP003_df['timesteps_total'], MP003_df[feature], label='MP003 - SAC - CPU')
ax.plot(MP005_df['timesteps_total'], MP005_df[feature], label='MP005 - SAC - REx - Beta=0.1')
ax.plot(MP006_df['timesteps_total'], MP006_df[feature], label='MP006 - SAC - REx - Beta=0.2')
ax.plot(MP007_df['timesteps_total'], MP007_df[feature], label='MP007 - SAC - REx - Beta=0.5')
ax.plot(MP017_df['timesteps_total'], MP017_df[feature], label='MP017 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP003_df['timesteps_total'], MP003_df[feature], label='MP003 - SAC - CPU')
ax.plot(MP005_df['timesteps_total'], MP005_df[feature], label='MP005 - SAC - REx - Beta=0.1')
ax.plot(MP006_df['timesteps_total'], MP006_df[feature], label='MP006 - SAC - REx - Beta=0.2')
ax.plot(MP007_df['timesteps_total'], MP007_df[feature], label='MP007 - SAC - REx - Beta=0.5')
ax.plot(MP017_df['timesteps_total'], MP017_df[feature], label='MP017 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP003_df['timesteps_total'], MP003_df[feature], label='MP003 - SAC - CPU')
ax.plot(MP005_df['timesteps_total'], MP005_df[feature], label='MP005 - SAC - REx - Beta=0.1')
ax.plot(MP006_df['timesteps_total'], MP006_df[feature], label='MP006 - SAC - REx - Beta=0.2')
ax.plot(MP007_df['timesteps_total'], MP007_df[feature], label='MP007 - SAC - REx - Beta=0.5')
ax.plot(MP017_df['timesteps_total'], MP017_df[feature], label='MP017 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'alpha'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP003_df['timesteps_total'], MP003_df[feature], label='SAC - CPU')
ax.plot(MP005_df['timesteps_total'], MP005_df[feature], label='SAC - REx - Beta=0.1')
ax.plot(MP006_df['timesteps_total'], MP006_df[feature], label='SAC - REx - Beta=0.2')
ax.plot(MP007_df['timesteps_total'], MP007_df[feature], label='SAC - REx - Beta=0.5')
ax.plot(MP017_df['timesteps_total'], MP017_df[feature], label='SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %% [markdown]
# # MP009-MP012 and MP016
#
# Using `HalfCheetah-v2` dataset containing transitions from 101 episodes where each half are marked as coming from different policies.

# %%
MP009_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-18_17-24-15js0kzarc/progress.csv"
MP010_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-18_17-28-38s0gohsqp/progress.csv"
MP011_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-18_17-32-31p5rs4an2/progress.csv"
MP012_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-18_17-33-51ndy4er80/progress.csv"
MP016_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-19_09-00-03cy0rk96e/progress.csv"

# %%
MP009_df = pd.read_csv(MP009_PROGRESS_PATH)
MP010_df = pd.read_csv(MP010_PROGRESS_PATH)
MP011_df = pd.read_csv(MP011_PROGRESS_PATH)
MP012_df = pd.read_csv(MP012_PROGRESS_PATH)
MP016_df = pd.read_csv(MP016_PROGRESS_PATH)

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP009_df['timesteps_total'], MP009_df[feature], label='MP009 - SAC - CPU')
ax.plot(MP010_df['timesteps_total'], MP010_df[feature], label='MP010 - SAC - REx - Beta=0.1')
ax.plot(MP011_df['timesteps_total'], MP011_df[feature], label='MP011 - SAC - REx - Beta=0.2')
ax.plot(MP012_df['timesteps_total'], MP012_df[feature], label='MP012 - SAC - REx - Beta=0.5')
ax.plot(MP016_df['timesteps_total'], MP016_df[feature], label='MP016 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP009_df['timesteps_total'], MP009_df[feature], label='MP009 - SAC - CPU')
ax.plot(MP010_df['timesteps_total'], MP010_df[feature], label='MP010 - SAC - REx - Beta=0.1')
ax.plot(MP011_df['timesteps_total'], MP011_df[feature], label='MP011 - SAC - REx - Beta=0.2')
ax.plot(MP012_df['timesteps_total'], MP012_df[feature], label='MP012 - SAC - REx - Beta=0.5')
ax.plot(MP016_df['timesteps_total'], MP016_df[feature], label='MP016 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP009_df['timesteps_total'], MP009_df[feature], label='MP009 - SAC - CPU')
ax.plot(MP010_df['timesteps_total'], MP010_df[feature], label='MP010 - SAC - REx - Beta=0.1')
ax.plot(MP011_df['timesteps_total'], MP011_df[feature], label='MP011 - SAC - REx - Beta=0.2')
ax.plot(MP012_df['timesteps_total'], MP012_df[feature], label='MP012 - SAC - REx - Beta=0.5')
ax.plot(MP016_df['timesteps_total'], MP016_df[feature], label='MP016 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
MP016_MODEL_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-19_09-00-03cy0rk96e/model_loss_history.txt"
MP016_MODEL_HO_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-19_09-00-03cy0rk96e/model_holdout_loss_history.txt"

# %%
MP016_loss_df = pd.read_csv(MP016_MODEL_LOSS_PATH)
MP016_ho_loss_df = pd.read_csv(MP016_MODEL_HO_LOSS_PATH)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP016_loss_df)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP016_ho_loss_df)
ax.set_xlabel('Epochs')
ax.set_ylabel('Holdout Loss')
pass

# %% [markdown]
# # MP018-MP023
#
# Using `HalfCheetah-v2` dataset containing transitions from 101 episodes where each half are marked as coming from different policies. This dataset was generated using a `SAC` agent trained with `d3rlpy`

# %%
MP018_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep1_101e3/seed:1443_2022-05-19_13-35-25wro5vnvb/progress.csv"
MP019_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_14-57-11gpzff8hh/progress.csv"
MP020_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-30-36rehohbus/progress.csv"
MP021_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-32-115sab3atj/progress.csv"
MP022_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-34-20vx9g438j/progress.csv"
MP023_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_16-48-58rho8o9v3/progress.csv"

# %%
MP018_df = pd.read_csv(MP018_PROGRESS_PATH)
MP019_df = pd.read_csv(MP019_PROGRESS_PATH)
MP020_df = pd.read_csv(MP020_PROGRESS_PATH)
MP021_df = pd.read_csv(MP021_PROGRESS_PATH)
MP022_df = pd.read_csv(MP022_PROGRESS_PATH)
MP023_df = pd.read_csv(MP023_PROGRESS_PATH)

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP018_df['timesteps_total'], MP018_df[feature], label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_df['timesteps_total'], MP019_df[feature], label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_df['timesteps_total'], MP020_df[feature], label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_df['timesteps_total'], MP021_df[feature], label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_df['timesteps_total'], MP022_df[feature], label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.plot(MP023_df['timesteps_total'], MP023_df[feature], label='MP023 - D3RLPY-PEP2 - Beta 10.0')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP018_df['timesteps_total'], MP018_df[feature], label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_df['timesteps_total'], MP019_df[feature], label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_df['timesteps_total'], MP020_df[feature], label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_df['timesteps_total'], MP021_df[feature], label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_df['timesteps_total'], MP022_df[feature], label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.plot(MP023_df['timesteps_total'], MP023_df[feature], label='MP023 - D3RLPY-PEP2 - Beta 10.0')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP018_df['timesteps_total'], MP018_df[feature], label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_df['timesteps_total'], MP019_df[feature], label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_df['timesteps_total'], MP020_df[feature], label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_df['timesteps_total'], MP021_df[feature], label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_df['timesteps_total'], MP022_df[feature], label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.plot(MP023_df['timesteps_total'], MP023_df[feature], label='MP023 - D3RLPY-PEP2 - Beta 10.0')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
MP018_MODEL_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep1_101e3/seed:1443_2022-05-19_13-35-25wro5vnvb/model_loss_history.txt"
MP019_MODEL_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_14-57-11gpzff8hh/model_loss_history.txt"
MP020_MODEL_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-30-36rehohbus/model_loss_history.txt"
MP021_MODEL_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-32-115sab3atj/model_loss_history.txt"
MP022_MODEL_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-34-20vx9g438j/model_loss_history.txt"

MP018_MODEL_HO_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep1_101e3/seed:1443_2022-05-19_13-35-25wro5vnvb/model_holdout_loss_history.txt"
MP019_MODEL_HO_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_14-57-11gpzff8hh/model_holdout_loss_history.txt"
MP020_MODEL_HO_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-30-36rehohbus/model_holdout_loss_history.txt"
MP021_MODEL_HO_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-32-115sab3atj/model_holdout_loss_history.txt"
MP022_MODEL_HO_LOSS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-34-20vx9g438j/model_holdout_loss_history.txt"

# %%
MP018_loss_df = pd.read_csv(MP018_MODEL_LOSS_PATH)
MP019_loss_df = pd.read_csv(MP019_MODEL_LOSS_PATH)
MP020_loss_df = pd.read_csv(MP020_MODEL_LOSS_PATH)
MP021_loss_df = pd.read_csv(MP021_MODEL_LOSS_PATH)
MP022_loss_df = pd.read_csv(MP022_MODEL_LOSS_PATH)

MP018_ho_loss_df = pd.read_csv(MP018_MODEL_HO_LOSS_PATH)
MP019_ho_loss_df = pd.read_csv(MP019_MODEL_HO_LOSS_PATH)
MP020_ho_loss_df = pd.read_csv(MP020_MODEL_HO_LOSS_PATH)
MP021_ho_loss_df = pd.read_csv(MP021_MODEL_HO_LOSS_PATH)
MP022_ho_loss_df = pd.read_csv(MP022_MODEL_HO_LOSS_PATH)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP018_loss_df.mean(axis=1), label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_loss_df.mean(axis=1), label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_loss_df.mean(axis=1), label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_loss_df.mean(axis=1), label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_loss_df.mean(axis=1), label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP018_ho_loss_df.mean(axis=1), label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_ho_loss_df.mean(axis=1), label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_ho_loss_df.mean(axis=1), label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_ho_loss_df.mean(axis=1), label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_ho_loss_df.mean(axis=1), label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Epochs')
ax.set_ylabel('Holdout Loss')
ax.legend()
pass
