# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/home/ajc348/rds/hpc-work/mopo')

# %%
from dogo.visualisation.policy_dynamics_plotting import (
    plot_policy_group_values,
)

# %%
# Rollout length 5
plot_policy_group_values([
    (("HC151", "HC152", "HC153"), 'No REx\n$\\lambda=0.0$'),
    (("HC154", "HC155", "HC156"), 'REx: $\\beta=5.0$\n$\\lambda=0.0$'),
    (("HC157", "HC158", "HC159"), 'REx: $\\beta=10.0$\n$\\lambda=0.0$'),
    (("HC160", "HC161", "HC162"), 'REx: $\\beta=20.0$\n$\\lambda=0.0$'),
    (("HC175", "HC176", "HC177"), 'No REx\n$\\lambda=1.0$'),
    (("HC178", "HC179", "HC180"), 'REx: $\\beta=5.0$\n$\\lambda=1.0$'),
    (("HC181", "HC182", "HC183"), 'REx: $\\beta=10.0$\n$\\lambda=1.0$'),
    (("HC184", "HC185", "HC186"), 'REx: $\\beta=20.0$\n$\\lambda=1.0$'),
    (("HC187", "HC188", "HC189"), 'No REx\n$\\lambda=5.0$'),
    (("HC190", "HC191", "HC192"), 'REx: $\\beta=5.0$\n$\\lambda=5.0$'),
    (("HC193", "HC194", "HC195"), 'REx: $\\beta=10.0$\n$\\lambda=5.0$'),
    (("HC196", "HC197", "HC198"), 'REx: $\\beta=20.0$\n$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(20,10))
# Out:
# Labels ['No REx\n$\\lambda=0.0$', 'REx: $\\beta=5.0$\n$\\lambda=0.0$', 'REx: $\\beta=10.0$\n$\\lambda=0.0$', 'REx: $\\beta=20.0$\n$\\lambda=0.0$', 'No REx\n$\\lambda=1.0$', 'REx: $\\beta=5.0$\n$\\lambda=1.0$', 'REx: $\\beta=10.0$\n$\\lambda=1.0$', 'REx: $\\beta=20.0$\n$\\lambda=1.0$', 'No REx\n$\\lambda=5.0$', 'REx: $\\beta=5.0$\n$\\lambda=5.0$', 'REx: $\\beta=10.0$\n$\\lambda=5.0$', 'REx: $\\beta=20.0$\n$\\lambda=5.0$']
# Fake [11440.36621094 11434.50488281 10696.12695312 11282.24804688
#  10541.85742188 10652.96191406  8609.18457031  9629.37109375
#   7114.22607422  6653.21582031  6567.87597656  4856.52099609] [ 553.69665527 2169.68701172 2084.54174805 1395.18737793  284.85202026
#  1965.96276855 1951.9329834  1482.89929199 1963.40808105 2334.11254883
#   889.08398438 2594.87963867]
# Eval [11497.83414084 11558.78822043 10763.79717169 11321.49818903
#  10562.78758514 10736.39116117  8652.33064791  9639.19689334
#   7110.77274054  6662.66484594  6567.93714298  4859.37556964] [ 561.5969108  2213.40777072 1936.15130763 1411.35774553  292.6230915
#  1982.00323678 1768.76626593 1490.83007403 1960.29619055 2301.13133533
#   889.90319881 2610.4514736 ]
# Real [9094.32311775 6268.94312387 6518.84730722 8084.25769363 8932.57446019
#  7065.32747934 7765.73414189 6617.92243694 6836.55981433 3553.47558323
#  5047.1584607  4506.71052948] [1170.4264132  3354.78787656 2457.74888673 1935.27860408 1559.63273886
#  2797.61055492  767.79161046 3427.96798064 1888.61067384 2988.47773015
#  1932.75041046 3115.17329691]
# Diff [2346.04081454 5165.55997265 4177.28000271 3197.98794439 1609.28442653
#  3587.63502931  843.45066036 3011.44824991  277.66579424 3099.73975949
#  1520.71710896  349.8098883 ] [1319.59192962 3215.5013294  2018.62573039 1713.95874128 1426.75991707
#  2557.64107869 1409.62845756 2070.28909002  169.3017672  3207.28285188
#  1725.09700283  951.57162439]

# %%
# Rollout length 5
plot_policy_group_values([
    (("HC151", "HC152", "HC153", "HC154", "HC155", "HC156", "HC157", "HC158", "HC159", "HC160", "HC161", "HC162"), '$\\lambda=0.0$'),
    (("HC175", "HC176", "HC177", "HC178", "HC179", "HC180", "HC181", "HC182", "HC183", "HC184", "HC185", "HC186"), '$\\lambda=1.0$'),
    (("HC187", "HC188", "HC189", "HC190", "HC191", "HC192", "HC193", "HC194", "HC195", "HC196", "HC197", "HC198"), '$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(10,10))
# Out:
# Labels ['$\\lambda=0.0$', '$\\lambda=1.0$', '$\\lambda=5.0$']
# Fake [11213.310546875, 9858.34375, 6297.958984375] [1708.7052001953125, 1779.5098876953125, 2223.17431640625]
# Eval [11285.479430497391, 9897.676571891394, 6300.187574775804] [1684.3707704487954, 1741.306015195077, 2218.130875583786]
# Real [7491.592810618499, 7595.389629588916, 4985.976096935356] [2634.9304887872768, 2532.4413147366163, 2812.820418301915]
# Diff [3721.7171835704457, 2262.954591526197, 1311.983137747363] [2426.534222731844, 2214.0245124594644, 2204.08756315158]

# %%
# Rollout length 10
plot_policy_group_values([
    (("HC163", "HC164", "HC165"), 'No REx\n$\\lambda=0.0$'),
    (("HC166", "HC167", "HC168"), 'REx: $\\beta=5.0$\n$\\lambda=0.0$'),
    (("HC169", "HC170", "HC171"), 'REx: $\\beta=10.0$\n$\\lambda=0.0$'),
    (("HC172", "HC173", "HC174"), 'REx: $\\beta=20.0$\n$\\lambda=0.0$'),
    (("HC199", "HC200", "HC201"), 'No REx\n$\\lambda=1.0$'),
    (("HC202", "HC203", "HC204"), 'REx: $\\beta=5.0$\n$\\lambda=1.0$'),
    (("HC205", "HC206", "HC207"), 'REx: $\\beta=10.0$\n$\\lambda=1.0$'),
    (("HC208", "HC209", "HC210"), 'REx: $\\beta=20.0$\n$\\lambda=1.0$'),
    (("HC211", "HC212", "HC213"), 'No REx\n$\\lambda=5.0$'),
    (("HC214", "HC215", "HC216"), 'REx: $\\beta=5.0$\n$\\lambda=5.0$'),
    (("HC217", "HC218", "HC219"), 'REx: $\\beta=10.0$\n$\\lambda=5.0$'),
    (("HC220", "HC221", "HC222"), 'REx: $\\beta=20.0$\n$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(20,10))
# Out:
# Labels ['No REx\n$\\lambda=0.0$', 'REx: $\\beta=5.0$\n$\\lambda=0.0$', 'REx: $\\beta=10.0$\n$\\lambda=0.0$', 'REx: $\\beta=20.0$\n$\\lambda=0.0$', 'No REx\n$\\lambda=1.0$', 'REx: $\\beta=5.0$\n$\\lambda=1.0$', 'REx: $\\beta=10.0$\n$\\lambda=1.0$', 'REx: $\\beta=20.0$\n$\\lambda=1.0$', 'No REx\n$\\lambda=5.0$', 'REx: $\\beta=5.0$\n$\\lambda=5.0$', 'REx: $\\beta=10.0$\n$\\lambda=5.0$', 'REx: $\\beta=20.0$\n$\\lambda=5.0$']
# Fake [ 6447.40185547 12057.29394531  6488.71875     7388.77246094
#  10219.93847656 11373.76269531  8872.97167969  9588.23730469
#   7062.12255859  6500.61181641  2780.8293457   2288.25439453] [5279.89453125  381.0368042  5111.77099609 5395.10986328 1934.24841309
#  3071.6328125  1118.54980469 1268.48364258 1393.25512695 2611.82250977
#  2988.95288086 3154.11132812]
# Eval [ 6487.33675598 12197.4410137   6474.44361215  7391.27572569
#  10249.18123643 11518.98176503  8882.01168782  9591.16344012
#   7056.86114577  6498.3034806   2789.05042304  2329.61469696] [5300.44883035  363.38640532 5240.23427818 5424.10846731 1947.5710154
#  3104.81797427 1122.55771652 1275.21172275 1384.65866776 2612.45774815
#  2977.56535446 3124.801035  ]
# Real [5225.54116542 6461.71245997 3477.08335426 4076.97299402 8863.67721499
#  5923.77914316 7098.58994032 7561.1119276  6908.83480079 4708.10571483
#  1701.61726847 2111.83582348] [4492.2240824  2643.49277781 2835.74001042 3583.83985131 1678.97792059
#  3585.17629298 1676.95856126 2191.7353086  1336.82703963 2907.10829842
#  2602.60995758 3208.24594047]
# Diff [1221.86067714 5595.58138769 3011.63528486 3311.79890362 1356.26126005
#  5449.9831764  1774.38204861 2027.12477487  153.28772881 1792.50554384
#  1079.21218634  176.41848853] [ 868.58873503 2596.18306404 2294.769219   2815.84607173  313.2982985
#  3628.12150251 1524.91958492 1288.58705649  167.09819288 2714.74607505
#  1695.51424557 1092.21197087]

# %%
# Rollout length 10
plot_policy_group_values([
    (("HC163", "HC164", "HC165", "HC166", "HC167", "HC168", "HC169", "HC170", "HC171", "HC172", "HC173", "HC174"), '$\\lambda=0.0$'),
    (("HC199", "HC200", "HC201", "HC202", "HC203", "HC204", "HC205", "HC206", "HC207", "HC208", "HC209", "HC210"), '$\\lambda=1.0$'),
    (("HC211", "HC212", "HC213", "HC214", "HC215", "HC216", "HC217", "HC218", "HC219", "HC220", "HC221", "HC222"), '$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(10,10))
# Out:
# Labels ['$\\lambda=0.0$', '$\\lambda=1.0$', '$\\lambda=5.0$']
# Fake [8095.546875, 10013.7275390625, 4657.95458984375] [5117.44873046875, 2202.897705078125, 3389.67236328125]
# Eval [8137.624276880131, 10060.334532349983, 4668.457436594739] [5187.402586064441, 2241.155357450248, 3370.0021130028854]
# Real [4810.327493416156, 7361.789556518721, 3857.598401890519] [3649.2562330205897, 2632.53174348893, 3355.3745572470184]
# Diff [3285.21906332683, 2651.937814983202, 800.3559868789486] [2755.0110812936177, 2641.7602484523154, 1825.895702122007]
