# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
from itertools import zip_longest

import numpy as np
import matplotlib.pyplot as plt

from dogo.results import get_results
from dogo.plot_results import plot_evaluation_returns, plot_grouped_evaluation_returns, plot_grouped_evaluation_and_dynamics_returns

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 100.0

# %%
HO973 = get_results("HO973") # No Rex
HO974 = get_results("HO974")
HO975 = get_results("HO975")
HO976 = get_results("HO976") # REx - 5.0
HO977 = get_results("HO977")
HO978 = get_results("HO978")
HO979 = get_results("HO979") # REx - 10.0
HO980 = get_results("HO980")
HO981 = get_results("HO981")
HO982 = get_results("HO982") # REx - 20.0
HO983 = get_results("HO983")
HO984 = get_results("HO984")

# %%
plot_evaluation_returns([
    HO973,
    HO974,
    HO975,
    HO976,
    HO977,
    HO978,
    HO979,
    HO980,
    HO981,
    HO982,
    HO983,
    HO984,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$')
# Out:
# HO973: 3317.89306640625
# HO974: 1978.756103515625
# HO975: 3341.32568359375
# HO976: 334.0850830078125
# HO977: 12.528131484985352
# HO978: 295.487548828125
# HO979: 2259.810302734375
# HO980: 1335.343994140625
# HO981: 1161.887939453125
# HO982: 1914.932373046875
# HO983: 3465.15478515625
# HO984: 1802.288818359375

# %%
plot_grouped_evaluation_returns([
    ((HO973, HO974, HO975), 'No REx'),
    ((HO976, HO977, HO978), 'REx - $\\beta=5.0$'),
    ((HO979, HO980, HO981), 'REx - $\\beta=10.0$'),
    ((HO982, HO983, HO984), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', max_timestep=1000000)
# Out:
# {'No REx': {'mean': 3318, 'std': 0, 'count': 1, 'text': '3318 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': 334, 'std': 0, 'count': 1, 'text': '334 ± 0'},
#  'REx - $\\beta=10.0$': {'mean': 1162,
#   'std': 0,
#   'count': 1,
#   'text': '1162 ± 0'},
#  'REx - $\\beta=20.0$': {'mean': 1802,
#   'std': 0,
#   'count': 1,
#   'text': '1802 ± 0'}}

# %%
plot_grouped_evaluation_and_dynamics_returns([
    ((HO973, HO974, HO975), 'No REx'),
    ((HO976, HO977, HO978), 'REx - $\\beta=5.0$'),
    ((HO979, HO980, HO981), 'REx - $\\beta=10.0$'),
    ((HO982, HO983, HO984), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', max_timestep=1000000)
# Out:
# {'No REx': {'mean_eval_std': 1134,
#   'mean_dyn_std': 804,
#   'outliers': 0.0,
#   'frac_inf': 0.0,
#   'diff_mean': 6,
#   'diff_std': 936,
#   'text': '6 ± 936'},
#  'REx - $\\beta=5.0$': {'mean_eval_std': 991,
#   'mean_dyn_std': 907,
#   'outliers': 0.0,
#   'frac_inf': 0.0,
#   'diff_mean': 931,
#   'diff_std': 1097,
#   'text': '931 ± 1097'},
#  'REx - $\\beta=10.0$': {'mean_eval_std': 842,
#   'mean_dyn_std': 868,
#   'outliers': 0.0,
#   'frac_inf': 0.0,
#   'diff_mean': 593,
#   'diff_std': 577,
#   'text': '593 ± 577'},
#  'REx - $\\beta=20.0$': {'mean_eval_std': 1038,
#   'mean_dyn_std': 816,
#   'outliers': 0.0,
#   'frac_inf': 0.0,
#   'diff_mean': 578,
#   'diff_std': 798,
#   'text': '578 ± 798'}}
