# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dogo.results import get_results, get_experiment_details

# %%
plt.rc('font', size=12)

# %%
# Prior No REx Experiments
MP134 = get_results("MP134")
MP135 = get_results("MP135")
MP136 = get_results("MP136")

# Prior No REx Expperiments
MP162 = get_results("MP162")
MP163 = get_results("MP163")
MP164 = get_results("MP164")

# No REx
MP165 = get_results("MP165")
MP166 = get_results("MP166")
MP167 = get_results("MP167")

# REx - 0.1 - LR 0.1
MP168 = get_results("MP168")
MP169 = get_results("MP169")
MP170 = get_results("MP170")

# REx - 1.0 - LR 0.1
MP171 = get_results("MP171")
MP172 = get_results("MP172")
MP173 = get_results("MP173")

# REx - 10.0 - LR 0.1
MP174 = get_results("MP174")
MP175 = get_results("MP175")
MP176 = get_results("MP176")

# REx - 100.0 - LR 0.001
MP177 = get_results("MP177")
MP178 = get_results("MP178")
MP179 = get_results("MP179")

# REx - 10.0 - LR 0.001
MP180 = get_results("MP180")
MP181 = get_results("MP181")
MP182 = get_results("MP182")

# %%
# Prior No REx Experiments
MP134_details = get_experiment_details("MP134", get_elites=True)
MP135_details = get_experiment_details("MP135", get_elites=True)
MP136_details = get_experiment_details("MP136", get_elites=True)

# Prior No REx Expperiments
MP162_details = get_experiment_details("MP162", get_elites=True)
MP163_details = get_experiment_details("MP163", get_elites=True)
MP164_details = get_experiment_details("MP164", get_elites=True)

# No REx
MP165_details = get_experiment_details("MP165", get_elites=True)
MP166_details = get_experiment_details("MP166", get_elites=True)
MP167_details = get_experiment_details("MP167", get_elites=True)

# REx_details - 0.1
MP168_details = get_experiment_details("MP168", get_elites=True)
MP169_details = get_experiment_details("MP169", get_elites=True)
MP170_details = get_experiment_details("MP170", get_elites=True)

# REx_details - 1.0
MP171_details = get_experiment_details("MP171", get_elites=True)
MP172_details = get_experiment_details("MP172", get_elites=True)
MP173_details = get_experiment_details("MP173", get_elites=True)

# REx_details - 10.0 - LR 0.1
MP174_details = get_experiment_details("MP174", get_elites=True)
MP175_details = get_experiment_details("MP175", get_elites=True)
MP176_details = get_experiment_details("MP176", get_elites=True)

# REx_details - 100.0 - LR 0.001
MP177_details = get_experiment_details("MP177", get_elites=True)
MP178_details = get_experiment_details("MP178", get_elites=True)
MP179_details = get_experiment_details("MP179", get_elites=True)

# REx_details - 10.0 - LR 0.001
MP180_details = get_experiment_details("MP180", get_elites=True)
MP181_details = get_experiment_details("MP181", get_elites=True)
MP182_details = get_experiment_details("MP182", get_elites=True)

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))
for exp in [
    # MP134,
    # MP135,
    # MP136,
    MP165,
    MP166,
    MP167,
]:
    ax[0].plot(exp.dynamics.model_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].legend()

    ax[1].plot(exp.dynamics.model_holdout_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Holdout Loss')
    ax[1].legend()
pass

# %%
np.testing.assert_array_equal(MP134.dynamics.model_loss_history.mean(axis=1), MP165.dynamics.model_loss_history.mean(axis=1)[:MP134.dynamics.model_loss_history.shape[0]])
np.testing.assert_array_equal(MP135.dynamics.model_loss_history.mean(axis=1), MP166.dynamics.model_loss_history.mean(axis=1)[:MP135.dynamics.model_loss_history.shape[0]])
np.testing.assert_array_equal(MP136.dynamics.model_loss_history.mean(axis=1), MP167.dynamics.model_loss_history.mean(axis=1)[:MP136.dynamics.model_loss_history.shape[0]])

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))
for exp in [
    # MP168,
    # MP169,
    # MP170,
    # MP171,
    # MP172,
    # MP173,
    # MP174,
    # MP175,
    # MP176,
    MP177,
    MP178,
    MP179,
    MP180,
    MP181,
    MP182,
]:
    ax[0].plot(exp.dynamics.model_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].set_ylim(0,1.)
    ax[0].legend()

    ax[1].plot(exp.dynamics.model_holdout_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Holdout Loss')
    ax[1].set_ylim(0,1.)
    ax[1].legend()
pass

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))
for exp in [
    # MP168,
    # MP169,
    # MP170,
    # MP171,
    # MP172,
    # MP173,
    # MP174,
    # MP175,
    # MP176,
    MP177,
    MP178,
    MP179,
    MP180,
    MP181,
    MP182,
]:
    ax[0].plot(exp.dynamics.model_pol_total_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Sum of Policy Losses - Training Data')
    ax[0].set_ylim(0,1.)
    ax[0].legend()

    ax[1].plot(exp.dynamics.model_holdout_pol_total_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Sum of Policy Losses - Held-Out Data')
    ax[1].set_ylim(0,1.)
    ax[1].legend()
pass

# %%
fig, ax = plt.subplots(2, 2, figsize=(20,20))
for exp, exp_details in [
    (MP168, MP168_details),
    (MP169, MP169_details),
    (MP170, MP170_details),
    (MP171, MP171_details),
    (MP172, MP172_details),
    (MP173, MP173_details),
    (MP174, MP174_details),
    (MP175, MP175_details),
    (MP176, MP176_details),
    (MP177, MP177_details),
    (MP178, MP178_details),
    (MP179, MP179_details),
]:
    ax[0,0].plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0,0].set_ylabel('Variance of Policy Losses - Training Data')

    ax[0,1].plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0,1].set_ylabel('Variance of Policy Losses - Evaluation Data')

    ax[1,0].plot(exp.dynamics.model_pol_var_loss_history.values[:,exp_details.elites].mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1,0].set_ylabel('Variance of Policy Losses - Training Data')

    ax[1,1].plot(exp.dynamics.model_holdout_pol_var_loss_history.values[:,exp_details.elites].mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1,1].set_ylabel('Variance of Policy Losses - Evaluation Data')

    for i in range(2):
        for j in range(2):
            ax[i,j].set_xlabel('Epochs')
            ax[i,j].set_ylim(0,0.02)
            ax[i,j].legend()
pass

# %%
fig, ax = plt.subplots(2, 2, figsize=(20,20))
for exp, exp_details in [
    # (MP162, MP162_details),
    # (MP168, MP168_details),
    # (MP171, MP171_details),
    (MP174, MP174_details),
    # (MP177, MP177_details),
    (MP180, MP180_details),
]:
    ax[0,0].plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0,0].set_ylabel('Variance of Policy Losses - Training Data')

    ax[0,1].plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0,1].set_ylabel('Variance of Policy Losses - Evaluation Data')

    ax[1,0].plot(exp.dynamics.model_pol_var_loss_history.values[:,exp_details.elites].mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1,0].set_ylabel('Variance of Policy Losses - Training Data')

    ax[1,1].plot(exp.dynamics.model_holdout_pol_var_loss_history.values[:,exp_details.elites].mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1,1].set_ylabel('Variance of Policy Losses - Evaluation Data')

    for i in range(2):
        for j in range(2):
            ax[i,j].set_xlabel('Epochs')
            # ax[i,j].set_ylim(0,0.02)
            ax[i,j].legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

for exp in [
    MP180,
]:
    ax.plot(exp.dynamics.model_train_loss_history, label=f'{exp.name} - Total')
    ax.plot(exp.dynamics.model_train_core_loss_history, label=f'{exp.name} - Core')
    ax.plot(exp.dynamics.model_train_decay_loss_history, label=f'{exp.name} - Weight Regularisation')
    ax.plot(exp.dynamics.model_train_var_lim_loss_history, label=f'{exp.name} - Variance Limiters')
ax.set_xlabel('Batches')
ax.set_ylabel('Training Loss')
ax.set_ylim(-200.,10.)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

for exp in [
    MP180,
]:
    ax.plot(exp.dynamics.model_train_loss_history, label=f'{exp.name} - Total')
    ax.plot(exp.dynamics.model_train_core_loss_history, label=f'{exp.name} - Core')
    ax.plot(exp.dynamics.model_train_decay_loss_history, label=f'{exp.name} - Weight Regularisation')
    ax.plot(exp.dynamics.model_train_var_lim_loss_history, label=f'{exp.name} - Variance Limiters')
ax.set_xlabel('Batches')
ax.set_ylabel('Training Loss')
ax.set_ylim(-10.,10.)
ax.legend()
pass

# %%
fig, ax = plt.subplots(2, 2, figsize=(20,20))
for exp, exp_details in [
    # (MP163, MP163_details),
    # (MP169, MP169_details),
    # (MP172, MP172_details),
    (MP175, MP175_details),
    # (MP178, MP178_details),
    (MP181, MP181_details),
]:
    ax[0,0].plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0,0].set_ylabel('Variance of Policy Losses - Training Data')

    ax[0,1].plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0,1].set_ylabel('Variance of Policy Losses - Evaluation Data')

    ax[1,0].plot(exp.dynamics.model_pol_var_loss_history.values[:,exp_details.elites].mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1,0].set_ylabel('Variance of Policy Losses - Training Data')

    ax[1,1].plot(exp.dynamics.model_holdout_pol_var_loss_history.values[:,exp_details.elites].mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1,1].set_ylabel('Variance of Policy Losses - Evaluation Data')

    for i in range(2):
        for j in range(2):
            ax[i,j].set_xlabel('Epochs')
            # ax[i,j].set_ylim(0,0.02)
            ax[i,j].legend()
pass

# %%
fig, ax = plt.subplots(2, 2, figsize=(20,20))
for exp, exp_details in [
    # (MP164, MP164_details),
    # (MP170, MP170_details),
    # (MP173, MP173_details),
    (MP176, MP176_details),
    # (MP179, MP179_details),
    (MP182, MP182_details),
]:
    ax[0,0].plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0,0].set_ylabel('Variance of Policy Losses - Training Data')

    ax[0,1].plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0,1].set_ylabel('Variance of Policy Losses - Evaluation Data')

    ax[1,0].plot(exp.dynamics.model_pol_var_loss_history.values[:,exp_details.elites].mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1,0].set_ylabel('Variance of Policy Losses - Training Data')

    ax[1,1].plot(exp.dynamics.model_holdout_pol_var_loss_history.values[:,exp_details.elites].mean(axis=1)[100:1500], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1,1].set_ylabel('Variance of Policy Losses - Evaluation Data')

    for i in range(2):
        for j in range(2):
            ax[i,j].set_xlabel('Epochs')
            # ax[i,j].set_ylim(0,0.02)
            ax[i,j].legend()
pass

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))
for exp in [
    MP168,
    MP169,
    MP170,
]:
    ax[0].plot(exp.dynamics.model_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].legend()

    ax[1].plot(exp.dynamics.model_holdout_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Holdout Loss')
    ax[1].legend()
pass

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))
for exp in [
    MP171,
    MP172,
    MP173,
]:
    ax[0].plot(exp.dynamics.model_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].legend()

    ax[1].plot(exp.dynamics.model_holdout_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Holdout Loss')
    ax[1].legend()
pass

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))
for exp in [
    MP174,
    MP175,
    MP176,
]:
    ax[0].plot(exp.dynamics.model_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].legend()

    ax[1].plot(exp.dynamics.model_holdout_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed}')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Holdout Loss')
    ax[1].legend()
pass
