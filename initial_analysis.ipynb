# %%
import os

import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('font', size=16)

# %%
RESULTS_BASEDIR = "../dogo_results/mopo"
get_results_path = lambda x: os.path.join(RESULTS_BASEDIR, x)

# %% [markdown]
# # MP001-MP002, MP013-MP015 MP043
#
# Using the D4RL `halfcheetah_medium_replay` dataset.

# %%
MP001 = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-11_12-43-30uimp9cp_/result.json")
MP002 = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-17_20-30-48wfqd03d0/result.json")

MP013 = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-19_08-47-3140eqztmo/result.json")
MP014 = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_local_101e3/seed:1443_2022-05-19_08-53-22d8z4ev_8/result.json")
MP015 = get_results_path("ray_mopo/HalfCheetah/halfcheetah_medium_replay_local_101e3/seed:1443_2022-05-19_08-56-51nbkojiz2/result.json")

MP043 = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-22_17-27-05v8c4s4k9/result.json")
MP044 = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-22_19-01-28ll6r2mlu/result.json")

# %%
MP001_df = pd.read_json(MP001, lines=True)
MP002_df = pd.read_json(MP002, lines=True)

MP013_df = pd.read_json(MP013, lines=True)
MP014_df = pd.read_json(MP014, lines=True)
MP015_df = pd.read_json(MP015, lines=True)

MP043_df = pd.read_json(MP043, lines=True)
MP044_df = pd.read_json(MP044, lines=True)

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP001_df['timesteps_total'], MP001_df[feature], label='MP001 - Original')
ax.plot(MP002_df['timesteps_total'], MP002_df[feature], label='MP002 - With REx Prep')
ax.plot(MP013_df['timesteps_total'], MP013_df[feature], label='MP013 - With Initial REx')
ax.plot(MP014_df['timesteps_total'], MP014_df[feature], label='MP014 - With Initial REx + Local DS + D4RL Env')
ax.plot(MP015_df['timesteps_total'], MP015_df[feature], label='MP015 - With Initial REx + Local DS + Gym Env')
ax.plot(MP043_df['timesteps_total'], MP043_df[feature], label='MP043 - Inital REx Corrected')
ax.plot(MP044_df['timesteps_total'], MP044_df[feature], label='MP044 - REx Logging')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP001_df['timesteps_total'], MP001_df[feature], label='MP001 - Original')
ax.plot(MP002_df['timesteps_total'], MP002_df[feature], label='MP002 - With REx Prep')
ax.plot(MP013_df['timesteps_total'], MP013_df[feature], label='MP013 - With Initial REx')
ax.plot(MP014_df['timesteps_total'], MP014_df[feature], label='MP014 - With Initial REx + Local DS + D4RL Env')
ax.plot(MP015_df['timesteps_total'], MP015_df[feature], label='MP015 - With Initial REx + Local DS + Gym Env')
ax.plot(MP043_df['timesteps_total'], MP043_df[feature], label='MP042 - Inital REx Corrected')
ax.plot(MP044_df['timesteps_total'], MP044_df[feature], label='MP044 - REx Logging')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP001_df['timesteps_total'], MP001_df[feature], label='MP001 - Original')
ax.plot(MP002_df['timesteps_total'], MP002_df[feature], label='MP002 - With REx Prep')
ax.plot(MP013_df['timesteps_total'], MP013_df[feature], label='MP013 - With Initial REx')
ax.plot(MP014_df['timesteps_total'], MP014_df[feature], label='MP014 - With Initial REx + Local DS + D4RL Env')
ax.plot(MP015_df['timesteps_total'], MP015_df[feature], label='MP015 - With Initial REx + Local DS + Gym Env')
ax.plot(MP043_df['timesteps_total'], MP043_df[feature], label='MP042 - Inital REx Corrected')
ax.plot(MP044_df['timesteps_total'], MP044_df[feature], label='MP044 - REx Logging')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'alpha'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP001_df['timesteps_total'], MP001_df[feature], label='MP001 - Original')
ax.plot(MP002_df['timesteps_total'], MP002_df[feature], label='MP002 - With REx Prep')
ax.plot(MP013_df['timesteps_total'], MP013_df[feature], label='MP013 - With Initial REx')
ax.plot(MP014_df['timesteps_total'], MP014_df[feature], label='MP014 - With Initial REx + Local DS + D4RL Env')
ax.plot(MP015_df['timesteps_total'], MP015_df[feature], label='MP015 - With Initial REx + Local DS + Gym Env')
ax.plot(MP043_df['timesteps_total'], MP043_df[feature], label='MP042 - Inital REx Corrected')
ax.plot(MP044_df['timesteps_total'], MP044_df[feature], label='MP044 - REx Logging')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
MP013_MODEL_LOSS_PATH = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-19_08-47-3140eqztmo/model_loss_history.txt")
MP043_MODEL_LOSS_PATH = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-22_17-27-05v8c4s4k9/model_loss_history.txt")
MP044_MODEL_LOSS_PATH = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-22_19-01-28ll6r2mlu/model_loss_history.txt")

MP013_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-19_08-47-3140eqztmo/model_holdout_loss_history.txt")
MP043_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-22_17-27-05v8c4s4k9/model_holdout_loss_history.txt")
MP044_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-22_19-01-28ll6r2mlu/model_holdout_loss_history.txt")

# %%
MP013_loss_df = pd.read_csv(MP013_MODEL_LOSS_PATH)
MP043_loss_df = pd.read_csv(MP043_MODEL_LOSS_PATH)
MP044_loss_df = pd.read_csv(MP044_MODEL_LOSS_PATH)

MP013_ho_loss_df = pd.read_csv(MP013_MODEL_HO_LOSS_PATH)
MP043_ho_loss_df = pd.read_csv(MP043_MODEL_HO_LOSS_PATH)
MP044_ho_loss_df = pd.read_csv(MP044_MODEL_HO_LOSS_PATH)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP013_loss_df.mean(axis=1), label='MLP013')
ax.plot(MP043_loss_df.mean(axis=1), label='MLP043')
ax.plot(MP044_loss_df.mean(axis=1), label='MLP044')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP013_ho_loss_df.mean(axis=1), label='MLP013')
ax.plot(MP043_ho_loss_df.mean(axis=1), label='MLP043')
ax.plot(MP044_ho_loss_df.mean(axis=1), label='MLP044')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()
pass

# %% [markdown]
# # MP003-MP008 and MP017
#
# Using `HalfCheetah-v2` dataset containing transitions from a selection of policies.

# %%
MP003_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_diverse_polocies_101e3/seed:1443_2022-05-18_13-45-23z7h1m8fc/result.json")
MP005_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_diverse_polocies_101e3/seed:1443_2022-05-18_15-00-09659nw038/result.json")
MP006_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_diverse_polocies_101e3/seed:1443_2022-05-18_15-22-202hfcimhc/result.json")
MP007_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_diverse_polocies_101e3/seed:1443_2022-05-18_15-31-51vc8iug3b/result.json")

MP017_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_diverse_polocies_101e3/seed:1443_2022-05-19_10-46-325l2baubp/result.json")

# %%
MP003_df = pd.read_json(MP003_PROGRESS_PATH, lines=True)
MP005_df = pd.read_json(MP005_PROGRESS_PATH, lines=True)
MP006_df = pd.read_json(MP006_PROGRESS_PATH, lines=True)
MP007_df = pd.read_json(MP007_PROGRESS_PATH, lines=True)

MP017_df = pd.read_json(MP017_PROGRESS_PATH, lines=True)

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP003_df['timesteps_total'], MP003_df[feature], label='MP003 - SAC - CPU')
ax.plot(MP005_df['timesteps_total'], MP005_df[feature], label='MP005 - SAC - REx - Beta=0.1')
ax.plot(MP006_df['timesteps_total'], MP006_df[feature], label='MP006 - SAC - REx - Beta=0.2')
ax.plot(MP007_df['timesteps_total'], MP007_df[feature], label='MP007 - SAC - REx - Beta=0.5')
ax.plot(MP017_df['timesteps_total'], MP017_df[feature], label='MP017 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP003_df['timesteps_total'], MP003_df[feature], label='MP003 - SAC - CPU')
ax.plot(MP005_df['timesteps_total'], MP005_df[feature], label='MP005 - SAC - REx - Beta=0.1')
ax.plot(MP006_df['timesteps_total'], MP006_df[feature], label='MP006 - SAC - REx - Beta=0.2')
ax.plot(MP007_df['timesteps_total'], MP007_df[feature], label='MP007 - SAC - REx - Beta=0.5')
ax.plot(MP017_df['timesteps_total'], MP017_df[feature], label='MP017 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP003_df['timesteps_total'], MP003_df[feature], label='MP003 - SAC - CPU')
ax.plot(MP005_df['timesteps_total'], MP005_df[feature], label='MP005 - SAC - REx - Beta=0.1')
ax.plot(MP006_df['timesteps_total'], MP006_df[feature], label='MP006 - SAC - REx - Beta=0.2')
ax.plot(MP007_df['timesteps_total'], MP007_df[feature], label='MP007 - SAC - REx - Beta=0.5')
ax.plot(MP017_df['timesteps_total'], MP017_df[feature], label='MP017 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'alpha'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP003_df['timesteps_total'], MP003_df[feature], label='SAC - CPU')
ax.plot(MP005_df['timesteps_total'], MP005_df[feature], label='SAC - REx - Beta=0.1')
ax.plot(MP006_df['timesteps_total'], MP006_df[feature], label='SAC - REx - Beta=0.2')
ax.plot(MP007_df['timesteps_total'], MP007_df[feature], label='SAC - REx - Beta=0.5')
ax.plot(MP017_df['timesteps_total'], MP017_df[feature], label='SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %% [markdown]
# # MP009-MP012 and MP016
#
# Using `HalfCheetah-v2` dataset containing transitions from 101 episodes where each half are marked as coming from different policies.

# %%
MP009_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-18_17-24-15js0kzarc/result.json")
MP010_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-18_17-28-38s0gohsqp/result.json")
MP011_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-18_17-32-31p5rs4an2/result.json")
MP012_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-18_17-33-51ndy4er80/result.json")
MP016_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-19_09-00-03cy0rk96e/result.json")

# %%
MP009_df = pd.read_json(MP009_PROGRESS_PATH, lines=True)
MP010_df = pd.read_json(MP010_PROGRESS_PATH, lines=True)
MP011_df = pd.read_json(MP011_PROGRESS_PATH, lines=True)
MP012_df = pd.read_json(MP012_PROGRESS_PATH, lines=True)
MP016_df = pd.read_json(MP016_PROGRESS_PATH, lines=True)

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP009_df['timesteps_total'], MP009_df[feature], label='MP009 - SAC - CPU')
ax.plot(MP010_df['timesteps_total'], MP010_df[feature], label='MP010 - SAC - REx - Beta=0.1')
ax.plot(MP011_df['timesteps_total'], MP011_df[feature], label='MP011 - SAC - REx - Beta=0.2')
ax.plot(MP012_df['timesteps_total'], MP012_df[feature], label='MP012 - SAC - REx - Beta=0.5')
ax.plot(MP016_df['timesteps_total'], MP016_df[feature], label='MP016 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP009_df['timesteps_total'], MP009_df[feature], label='MP009 - SAC - CPU')
ax.plot(MP010_df['timesteps_total'], MP010_df[feature], label='MP010 - SAC - REx - Beta=0.1')
ax.plot(MP011_df['timesteps_total'], MP011_df[feature], label='MP011 - SAC - REx - Beta=0.2')
ax.plot(MP012_df['timesteps_total'], MP012_df[feature], label='MP012 - SAC - REx - Beta=0.5')
ax.plot(MP016_df['timesteps_total'], MP016_df[feature], label='MP016 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP009_df['timesteps_total'], MP009_df[feature], label='MP009 - SAC - CPU')
ax.plot(MP010_df['timesteps_total'], MP010_df[feature], label='MP010 - SAC - REx - Beta=0.1')
ax.plot(MP011_df['timesteps_total'], MP011_df[feature], label='MP011 - SAC - REx - Beta=0.2')
ax.plot(MP012_df['timesteps_total'], MP012_df[feature], label='MP012 - SAC - REx - Beta=0.5')
ax.plot(MP016_df['timesteps_total'], MP016_df[feature], label='MP016 - SAC - GPU')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
MP016_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-19_09-00-03cy0rk96e/model_loss_history.txt")
MP016_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_paper_rep_101e3/seed:1443_2022-05-19_09-00-03cy0rk96e/model_holdout_loss_history.txt")

# %%
MP016_loss_df = pd.read_csv(MP016_MODEL_LOSS_PATH)
MP016_ho_loss_df = pd.read_csv(MP016_MODEL_HO_LOSS_PATH)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP016_loss_df)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP016_ho_loss_df)
ax.set_xlabel('Epochs')
ax.set_ylabel('Holdout Loss')
pass

# %% [markdown]
# # MP018-MP023
#
# Using `HalfCheetah-v2` dataset containing transitions from 101 episodes where each half are marked as coming from different policies. This dataset was generated using a `SAC` agent trained with `d3rlpy`

# %%
MP018_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep1_101e3/seed:1443_2022-05-19_13-35-25wro5vnvb/result.json")
MP019_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_14-57-11gpzff8hh/result.json")
MP020_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-30-36rehohbus/result.json")
MP021_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-32-115sab3atj/result.json")
MP022_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-34-20vx9g438j/result.json")
MP023_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_16-48-58rho8o9v3/result.json")

MP024_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_20-05-11m23ma4x8/result.json")
MP025_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_20-05-117vysrywm/result.json")

# %%
MP018_df = pd.read_json(MP018_PROGRESS_PATH, lines=True)
MP019_df = pd.read_json(MP019_PROGRESS_PATH, lines=True)
MP020_df = pd.read_json(MP020_PROGRESS_PATH, lines=True)
MP021_df = pd.read_json(MP021_PROGRESS_PATH, lines=True)
MP022_df = pd.read_json(MP022_PROGRESS_PATH, lines=True)
MP023_df = pd.read_json(MP023_PROGRESS_PATH, lines=True)

MP024_df = pd.read_json(MP024_PROGRESS_PATH, lines=True)
MP025_df = pd.read_json(MP025_PROGRESS_PATH, lines=True)

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP018_df['timesteps_total'], MP018_df[feature], label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_df['timesteps_total'], MP019_df[feature], label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_df['timesteps_total'], MP020_df[feature], label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_df['timesteps_total'], MP021_df[feature], label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_df['timesteps_total'], MP022_df[feature], label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.plot(MP023_df['timesteps_total'], MP023_df[feature], label='MP023 - D3RLPY-PEP2 - Beta 10.0')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %% [markdown]
# MP019 is the original run which included training the dynamics model. MP024 and MP025 both load the pre-trained dynamics model. MP024 use a GPU, and MP025 a CPU. Surprisingly, the CPU completed more steps before the 1 hour timeout.

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP019_df['timesteps_total'], MP019_df[feature], label='MP019 - D3RLPY-PEP2')
ax.plot(MP024_df['timesteps_total'], MP024_df[feature], label='MP024 - D3RLPY-PEP2')
ax.plot(MP025_df['timesteps_total'], MP025_df[feature], label='MP025 - D3RLPY-PEP2')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP018_df['timesteps_total'], MP018_df[feature], label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_df['timesteps_total'], MP019_df[feature], label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_df['timesteps_total'], MP020_df[feature], label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_df['timesteps_total'], MP021_df[feature], label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_df['timesteps_total'], MP022_df[feature], label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.plot(MP023_df['timesteps_total'], MP023_df[feature], label='MP023 - D3RLPY-PEP2 - Beta 10.0')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP018_df['timesteps_total'], MP018_df[feature], label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_df['timesteps_total'], MP019_df[feature], label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_df['timesteps_total'], MP020_df[feature], label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_df['timesteps_total'], MP021_df[feature], label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_df['timesteps_total'], MP022_df[feature], label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.plot(MP023_df['timesteps_total'], MP023_df[feature], label='MP023 - D3RLPY-PEP2 - Beta 10.0')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
MP018_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep1_101e3/seed:1443_2022-05-19_13-35-25wro5vnvb/model_loss_history.txt")
MP019_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_14-57-11gpzff8hh/model_loss_history.txt")
MP020_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-30-36rehohbus/model_loss_history.txt")
MP021_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-32-115sab3atj/model_loss_history.txt")
MP022_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-34-20vx9g438j/model_loss_history.txt")
MP023_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_16-48-58rho8o9v3/model_loss_history.txt")

MP018_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep1_101e3/seed:1443_2022-05-19_13-35-25wro5vnvb/model_holdout_loss_history.txt")
MP019_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_14-57-11gpzff8hh/model_holdout_loss_history.txt")
MP020_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-30-36rehohbus/model_holdout_loss_history.txt")
MP021_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-32-115sab3atj/model_holdout_loss_history.txt")
MP022_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_15-34-20vx9g438j/model_holdout_loss_history.txt")
MP023_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_16-48-58rho8o9v3/model_holdout_loss_history.txt")

# %%
MP018_loss_df = pd.read_csv(MP018_MODEL_LOSS_PATH)
MP019_loss_df = pd.read_csv(MP019_MODEL_LOSS_PATH)
MP020_loss_df = pd.read_csv(MP020_MODEL_LOSS_PATH)
MP021_loss_df = pd.read_csv(MP021_MODEL_LOSS_PATH)
MP022_loss_df = pd.read_csv(MP022_MODEL_LOSS_PATH)
MP023_loss_df = pd.read_csv(MP023_MODEL_LOSS_PATH)

MP018_ho_loss_df = pd.read_csv(MP018_MODEL_HO_LOSS_PATH)
MP019_ho_loss_df = pd.read_csv(MP019_MODEL_HO_LOSS_PATH)
MP020_ho_loss_df = pd.read_csv(MP020_MODEL_HO_LOSS_PATH)
MP021_ho_loss_df = pd.read_csv(MP021_MODEL_HO_LOSS_PATH)
MP022_ho_loss_df = pd.read_csv(MP022_MODEL_HO_LOSS_PATH)
MP023_ho_loss_df = pd.read_csv(MP023_MODEL_HO_LOSS_PATH)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP018_loss_df.mean(axis=1), label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_loss_df.mean(axis=1), label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_loss_df.mean(axis=1), label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_loss_df.mean(axis=1), label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_loss_df.mean(axis=1), label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.plot(MP023_loss_df.mean(axis=1), label='MP023 - D3RLPY-PEP2 - Beta 10.0')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP018_ho_loss_df.mean(axis=1), label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_ho_loss_df.mean(axis=1), label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_ho_loss_df.mean(axis=1), label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_ho_loss_df.mean(axis=1), label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_ho_loss_df.mean(axis=1), label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.plot(MP023_ho_loss_df.mean(axis=1), label='MP023 - D3RLPY-PEP2 - Beta 10.0')
ax.set_xlabel('Epochs')
ax.set_ylabel('Holdout Loss')
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
# ax.plot(MP018_ho_loss_df.mean(axis=1), label='MP018 - D3RLPY-PEP1')
ax.plot(MP019_ho_loss_df.mean(axis=1), label='MP019 - D3RLPY-PEP2')
ax.plot(MP020_ho_loss_df.mean(axis=1), label='MP020 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP021_ho_loss_df.mean(axis=1), label='MP021 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP022_ho_loss_df.mean(axis=1), label='MP022 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Epochs')
ax.set_ylabel('Holdout Loss')
ax.legend()
pass

# %% [markdown]
# # MP026-MP034

# %%
# Seed: 1443
MP026_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_22-26-5615z5zc49/result.json")
MP030_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-20_10-32-53_tchjmvu/result.json"
MP028_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_22-28-57b1r97owe/result.json")
MP029_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1443_2022-05-19_22-30-25d_lnn_2z/result.json")

# Seed: 1234
MP031_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1234_2022-05-20_10-58-16e1gov1rm/result.json"
MP032_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1234_2022-05-20_10-59-55i5b_cwr5/result.json"
MP033_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1234_2022-05-20_11-03-499pnebryi/result.json"
MP034_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep2_101e3/seed:1234_2022-05-20_11-05-41mt68x5_p/result.json"

# %%
MP026_df = pd.read_json(MP026_PROGRESS_PATH, lines=True)
MP030_df = pd.read_json(MP030_PROGRESS_PATH, lines=True)
MP028_df = pd.read_json(MP028_PROGRESS_PATH, lines=True)
MP029_df = pd.read_json(MP029_PROGRESS_PATH, lines=True)

MP031_df = pd.read_json(MP031_PROGRESS_PATH, lines=True)
MP032_df = pd.read_json(MP032_PROGRESS_PATH, lines=True)
MP033_df = pd.read_json(MP033_PROGRESS_PATH, lines=True)
MP034_df = pd.read_json(MP034_PROGRESS_PATH, lines=True)

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(15,10))
ax.plot(MP026_df['timesteps_total'], MP026_df[feature], label='MP026 - D3RLPY-PEP2')
ax.plot(MP030_df['timesteps_total'], MP030_df[feature], label='MP030 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP028_df['timesteps_total'], MP028_df[feature], label='MP028 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP029_df['timesteps_total'], MP029_df[feature], label='MP029 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(15,10))
ax.plot(MP026_df['timesteps_total'], MP026_df[feature], label='MP026 - D3RLPY-PEP2')
ax.plot(MP030_df['timesteps_total'], MP030_df[feature], label='MP030 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP028_df['timesteps_total'], MP028_df[feature], label='MP028 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP029_df['timesteps_total'], MP029_df[feature], label='MP029 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(15,10))
ax.plot(MP026_df['timesteps_total'], MP026_df[feature], label='MP026 - D3RLPY-PEP2')
ax.plot(MP030_df['timesteps_total'], MP030_df[feature], label='MP030 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP028_df['timesteps_total'], MP028_df[feature], label='MP028 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP029_df['timesteps_total'], MP029_df[feature], label='MP029 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(15,10))
ax.plot(MP031_df['timesteps_total'], MP031_df[feature], label='MP031 - D3RLPY-PEP2')
ax.plot(MP032_df['timesteps_total'], MP032_df[feature], label='MP032 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP033_df['timesteps_total'], MP033_df[feature], label='MP033 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP034_df['timesteps_total'], MP034_df[feature], label='MP034 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(15,10))
ax.plot(MP031_df['timesteps_total'], MP031_df[feature], label='MP031 - D3RLPY-PEP2')
ax.plot(MP032_df['timesteps_total'], MP032_df[feature], label='MP032 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP033_df['timesteps_total'], MP033_df[feature], label='MP033 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP034_df['timesteps_total'], MP034_df[feature], label='MP034 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(15,10))
ax.plot(MP031_df['timesteps_total'], MP031_df[feature], label='MP031 - D3RLPY-PEP2')
ax.plot(MP032_df['timesteps_total'], MP032_df[feature], label='MP032 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP033_df['timesteps_total'], MP033_df[feature], label='MP033 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP034_df['timesteps_total'], MP034_df[feature], label='MP034 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %% [markdown]
# # MP035-MP042
#
# Using `HalfCheetah-v2` dataset containing transitions from a selection of policies.

# %%
MP035_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-34-49czxvu71z/result.json")
MP036_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-36-24fadbkq86/result.json")
MP037_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-37-58an5asxxe/result.json")
MP038_PROGRESS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-42-446g8qnyrh/result.json")

MP039_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_14-05-19brzi7cfw/result.json"
MP040_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_14-07-10sg_nz4yo/result.json"
MP041_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_14-10-16kv11tcey/result.json"
MP042_PROGRESS_PATH = "ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_14-12-30e93xqa4i/result.json"

# %%
MP035_df = pd.read_json(MP035_PROGRESS_PATH, lines=True)
MP036_df = pd.read_json(MP036_PROGRESS_PATH, lines=True)
MP037_df = pd.read_json(MP037_PROGRESS_PATH, lines=True)
MP038_df = pd.read_json(MP038_PROGRESS_PATH, lines=True)

MP039_df = pd.read_json(MP039_PROGRESS_PATH, lines=True)
MP040_df = pd.read_json(MP040_PROGRESS_PATH, lines=True)
MP041_df = pd.read_json(MP041_PROGRESS_PATH, lines=True)
MP042_df = pd.read_json(MP042_PROGRESS_PATH, lines=True)

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP035_df['timesteps_total'], MP035_df[feature], label='MP035 - SAC')
ax.plot(MP036_df['timesteps_total'], MP036_df[feature], label='MP036 - SAC - REx - Beta=0.1')
ax.plot(MP037_df['timesteps_total'], MP037_df[feature], label='MP037 - SAC - REx - Beta=0.2')
ax.plot(MP038_df['timesteps_total'], MP038_df[feature], label='MP038 - SAC - REx - Beta=0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP035_df['timesteps_total'], MP035_df[feature], label='MP035 - SAC')
ax.plot(MP036_df['timesteps_total'], MP036_df[feature], label='MP036 - SAC - REx - Beta=0.1')
ax.plot(MP037_df['timesteps_total'], MP037_df[feature], label='MP037 - SAC - REx - Beta=0.2')
ax.plot(MP038_df['timesteps_total'], MP038_df[feature], label='MP038 - SAC - REx - Beta=0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP035_df['timesteps_total'], MP035_df[feature], label='MP035 - SAC')
ax.plot(MP036_df['timesteps_total'], MP036_df[feature], label='MP036 - SAC - REx - Beta=0.1')
ax.plot(MP037_df['timesteps_total'], MP037_df[feature], label='MP037 - SAC - REx - Beta=0.2')
ax.plot(MP038_df['timesteps_total'], MP038_df[feature], label='MP038 - SAC - REx - Beta=0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(15,10))
ax.plot(MP039_df['timesteps_total'], MP039_df[feature], label='MP039 - D3RLPY-PEP2')
ax.plot(MP040_df['timesteps_total'], MP040_df[feature], label='MP040 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP041_df['timesteps_total'], MP041_df[feature], label='MP041 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP042_df['timesteps_total'], MP042_df[feature], label='MP042 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(15,10))
ax.plot(MP039_df['timesteps_total'], MP039_df[feature], label='MP039 - D3RLPY-PEP2')
ax.plot(MP040_df['timesteps_total'], MP040_df[feature], label='MP040 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP041_df['timesteps_total'], MP041_df[feature], label='MP041 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP042_df['timesteps_total'], MP042_df[feature], label='MP042 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(15,10))
ax.plot(MP039_df['timesteps_total'], MP039_df[feature], label='MP039 - D3RLPY-PEP2')
ax.plot(MP040_df['timesteps_total'], MP040_df[feature], label='MP040 - D3RLPY-PEP2 - Beta 0.1')
ax.plot(MP041_df['timesteps_total'], MP041_df[feature], label='MP041 - D3RLPY-PEP2 - Beta 0.2')
ax.plot(MP042_df['timesteps_total'], MP042_df[feature], label='MP042 - D3RLPY-PEP2 - Beta 0.5')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
MP035_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-34-49czxvu71z/model_loss_history.txt")
MP036_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-36-24fadbkq86/model_loss_history.txt")
MP037_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-37-58an5asxxe/model_loss_history.txt")
MP038_MODEL_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-42-446g8qnyrh/model_loss_history.txt")

MP035_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-34-49czxvu71z/model_holdout_loss_history.txt")
MP036_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-36-24fadbkq86/model_holdout_loss_history.txt")
MP037_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-37-58an5asxxe/model_holdout_loss_history.txt")
MP038_MODEL_HO_LOSS_PATH = get_results_path("ray_mopo/HalfCheetah/halfcheetah_d3rlpy_pep3_101e3/seed:1443_2022-05-20_12-42-446g8qnyrh/model_holdout_loss_history.txt")

# %%
MP035_loss_df = pd.read_csv(MP035_MODEL_LOSS_PATH)
MP036_loss_df = pd.read_csv(MP036_MODEL_LOSS_PATH)
MP037_loss_df = pd.read_csv(MP037_MODEL_LOSS_PATH)
MP038_loss_df = pd.read_csv(MP038_MODEL_LOSS_PATH)

MP035_ho_loss_df = pd.read_csv(MP035_MODEL_HO_LOSS_PATH)
MP036_ho_loss_df = pd.read_csv(MP036_MODEL_HO_LOSS_PATH)
MP037_ho_loss_df = pd.read_csv(MP037_MODEL_HO_LOSS_PATH)
MP038_ho_loss_df = pd.read_csv(MP038_MODEL_HO_LOSS_PATH)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP035_loss_df.mean(axis=1), label='MP035 - D3RLPY-PEP3')
ax.plot(MP036_loss_df.mean(axis=1), label='MP036 - D3RLPY-PEP3 - Beta 0.1')
ax.plot(MP037_loss_df.mean(axis=1), label='MP037 - D3RLPY-PEP3 - Beta 0.2')
ax.plot(MP038_loss_df.mean(axis=1), label='MP038 - D3RLPY-PEP3 - Beta 0.5')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(MP035_ho_loss_df.mean(axis=1), label='MP035 - D3RLPY-PEP3')
ax.plot(MP036_ho_loss_df.mean(axis=1), label='MP036 - D3RLPY-PEP3 - Beta 0.1')
ax.plot(MP037_ho_loss_df.mean(axis=1), label='MP037 - D3RLPY-PEP3 - Beta 0.2')
ax.plot(MP038_ho_loss_df.mean(axis=1), label='MP038 - D3RLPY-PEP3 - Beta 0.5')
ax.set_xlabel('Epochs')
ax.set_ylabel('Holdout Loss')
ax.legend()
pass
