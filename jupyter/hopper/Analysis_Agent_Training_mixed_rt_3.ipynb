# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
from itertools import zip_longest

import numpy as np
import matplotlib.pyplot as plt

from dogo.results import get_results, get_experiment_details
from dogo.plot_results import plot_experiment_metrics, plot_min_max_logvars, plot_evaluation_returns, plot_grouped_evaluation_returns, plot_min_max_penalty

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
#######################################
# MOPO - Penalty 0.0 - Rollout Length 5
#######################################

HO061 = get_results("HO061") # No Rex
HO062 = get_results("HO062")
HO063 = get_results("HO063")
HO064 = get_results("HO064") # REx - 5.0
HO065 = get_results("HO065")
HO066 = get_results("HO066")
HO067 = get_results("HO067") # REx - 10.0
HO068 = get_results("HO068")
HO069 = get_results("HO069")
HO070 = get_results("HO070") # REx - 20.0
HO071 = get_results("HO071")
HO072 = get_results("HO072")

# %%
########################################
# MOPO - Penalty 0.0 - Rollout Length 10
########################################

HO073 = get_results("HO073") # No Rex
HO074 = get_results("HO074")
HO075 = get_results("HO075")
HO076 = get_results("HO076") # REx - 5.0
HO077 = get_results("HO077")
HO078 = get_results("HO078")
HO079 = get_results("HO079") # REx - 10.0
HO080 = get_results("HO080")
HO081 = get_results("HO081")
HO082 = get_results("HO082") # REx - 20.0
HO083 = get_results("HO083")
HO084 = get_results("HO084")

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 5.0

# %%
plot_evaluation_returns([
    HO061,
    HO062,
    HO063,
    HO064,
    HO065,
    HO066,
    HO067,
    HO068,
    HO069,
    HO070,
    HO071,
    HO072,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$')
# Out:
# HO061: 557.3714599609375
# HO062: 528.0216064453125
# HO063: 1753.6431884765625
# HO064: 731.5738525390625
# HO065: 206.03408813476562
# HO066: 648.288818359375
# HO067: 746.7073974609375
# HO068: 713.3585205078125
# HO069: 211.8051300048828
# HO070: 743.7596435546875
# HO071: 808.7872314453125
# HO072: 186.53700256347656

# %%
plot_grouped_evaluation_returns([
    ((HO061, HO062, HO063), 'No REx'),
    ((HO064, HO065, HO066), 'REx - $\\beta=5.0$'),
    ((HO067, HO068, HO069), 'REx - $\\beta=10.0$'),
    ((HO070, HO071, HO072), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$', max_timestep=700000)
# Out:
# {'No REx': {'mean': 364, 'std': 355, 'count': 3, 'text': '364 ± 355'},
#  'REx - $\\beta=5.0$': {'mean': 424,
#   'std': 171,
#   'count': 3,
#   'text': '424 ± 171'},
#  'REx - $\\beta=10.0$': {'mean': 674,
#   'std': 385,
#   'count': 3,
#   'text': '674 ± 385'},
#  'REx - $\\beta=20.0$': {'mean': 909,
#   'std': 108,
#   'count': 3,
#   'text': '909 ± 108'}}

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 10.0

# %%
plot_evaluation_returns([
    HO073,
    HO074,
    HO075,
    HO076,
    HO077,
    HO078,
    HO079,
    HO080,
    HO081,
    HO082,
    HO083,
    HO084,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$')
# Out:
# HO073: 916.33251953125
# HO074: 896.4775390625
# HO075: 730.8263549804688
# HO076: 841.3944091796875
# HO077: 990.9714965820312
# HO078: 952.6705932617188
# HO079: 923.3682861328125
# HO080: 954.07177734375
# HO081: 1058.822509765625
# HO082: 199.62454223632812
# HO083: 1547.350341796875
# HO084: 1020.5899658203125

# %%
plot_grouped_evaluation_returns([
    ((HO073, HO074, HO075), 'No REx'),
    ((HO076, HO077, HO078), 'REx - $\\beta=5.0$'),
    ((HO079, HO080, HO081), 'REx - $\\beta=10.0$'),
    ((HO082, HO083, HO084), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$', max_timestep=700000)
# Out:
# {'No REx': {'mean': 912, 'std': 298, 'count': 3, 'text': '912 ± 298'},
#  'REx - $\\beta=5.0$': {'mean': 948,
#   'std': 86,
#   'count': 3,
#   'text': '948 ± 86'},
#  'REx - $\\beta=10.0$': {'mean': 716,
#   'std': 289,
#   'count': 3,
#   'text': '716 ± 289'},
#  'REx - $\\beta=20.0$': {'mean': 975,
#   'std': 331,
#   'count': 3,
#   'text': '975 ± 331'}}

# %% [markdown]
# # RAND-1

# %%
#######################################
# MOPO - Penalty 0.0 - Rollout Length 5
#######################################

HO121 = get_results("HO121") # No Rex
HO122 = get_results("HO122")
HO123 = get_results("HO123")
HO124 = get_results("HO124") # REx - 5.0
HO125 = get_results("HO125")
HO126 = get_results("HO126")
HO127 = get_results("HO127") # REx - 10.0
HO128 = get_results("HO128")
HO129 = get_results("HO129")
HO130 = get_results("HO130") # REx - 20.0
HO131 = get_results("HO131")
HO132 = get_results("HO132")

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 5.0

# %%
plot_evaluation_returns([
    HO121,
    HO122,
    HO123,
    HO124,
    HO125,
    HO126,
    HO127,
    HO128,
    HO129,
    HO130,
    HO131,
    HO132,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$')
# Out:
# HO121: 8.511380195617676
# HO122: 5.461239337921143
# HO123: 6.027349948883057
# HO124: 7.428135871887207
# HO125: 8.550934791564941
# HO126: 6.986745357513428
# HO127: 7.686587333679199
# HO128: 9.404183387756348
# HO129: 4.800070762634277
# HO130: 9.67376708984375
# HO131: 7.29330587387085
# HO132: 4.675088405609131

# %%
plot_grouped_evaluation_returns([
    ((HO121, HO122, HO123), 'No REx'),
    ((HO124, HO125, HO126), 'REx - $\\beta=5.0$'),
    ((HO127, HO128, HO129), 'REx - $\\beta=10.0$'),
    ((HO130, HO131, HO132), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$', max_timestep=1000000)
# Out:
# {'No REx': {'mean': 7, 'std': 1, 'count': 3, 'text': '7 ± 1'},
#  'REx - $\\beta=5.0$': {'mean': 8, 'std': 1, 'count': 3, 'text': '8 ± 1'},
#  'REx - $\\beta=10.0$': {'mean': 7, 'std': 2, 'count': 3, 'text': '7 ± 2'},
#  'REx - $\\beta=20.0$': {'mean': 7, 'std': 2, 'count': 3, 'text': '7 ± 2'}}
