# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rc('font', size=16)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
labels = ['$\\lambda=0.0$', '$\\lambda=1.0$', '$\\lambda=5.0$']

rt_1_rl_5_mean = [-49.79794674, 8.15787999, -77.66736487]
rt_1_rl_5_std = [145.45731226, 17.89381356, 243.50435446]

rt_4_rl_5_mean = [-1.09610801, -19.98960991, -0.4587793]
rt_4_rl_5_std = [18.94173563, 57.20455312, 20.35530243]

rt_5_rl_5_mean = [-98.94164432, -9.41840652, -17.66702878]
rt_5_rl_5_std = [358.11169894, 37.5614601, 30.35812048]

rt_1_rl_10_mean = [-37.82544760002961, -15.239852480270883, 36.4457176933843]
rt_1_rl_10_std = [54.77818899205404, 41.23289064419776, 36.8928233723657]

rt_4_rl_10_mean = [-15.858048035048531, -61.76962754089228, -12.98959541938142]
rt_4_rl_10_std = [35.98597532476668, 189.44941579862765, 25.41857215079696]

rt_5_rl_10_mean = [-319.08053495471944, 16.091587985314618, 9.390184039884844]
rt_5_rl_10_std = [1012.4140023883749, 49.02162615947647, 51.91214075403514]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for mean_arr, std_err, label, c, ls in [
    (rt_1_rl_5_mean, rt_1_rl_5_std, 'Mixed - h=5', cols[0], '-'),
    (rt_4_rl_5_mean, rt_4_rl_5_std, 'Experienced - h=5', cols[1], '-'),
    (rt_5_rl_5_mean, rt_5_rl_5_std, 'Novice - h=5', cols[2], '-'),
    (rt_1_rl_10_mean, rt_1_rl_10_std, 'Mixed - h=10', cols[0], '--'),
    (rt_4_rl_10_mean, rt_4_rl_10_std, 'Experienced - h=10', cols[1], '--'),
    (rt_5_rl_10_mean, rt_5_rl_10_std, 'Novice - h=10', cols[2], '--'),
]:
    ax.errorbar(np.arange(3), mean_arr, std_err, color=c, ls=ls, label=label, capsize=10)
ax.set_xticks(np.arange(3))
ax.set_xticklabels(labels)
ax.set_title('Hopper')
ax.set_xlabel('MOPO Penaly Coefficient')
ax.set_ylabel('Model Exploitation')
ax.set_ylim(-150, 150)
ax.legend()
