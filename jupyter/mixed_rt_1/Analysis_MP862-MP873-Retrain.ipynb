# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
from itertools import zip_longest

import numpy as np
import matplotlib.pyplot as plt

from dogo.results import get_results
from dogo.plot_results import plot_experiment_metrics, plot_min_max_logvars, plot_evaluation_returns, plot_grouped_evaluation_returns, plot_min_max_penalty

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 10.0 - Epoch Retraining

# %%
##########################
# Original Dynamics Models
##########################
MP748 = get_results("MP748") # No REx
MP749 = get_results("MP749")
MP750 = get_results("MP750")
MP757 = get_results("MP757") # REx 10.0
MP758 = get_results("MP758")
MP759 = get_results("MP759")

# %%
#############################################################
# MOPO - Penalty 5.0 - Rollout Length 10 v1 - 1 epoch retrain
#############################################################
MP817 = get_results("MP817") # No Rex
MP818 = get_results("MP818")
MP819 = get_results("MP819")
MP823 = get_results("MP823") # REx - 5.0
MP824 = get_results("MP824")
MP825 = get_results("MP825")
MP820 = get_results("MP820") # REx - 10.0
MP821 = get_results("MP821")
MP822 = get_results("MP822")

#############################################################
# MOPO - Penalty 5.0 - Rollout Length 10 v2 - 1 epoch retrain
#############################################################
MP862 = get_results("MP862") # No Rex
MP863 = get_results("MP863")
MP864 = get_results("MP864")
MP865 = get_results("MP865") # REx - 10.0
MP866 = get_results("MP866")
MP867 = get_results("MP867")

# %%
##########################################################
# MOPO - Penalty 5.0 - Rollout Length 10 - 0 epoch retrain
##########################################################
MP868 = get_results("MP868") # No Rex
MP869 = get_results("MP869")
MP870 = get_results("MP870")
MP871 = get_results("MP871") # REx - 10.0
MP872 = get_results("MP872")
MP873 = get_results("MP873")

# %% [markdown]
# ## Original results

# %%
plot_evaluation_returns([
    MP817,
    MP818,
    MP819,
    MP820,
    MP821,
    MP822,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', ymin=-3000, ymax=12000)

# %%
plot_grouped_evaluation_returns([
    ((MP817, MP818, MP819), '0'),
    ((MP823, MP824, MP825), '5.0'),
    ((MP820, MP821, MP822), '10.0'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', ymin=-3000, ymax=12000)
# Out:
# {'0': {'mean': -497.11460876464844, 'std': 421.9729331598046},
#  '5.0': {'mean': 4704.326855977376, 'std': 3412.8571645502293},
#  '10.0': {'mean': 7273.643391927083, 'std': 945.3930401101429}}

# %% [markdown]
# ## Re-Run results

# %%
plot_evaluation_returns([
    MP862,
    MP863,
    MP864,
    MP865,
    MP866,
    MP867,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', ymin=-3000, ymax=12000)

# %%
plot_grouped_evaluation_returns([
    ((MP862, MP863, MP864), '0'),
    ((MP865, MP866, MP867), '10.0'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', ymin=-3000, ymax=12000)
# Out:
# {'0': {'mean': -420.41717529296875, 'std': 49.997673052090136},
#  '10.0': {'mean': 8127.672526041667, 'std': 1053.402132572436}}

# %% [markdown]
# ## Original and Re-Run Comparison

# %%
plot_grouped_evaluation_returns([
    ((MP817, MP818, MP819), '0 - Original'),
    ((MP862, MP863, MP864), '0 - Latest'),
    ((MP820, MP821, MP822), '10.0 - Original'),
    ((MP865, MP866, MP867), '10.0 - Latest'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', ymin=-3000, ymax=12000)
# Out:
# {'0 - Original': {'mean': -497.11460876464844, 'std': 421.9729331598046},
#  '0 - Latest': {'mean': -420.41717529296875, 'std': 49.997673052090136},
#  '10.0 - Original': {'mean': 7273.643391927083, 'std': 945.3930401101429},
#  '10.0 - Latest': {'mean': 8127.672526041667, 'std': 1053.402132572436}}

# %% [markdown]
# ## No Additional Retraining

# %%
plot_evaluation_returns([
    MP868,
    MP869,
    MP870,
    MP871,
    MP872,
    MP873,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', ymin=-3000, ymax=12000)

# %% [markdown]
# ## Compare REx Results

# %%
plot_evaluation_returns([
    MP865,
    MP866,
    MP867,
    MP871,
    MP872,
    MP873,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', ymin=-3000, ymax=12000)

# %%
plot_grouped_evaluation_returns([
    ((MP871, MP872, MP873), '10.0 - Original Model'),
    ((MP865, MP866, MP867), '10.0 - 1 Epoch of Retraining'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', ymin=-3000, ymax=12000)
# Out:
# {'10.0 - Original Model': {'mean': 4616.130366007487,
#   'std': 3466.8020158263375},
#  '10.0 - 1 Epoch of Retraining': {'mean': 8127.672526041667,
#   'std': 1053.402132572436}}

# %%
plot_grouped_evaluation_returns([
    ((MP868, MP869, MP870), 'No REx - Original Model'),
    ((MP862, MP863, MP864), 'No REx - Updated Model'),
    ((MP871, MP872, MP873), 'REx - $\\beta=10.0$ - Original Model'),
    ((MP865, MP866, MP867), 'REx - $\\beta=10.0$ - Updated Model'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', ymin=-3000, ymax=12000)
# Out:
# {'No REx - Original Model': {'mean': -378.9310709635417,
#   'std': 359.52803441473617},
#  'No REx - Updated Model': {'mean': -420.41717529296875,
#   'std': 49.997673052090136},
#  'REx - $\\beta=10.0$ - Original Model': {'mean': 4616.130366007487,
#   'std': 3466.8020158263375},
#  'REx - $\\beta=10.0$ - Updated Model': {'mean': 8127.672526041667,
#   'std': 1053.402132572436}}

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'model/mean_penalty'
for exp, rex, beta, col_ind, ls, post_label in [
    (MP871, True, 10.0, 0, '-',  'Original Model'),
    (MP872, True, 10.0, 1, '-',  'Original Model'),
    (MP873, True, 10.0, 2, '-',  'Original Model'),
    (MP865, True, 10.0, 0, '--', '1 Epoch of Retraining'),
    (MP866, True, 10.0, 1, '--', '1 Epoch of Retraining'),
    (MP867, True, 10.0, 2, '--', '1 Epoch of Retraining'),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], c=cols[col_ind], ls=ls, label=f'{exp.name} - REx: {rex} - Beta: {beta} - Seed: {exp.seed} - {post_label}'
    )
    ax.axhline(exp.max_penalty, c=cols[col_ind], ls=':')
ax.set_xlabel('Steps')
ax.set_ylabel('Average Reward Penalty')
ax.legend()
pass

# %% [markdown]
# ## Log Vars and Penalties Comparison

# %%
plot_min_max_logvars([
    ((MP748, MP749, MP750), 'No REx - Original Model'),
    ((MP862, MP863, MP864), 'No REx - 1 Epoch of Retraining'),
    ((MP757, MP758, MP759), 'REx - Beta = 10.0 - Original Model'),
    ((MP865, MP866, MP867), 'REx - Beta = 10.0 - 1 Epoch of Retraining'),
])

# %%
plot_min_max_penalty([
    ((MP748, MP749, MP750), 'No REx - Original Model'),
    ((MP862, MP863, MP864), 'No REx - 1 Epoch of Retraining'),
    ((MP757, MP758, MP759), 'REx - Beta = 10.0 - Original Model'),
    ((MP865, MP866, MP867), 'REx - Beta = 10.0 - 1 Epoch of Retraining'),
])
