# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/home/ajc348/rds/hpc-work/mopo')

# %%
import matplotlib.pyplot as plt

from dogo.results import get_results
from dogo.plot_results import plot_evaluation_returns, plot_grouped_evaluation_returns

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 5.0

# %%
WA157 = get_results("WA157") # No Rex
WA158 = get_results("WA158")
WA159 = get_results("WA159")
WA160 = get_results("WA160") # REx - 5.0
WA161 = get_results("WA161")
WA162 = get_results("WA162")
WA163 = get_results("WA163") # REx - 10.0
WA164 = get_results("WA164")
WA165 = get_results("WA165")
WA166 = get_results("WA166") # REx - 20.0
WA167 = get_results("WA167")
WA168 = get_results("WA168")

# %%
# plot_evaluation_returns([
#     WA157,
#     WA158,
#     WA159,
#     WA160,
#     WA161,
#     WA162,
#     WA163,
#     WA164,
#     WA165,
#     WA166,
#     WA167,
#     WA168,
# ], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$')

# %%
plot_grouped_evaluation_returns([
    ((WA157, WA158, WA159), 'No REx'),
    ((WA160, WA161, WA162), 'REx - $\\beta=5.0$'),
    ((WA163, WA164, WA165), 'REx - $\\beta=10.0$'),
    ((WA166, WA167, WA168), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$', max_timestep=3000000)
# Out:
# {'No REx': {'mean': 263, 'std': 203, 'count': 3, 'text': '263 ± 203'},
#  'REx - $\\beta=5.0$': {'mean': 412,
#   'std': 263,
#   'count': 3,
#   'text': '412 ± 263'},
#  'REx - $\\beta=10.0$': {'mean': 501,
#   'std': 89,
#   'count': 3,
#   'text': '501 ± 89'},
#  'REx - $\\beta=20.0$': {'mean': 1068,
#   'std': 849,
#   'count': 3,
#   'text': '1068 ± 849'}}

# %%
plot_evaluation_returns([
    WA157,
    WA158,
    WA159,
    WA160,
    WA161,
    WA162,
    WA163,
    WA164,
    WA165,
    WA166,
    WA167,
    WA168,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$', feature='Q-avg', ymin=-1e3, ymax=1e3, legend=True, loc='upper right')
# Out:
# WA157: 130.14990234375
# WA158: 36.54345703125
# WA159: 80.72310638427734
# WA160: 75.23777770996094
# WA161: 147.572265625
# WA162: 108.48657989501953
# WA163: 135.74415588378906
# WA164: 96.91321563720703
# WA165: 111.51754760742188
# WA166: 126.88316345214844
# WA167: 64.112548828125
# WA168: 130.34881591796875

# %% [markdown]
# # MOPO: 1.0 - Rollout-Length: 5.0

# %%
WA181 = get_results("WA181") # No Rex
WA182 = get_results("WA182")
WA183 = get_results("WA183")
WA184 = get_results("WA184") # REx - 5.0
WA185 = get_results("WA185")
WA186 = get_results("WA186")
WA187 = get_results("WA187") # REx - 10.0
WA188 = get_results("WA188")
WA189 = get_results("WA189")
WA190 = get_results("WA190") # REx - 20.0
WA191 = get_results("WA191")
WA192 = get_results("WA192")

# %%
# plot_evaluation_returns([
#     WA181,
#     WA182,
#     WA183,
#     WA184,
#     WA185,
#     WA186,
#     WA187,
#     WA188,
#     WA189,
#     WA190,
#     WA191,
#     WA192,
# ], title='MOPO Hyperparameters: $\\lambda=1.0$, $h=5$')

# %%
plot_grouped_evaluation_returns([
    ((WA181, WA182, WA183), 'No REx'),
    ((WA184, WA185, WA186), 'REx - $\\beta=5.0$'),
    ((WA187, WA188, WA189), 'REx - $\\beta=10.0$'),
    ((WA190, WA191, WA192), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=1.0$, $h=5$', max_timestep=3000000)
# Out:
# {'No REx': {'mean': 214, 'std': 222, 'count': 3, 'text': '214 ± 222'},
#  'REx - $\\beta=5.0$': {'mean': 98,
#   'std': 141,
#   'count': 3,
#   'text': '98 ± 141'},
#  'REx - $\\beta=10.0$': {'mean': -2, 'std': 1, 'count': 3, 'text': '-2 ± 1'},
#  'REx - $\\beta=20.0$': {'mean': -2, 'std': 0, 'count': 3, 'text': '-2 ± 0'}}

# %%
plot_evaluation_returns([
    WA181,
    WA182,
    WA183,
    WA184,
    WA185,
    WA186,
    WA187,
    WA188,
    WA189,
    WA190,
    WA191,
    WA192,
], title='MOPO Hyperparameters: $\\lambda=1.0$, $h=5$', feature='Q-avg', ymin=-1e3, ymax=1e3, legend=True, loc='upper right')
# Out:
# WA181: 22.720264434814453
# WA182: -18.181751251220703
# WA183: -0.24990990757942202
# WA184: -10.763655662536621
# WA185: 6.454527378082275
# WA186: 9.891387939453125
# WA187: 6.200634956359863
# WA188: -8.402575492858887
# WA189: -9.555669784545898
# WA190: -1.8582520484924312
# WA191: -29.877277374267578
# WA192: 3.192480564117431

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 5.0

# %%
WA193 = get_results("WA193") # No Rex
WA194 = get_results("WA194")
WA195 = get_results("WA195")
WA196 = get_results("WA196") # REx - 5.0
WA197 = get_results("WA197")
WA198 = get_results("WA198")
WA199 = get_results("WA199") # REx - 10.0
WA200 = get_results("WA200")
WA201 = get_results("WA201")
WA202 = get_results("WA202") # REx - 20.0
WA203 = get_results("WA203")
WA204 = get_results("WA204")

# %%
# plot_evaluation_returns([
#     WA193,
#     WA194,
#     WA195,
#     WA196,
#     WA197,
#     WA198,
#     WA199,
#     WA200,
#     WA201,
#     WA202,
#     WA203,
#     WA204,
# ], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$')

# %%
plot_grouped_evaluation_returns([
    ((WA193, WA194, WA195), 'No REx'),
    ((WA196, WA197, WA198), 'REx - $\\beta=5.0$'),
    ((WA199, WA200, WA201), 'REx - $\\beta=10.0$'),
    ((WA202, WA203, WA204), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$', max_timestep=3000000)
# Out:
# {'No REx': {'mean': -2, 'std': 0, 'count': 3, 'text': '-2 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': -3, 'std': 0, 'count': 3, 'text': '-3 ± 0'},
#  'REx - $\\beta=10.0$': {'mean': -2, 'std': 0, 'count': 3, 'text': '-2 ± 0'},
#  'REx - $\\beta=20.0$': {'mean': -3, 'std': 0, 'count': 3, 'text': '-3 ± 0'}}

# %%
plot_evaluation_returns([
    WA193,
    WA194,
    WA195,
    WA196,
    WA197,
    WA198,
    WA199,
    WA200,
    WA201,
    WA202,
    WA203,
    WA204,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$', feature='Q-avg', ymin=-1e3, ymax=1e3, legend=True, loc='upper right')
# Out:
# WA193: -68.32511138916016
# WA194: -111.39419555664062
# WA195: -80.42561340332031
# WA196: -109.8147964477539
# WA197: -87.51891326904297
# WA198: -89.54023742675781
# WA199: -110.82424926757812
# WA200: -139.79530334472656
# WA201: -133.63577270507812
# WA202: -118.14498901367188
# WA203: -194.48265075683594
# WA204: -103.42147064208984

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 10.0

# %%
WA169 = get_results("WA169") # No Rex
WA170 = get_results("WA170")
WA171 = get_results("WA171")
WA172 = get_results("WA172") # REx - 5.0
WA173 = get_results("WA173")
WA174 = get_results("WA174")
WA175 = get_results("WA175") # REx - 10.0
WA176 = get_results("WA176")
WA177 = get_results("WA177")
WA178 = get_results("WA178") # REx - 20.0
WA179 = get_results("WA179")
WA180 = get_results("WA180")

# %%
# plot_evaluation_returns([
#     WA169,
#     WA170,
#     WA171,
#     WA172,
#     WA173,
#     WA174,
#     WA175,
#     WA176,
#     WA177,
#     WA178,
#     WA179,
#     WA180,
# ], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$')

# %%
plot_grouped_evaluation_returns([
    ((WA169, WA170, WA171), 'No REx'),
    ((WA172, WA173, WA174), 'REx - $\\beta=5.0$'),
    ((WA175, WA176, WA177), 'REx - $\\beta=10.0$'),
    ((WA178, WA179, WA180), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$', max_timestep=3000000)
# Out:
# {'No REx': {'mean': 327, 'std': 62, 'count': 3, 'text': '327 ± 62'},
#  'REx - $\\beta=5.0$': {'mean': 521,
#   'std': 182,
#   'count': 3,
#   'text': '521 ± 182'},
#  'REx - $\\beta=10.0$': {'mean': 817,
#   'std': 242,
#   'count': 3,
#   'text': '817 ± 242'},
#  'REx - $\\beta=20.0$': {'mean': 1594,
#   'std': 1598,
#   'count': 3,
#   'text': '1594 ± 1598'}}

# %%
plot_evaluation_returns([
    WA169,
    WA170,
    WA171,
    WA172,
    WA173,
    WA174,
    WA175,
    WA176,
    WA177,
    WA178,
    WA179,
    WA180,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$', feature='Q-avg', ymin=-1e3, ymax=1e3, legend=True, loc='upper right')
# Out:
# WA169: 123.9737319946289
# WA170: 29.86662483215332
# WA171: 70.28694915771484
# WA172: 63.7869873046875
# WA173: 166.23541259765625
# WA174: 122.72184753417969
# WA175: 137.69154357910156
# WA176: 112.42898559570312
# WA177: 111.99484252929688
# WA178: 160.3046112060547
# WA179: 72.61611938476562
# WA180: 154.25997924804688

# %% [markdown]
# # MOPO: 1.0 - Rollout-Length: 10.0

# %%
WA205 = get_results("WA205") # No Rex
WA206 = get_results("WA206")
WA207 = get_results("WA207")
WA208 = get_results("WA208") # REx - 5.0
WA209 = get_results("WA209")
WA210 = get_results("WA210")
WA211 = get_results("WA211") # REx - 10.0
WA212 = get_results("WA212")
WA213 = get_results("WA213")
WA214 = get_results("WA214") # REx - 20.0
WA215 = get_results("WA215")
WA216 = get_results("WA216")

# %%
# plot_evaluation_returns([
#     WA205,
#     WA206,
#     WA207,
#     WA208,
#     WA209,
#     WA210,
#     WA211,
#     WA212,
#     WA213,
#     WA214,
#     WA215,
#     WA216,
# ], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$')

# %%
plot_grouped_evaluation_returns([
    ((WA205, WA206, WA207), 'No REx'),
    ((WA208, WA209, WA210), 'REx - $\\beta=5.0$'),
    ((WA211, WA212, WA213), 'REx - $\\beta=10.0$'),
    ((WA214, WA215, WA216), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$', max_timestep=3000000)
# Out:
# {'No REx': {'mean': 83, 'std': 121, 'count': 3, 'text': '83 ± 121'},
#  'REx - $\\beta=5.0$': {'mean': 325,
#   'std': 364,
#   'count': 3,
#   'text': '325 ± 364'},
#  'REx - $\\beta=10.0$': {'mean': 82,
#   'std': 118,
#   'count': 3,
#   'text': '82 ± 118'},
#  'REx - $\\beta=20.0$': {'mean': 86,
#   'std': 125,
#   'count': 3,
#   'text': '86 ± 125'}}

# %%
plot_evaluation_returns([
    WA205,
    WA206,
    WA207,
    WA208,
    WA209,
    WA210,
    WA211,
    WA212,
    WA213,
    WA214,
    WA215,
    WA216,
], title='MOPO Hyperparameters: $\\lambda=1.0$, $h=10$', feature='Q-avg', ymin=-1e3, ymax=1e3, legend=True, loc='upper right')
# Out:
# WA205: 18.445613861083984
# WA206: -26.705718994140625
# WA207: 9.088338851928711
# WA208: -5.324227333068848
# WA209: 33.85692596435547
# WA210: 12.833686828613281
# WA211: 18.27193832397461
# WA212: -9.774658203125
# WA213: 0.078746795654296
# WA214: 2.596604824066162
# WA215: -27.463146209716797
# WA216: 21.282207489013672

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 10.0

# %%
WA217 = get_results("WA217") # No Rex
WA218 = get_results("WA218")
WA219 = get_results("WA219")
WA220 = get_results("WA220") # REx - 5.0
WA221 = get_results("WA221")
WA222 = get_results("WA222")
WA223 = get_results("WA223") # REx - 10.0
WA224 = get_results("WA224")
WA225 = get_results("WA225")
WA226 = get_results("WA226") # REx - 20.0
WA227 = get_results("WA227")
WA228 = get_results("WA228")

# %%
# plot_evaluation_returns([
#     WA217,
#     WA218,
#     WA219,
#     WA220,
#     WA221,
#     WA222,
#     WA223,
#     WA224,
#     WA225,
#     WA226,
#     WA227,
#     WA228,
# ], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$')

# %%
plot_grouped_evaluation_returns([
    ((WA217, WA218, WA219), 'No REx'),
    ((WA220, WA221, WA222), 'REx - $\\beta=5.0$'),
    ((WA223, WA224, WA225), 'REx - $\\beta=10.0$'),
    ((WA226, WA227, WA228), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', max_timestep=3000000)
# Out:
# {'No REx': {'mean': -3, 'std': 0, 'count': 3, 'text': '-3 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': -2, 'std': 1, 'count': 3, 'text': '-2 ± 1'},
#  'REx - $\\beta=10.0$': {'mean': -2, 'std': 0, 'count': 3, 'text': '-2 ± 0'},
#  'REx - $\\beta=20.0$': {'mean': -3, 'std': 0, 'count': 3, 'text': '-3 ± 0'}}

# %%
plot_evaluation_returns([
    WA217,
    WA218,
    WA219,
    WA220,
    WA221,
    WA222,
    WA223,
    WA224,
    WA225,
    WA226,
    WA227,
    WA228,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', feature='Q-avg', ymin=-1e3, ymax=1e3, legend=True, loc='upper right')
# Out:
# WA217: -62.502689361572266
# WA218: -103.07125091552734
# WA219: -68.93402862548828
# WA220: -83.31826782226562
# WA221: -79.88893127441406
# WA222: -68.68096923828125
# WA223: -101.54069519042969
# WA224: -117.17636108398438
# WA225: -111.07183837890625
# WA226: -103.51365661621094
# WA227: -151.53128051757812
# WA228: -87.57941436767578
