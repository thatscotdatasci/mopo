# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
import numpy as np
import matplotlib.pyplot as plt

from dogo.plot_results import plot_dynamics_score_vs_agent_return

# %%
plt.rc('font', size=24)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
evaluation_datasets_lables = [
    ("H-D3RLPY-RT-0.1M-1-P0_10000", "D3RLPY 1: 0.1M"),
    ("H-D3RLPY-RT-0.2M-1-P0_10000", "D3RLPY 1: 0.2M"),
    ("H-D3RLPY-RT-0.4M-1-P0_10000", "D3RLPY 1: 0.4M"),
    ("H-D3RLPY-RT-0.6M-1-P0_10000", "D3RLPY 1: 0.6M"),
    ("H-D3RLPY-RT-0.8M-1-P0_10000", "D3RLPY 1: 0.8M"),
    ("H-D3RLPY-RT-1M-1-P0_10000", "D3RLPY 1: 1M"),
    ("H-D3RLPY-RT-0.1M-2-P0_10000", "D3RLPY 2: 0.1M"),
    ("H-D3RLPY-RT-0.2M-2-P0_10000", "D3RLPY 2: 0.2M"),
    ("H-D3RLPY-RT-0.4M-2-P0_10000", "D3RLPY 2: 0.4M"),
    ("H-D3RLPY-RT-0.6M-2-P0_10000", "D3RLPY 2: 0.6M"),
    ("H-D3RLPY-RT-0.8M-2-P0_10000", "D3RLPY 2: 0.8M"),
    ("H-D3RLPY-RT-1M-2-P0_10000", "D3RLPY 2: 1M"),
    ("H-D3RLPY-RT-0.1M-3-P0_10000", "D3RLPY 3: 0.1M"),
    ("H-D3RLPY-RT-0.2M-3-P0_10000", "D3RLPY 3: 0.2M"),
    ("H-D3RLPY-RT-0.4M-3-P0_10000", "D3RLPY 3: 0.4M"),
    ("H-D3RLPY-RT-0.6M-3-P0_10000", "D3RLPY 3: 0.6M"),
    ("H-D3RLPY-RT-0.8M-3-P0_10000", "D3RLPY 3: 0.8M"),
    ("H-D3RLPY-RT-1M-3-P0_10000", "D3RLPY 3: 1M"),
    ("H-SAC-RT-0.1M-1-P0_10000", "SL 1: 0.1M"),
    ("H-SAC-RT-0.2M-1-P0_10000", "SL 1: 0.2M"),
    ("H-SAC-RT-0.4M-1-P0_10000", "SL 1: 0.4M"),
    ("H-SAC-RT-0.6M-1-P0_10000", "SL 1: 0.6M"),
    ("H-SAC-RT-0.8M-1-P0_10000", "SL 1: 0.8M"),
    ("H-SAC-RT-1M-1-P0_10000", "SL 1: 1M"),
    ("H-SAC-RT-0.1M-2-P0_10000", "SL 2: 0.1M"),
    ("H-SAC-RT-0.2M-2-P0_10000", "SL 2: 0.2M"),
    ("H-SAC-RT-0.4M-2-P0_10000", "SL 2: 0.4M"),
    ("H-SAC-RT-0.6M-2-P0_10000", "SL 2: 0.6M"),
    ("H-SAC-RT-0.8M-2-P0_10000", "SL 2: 0.8M"),
    ("H-SAC-RT-1M-2-P0_10000", "SL 2: 1M"),
    ("H-SAC-RT-0.1M-3-P0_10000", "SL 3: 0.1M"),
    ("H-SAC-RT-0.2M-3-P0_10000", "SL 3: 0.2M"),
    ("H-SAC-RT-0.4M-3-P0_10000", "SL 3: 0.4M"),
    ("H-SAC-RT-0.6M-3-P0_10000", "SL 3: 0.6M"),
    ("H-SAC-RT-0.8M-3-P0_10000", "SL 3: 0.8M"),
    ("H-SAC-RT-1M-3-P0_10000", "SL 3: 1M"),
    ("D4RL-H-M_10000", "D4RL: M"),
    ("D4RL-H-ME_10000", "D4RL: ME"),
    ("D4RL-H-MR_10000", "D4RL: MR"),
    ("D4RL-H-R_10000", "D4RL: R"),
    ("H-RAND-1_10000", "Random 1"),
    ("H-RAND-2_10000", "Random 2"),
    ("H-RAND-3_10000", "Random 3"),
]
evaluation_datasets = [i[0] for i in evaluation_datasets_lables]
evaluation_labels = [i[1] for i in evaluation_datasets_lables]

rt_1_training_datasets_labels = [
    ("H-RAND-2_10000", "Random 2"),
    ("H-SAC-RT-0.25M-4-P0_10000", "SL: 0.25M"),
    ("H-SAC-RT-1M-4-P0_10000", "SL: 1M"),
    ("H-D3RLPY-RT-0.2M-4-P0_10000", "D3RLPY: 0.2M"),
    ("H-D3RLPY-RT-2M-4-P0_10000", "D3RLPY: 2M"),
]
rt_1_training_datasets = [i[0] for i in rt_1_training_datasets_labels]
rt_1_training_labels = [i[1] for i in rt_1_training_datasets_labels]

rt_3_training_datasets_labels = [
    ("H-RAND-2_10000", "Random 2"),
    ("H-RAND-3_10000", "Random 3"),
    ("H-SAC-RT-0.1M-4-P0_10000", "SL: 0.1M"),
    ("H-D3RLPY-RT-0.1M-4-P0_10000", "D3RLPY: 0.1M"),
    ("H-D3RLPY-RT-0.2M-4-P0_10000", "D3RLPY: 0.2M"),
]
rt_3_training_datasets = [i[0] for i in rt_3_training_datasets_labels]
rt_3_training_labels = [i[1] for i in rt_3_training_datasets_labels]

rt_4_training_datasets_labels = [
    ("H-SAC-RT-1M-4-P0_10000", "SL: 1M"),
    ("H-SAC-RT-2M-4-P0_10000", "SL: 2M"),
    ("H-SAC-RT-3M-4-P0_10000", "SL: 3M"),
    ("H-D3RLPY-RT-1M-4-P0_10000", "D3RLPY: 1M"),
    ("H-D3RLPY-RT-2M-4-P0_10000", "D3RLPY: 2M"),
]
rt_4_training_datasets = [i[0] for i in rt_4_training_datasets_labels]
rt_4_training_labels = [i[1] for i in rt_4_training_datasets_labels]

# %% [markdown]
# # All Datasets

# %% [markdown]
# ## h=5

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO325', 'HO326', 'HO327', 'HO349', 'HO350', 'HO351', 'HO157', 'HO158', 'HO159'), 'No REx'),
    (('HO328', 'HO329', 'HO330', 'HO352', 'HO353', 'HO354', 'HO160', 'HO161', 'HO162'), 'REx - $\\beta=5.0$'),
    (('HO331', 'HO332', 'HO333', 'HO355', 'HO356', 'HO357', 'HO163', 'HO164', 'HO165'), 'REx - $\\beta=10.0$'),
    (('HO334', 'HO335', 'HO336', 'HO358', 'HO359', 'HO360', 'HO166', 'HO167', 'HO168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-1200, xmax=50, agent_score_timesteps=1000000, save_path='workshop/env_model_log_lik_policy_eval_h_h5.png', fig_size=(10,12))

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO325', 'HO326', 'HO327', 'HO349', 'HO350', 'HO351', 'HO157', 'HO158', 'HO159'), 'No REx'),
    # (('HO328', 'HO329', 'HO330', 'HO352', 'HO353', 'HO354', 'HO160', 'HO161', 'HO162'), 'REx - $\\beta=5.0$'),
    (('HO331', 'HO332', 'HO333', 'HO355', 'HO356', 'HO357', 'HO163', 'HO164', 'HO165'), 'REx - $\\beta=10.0$'),
    (('HO334', 'HO335', 'HO336', 'HO358', 'HO359', 'HO360', 'HO166', 'HO167', 'HO168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-600, agent_score_timesteps=1000000)

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO325', 'HO326', 'HO327', 'HO349', 'HO350', 'HO351', 'HO157', 'HO158', 'HO159'), 'No REx'),
    (('HO328', 'HO329', 'HO330', 'HO352', 'HO353', 'HO354', 'HO160', 'HO161', 'HO162'), 'REx - $\\beta=5.0$'),
    (('HO331', 'HO332', 'HO333', 'HO355', 'HO356', 'HO357', 'HO163', 'HO164', 'HO165'), 'REx - $\\beta=10.0$'),
    (('HO334', 'HO335', 'HO336', 'HO358', 'HO359', 'HO360', 'HO166', 'HO167', 'HO168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-150, agent_score_timesteps=1000000, mode='id')

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO325', 'HO326', 'HO327', 'HO349', 'HO350', 'HO351', 'HO157', 'HO158', 'HO159'), 'No REx'),
    (('HO328', 'HO329', 'HO330', 'HO352', 'HO353', 'HO354', 'HO160', 'HO161', 'HO162'), 'REx - $\\beta=5.0$'),
    (('HO331', 'HO332', 'HO333', 'HO355', 'HO356', 'HO357', 'HO163', 'HO164', 'HO165'), 'REx - $\\beta=10.0$'),
    (('HO334', 'HO335', 'HO336', 'HO358', 'HO359', 'HO360', 'HO166', 'HO167', 'HO168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-600, agent_score_timesteps=1000000, mode='all')

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO325', 'HO326', 'HO327', 'HO349', 'HO350', 'HO351', 'HO157', 'HO158', 'HO159'), 'No REx'),
    (('HO328', 'HO329', 'HO330', 'HO352', 'HO353', 'HO354', 'HO160', 'HO161', 'HO162'), 'REx - $\\beta=5.0$'),
    (('HO331', 'HO332', 'HO333', 'HO355', 'HO356', 'HO357', 'HO163', 'HO164', 'HO165'), 'REx - $\\beta=10.0$'),
    (('HO334', 'HO335', 'HO336', 'HO358', 'HO359', 'HO360', 'HO166', 'HO167', 'HO168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, agent_score_timesteps=1000000)

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO325', 'HO326', 'HO327', 'HO349', 'HO350', 'HO351', 'HO157', 'HO158', 'HO159'), 'No REx'),
    (('HO328', 'HO329', 'HO330', 'HO352', 'HO353', 'HO354', 'HO160', 'HO161', 'HO162'), 'REx - $\\beta=5.0$'),
    (('HO331', 'HO332', 'HO333', 'HO355', 'HO356', 'HO357', 'HO163', 'HO164', 'HO165'), 'REx - $\\beta=10.0$'),
    (('HO334', 'HO335', 'HO336', 'HO358', 'HO359', 'HO360', 'HO166', 'HO167', 'HO168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, agent_score_timesteps=1000000, mode='id')

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO325', 'HO326', 'HO327', 'HO349', 'HO350', 'HO351', 'HO157', 'HO158', 'HO159'), 'No REx'),
    (('HO328', 'HO329', 'HO330', 'HO352', 'HO353', 'HO354', 'HO160', 'HO161', 'HO162'), 'REx - $\\beta=5.0$'),
    (('HO331', 'HO332', 'HO333', 'HO355', 'HO356', 'HO357', 'HO163', 'HO164', 'HO165'), 'REx - $\\beta=10.0$'),
    (('HO334', 'HO335', 'HO336', 'HO358', 'HO359', 'HO360', 'HO166', 'HO167', 'HO168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, agent_score_timesteps=1000000, mode='all')

# %% [markdown]
# ## h=10

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO337', 'HO338', 'HO339', 'HO361', 'HO362', 'HO363', 'HO169', 'HO170', 'HO171'), 'No REx'),
    (('HO340', 'HO341', 'HO342', 'HO364', 'HO365', 'HO366', 'HO172', 'HO173', 'HO174'), 'REx - $\\beta=5.0$'),
    (('HO343', 'HO344', 'HO345', 'HO367', 'HO368', 'HO369', 'HO175', 'HO176', 'HO177'), 'REx - $\\beta=10.0$'),
    (('HO346', 'HO347', 'HO348', 'HO370', 'HO371', 'HO372', 'HO178', 'HO179', 'HO180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-2000, xmax=50, agent_score_timesteps=1000000)

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO337', 'HO338', 'HO339', 'HO361', 'HO362', 'HO363', 'HO169', 'HO170', 'HO171'), 'No REx'),
    (('HO340', 'HO341', 'HO342', 'HO364', 'HO365', 'HO366', 'HO172', 'HO173', 'HO174'), 'REx - $\\beta=5.0$'),
    (('HO343', 'HO344', 'HO345', 'HO367', 'HO368', 'HO369', 'HO175', 'HO176', 'HO177'), 'REx - $\\beta=10.0$'),
    (('HO346', 'HO347', 'HO348', 'HO370', 'HO371', 'HO372', 'HO178', 'HO179', 'HO180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-150, xmax=75, agent_score_timesteps=1000000, mode='id')

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO337', 'HO338', 'HO339', 'HO361', 'HO362', 'HO363', 'HO169', 'HO170', 'HO171'), 'No REx'),
    (('HO340', 'HO341', 'HO342', 'HO364', 'HO365', 'HO366', 'HO172', 'HO173', 'HO174'), 'REx - $\\beta=5.0$'),
    (('HO343', 'HO344', 'HO345', 'HO367', 'HO368', 'HO369', 'HO175', 'HO176', 'HO177'), 'REx - $\\beta=10.0$'),
    (('HO346', 'HO347', 'HO348', 'HO370', 'HO371', 'HO372', 'HO178', 'HO179', 'HO180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-2000, xmax=50, agent_score_timesteps=1000000, mode='all')

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO337', 'HO338', 'HO339', 'HO361', 'HO362', 'HO363', 'HO169', 'HO170', 'HO171'), 'No REx'),
    (('HO340', 'HO341', 'HO342', 'HO364', 'HO365', 'HO366', 'HO172', 'HO173', 'HO174'), 'REx - $\\beta=5.0$'),
    (('HO343', 'HO344', 'HO345', 'HO367', 'HO368', 'HO369', 'HO175', 'HO176', 'HO177'), 'REx - $\\beta=10.0$'),
    (('HO346', 'HO347', 'HO348', 'HO370', 'HO371', 'HO372', 'HO178', 'HO179', 'HO180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, agent_score_timesteps=1000000)

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO337', 'HO338', 'HO339', 'HO361', 'HO362', 'HO363', 'HO169', 'HO170', 'HO171'), 'No REx'),
    (('HO340', 'HO341', 'HO342', 'HO364', 'HO365', 'HO366', 'HO172', 'HO173', 'HO174'), 'REx - $\\beta=5.0$'),
    (('HO343', 'HO344', 'HO345', 'HO367', 'HO368', 'HO369', 'HO175', 'HO176', 'HO177'), 'REx - $\\beta=10.0$'),
    (('HO346', 'HO347', 'HO348', 'HO370', 'HO371', 'HO372', 'HO178', 'HO179', 'HO180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, agent_score_timesteps=1000000, mode='id')

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO337', 'HO338', 'HO339', 'HO361', 'HO362', 'HO363', 'HO169', 'HO170', 'HO171'), 'No REx'),
    (('HO340', 'HO341', 'HO342', 'HO364', 'HO365', 'HO366', 'HO172', 'HO173', 'HO174'), 'REx - $\\beta=5.0$'),
    (('HO343', 'HO344', 'HO345', 'HO367', 'HO368', 'HO369', 'HO175', 'HO176', 'HO177'), 'REx - $\\beta=10.0$'),
    (('HO346', 'HO347', 'HO348', 'HO370', 'HO371', 'HO372', 'HO178', 'HO179', 'HO180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, agent_score_timesteps=1000000, mode='all')

# %% [markdown]
# # MIXED-RT-1

# %% [markdown]
# ## h=5

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO037', 'HO038', 'HO039'), 'No REx'),
    (('HO040', 'HO041', 'HO042'), 'REx - $\\beta=5.0$'),
    (('HO043', 'HO044', 'HO045'), 'REx - $\\beta=10.0$'),
    (('HO046', 'HO047', 'HO048'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=1000000)

# %% [markdown]
# ## h=10

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO048', 'HO050', 'HO051'), 'No REx'),
    (('HO052', 'HO053', 'HO054'), 'REx - $\\beta=5.0$'),
    (('HO054', 'HO056', 'HO057'), 'REx - $\\beta=10.0$'),
    (('HO057', 'HO059', 'HO060'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=700000)

# %% [markdown]
# # MIXED-RT-3

# %% [markdown]
# ## h=5

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO061', 'HO062', 'HO063'), 'No REx'),
    (('HO064', 'HO065', 'HO066'), 'REx - $\\beta=5.0$'),
    (('HO067', 'HO068', 'HO069'), 'REx - $\\beta=10.0$'),
    (('HO070', 'HO071', 'HO072'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=1000000)

# %% [markdown]
# ## h=10

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO073', 'HO074', 'HO075'), 'No REx'),
    (('HO076', 'HO077', 'HO078'), 'REx - $\\beta=5.0$'),
    (('HO079', 'HO080', 'HO081'), 'REx - $\\beta=10.0$'),
    (('HO082', 'HO083', 'HO084'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=1000000)

# %% [markdown]
# # MIXED-RT-4

# %% [markdown]
# ## h=5

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO085', 'HO086', 'HO087'), 'No REx'),
    (('HO088', 'HO089', 'HO090'), 'REx - $\\beta=5.0$'),
    (('HO091', 'HO092', 'HO093'), 'REx - $\\beta=10.0$'),
    (('HO094', 'HO095', 'HO096'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=1000000)

# %% [markdown]
# ## h=10

# %%
plot_dynamics_score_vs_agent_return([
    # (('HO097', 'HO098', 'HO099'), 'No REx'),
    (('HO100', 'HO101', 'HO102'), 'REx - $\\beta=5.0$'),
    (('HO103', 'HO104', 'HO105'), 'REx - $\\beta=10.0$'),
    (('HO106', 'HO107', 'HO108'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=1000000)
