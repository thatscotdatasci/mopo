# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/home/ajc348/rds/hpc-work/mopo')

# %%
from itertools import zip_longest

import numpy as np
import matplotlib.pyplot as plt

from dogo.results import get_results, get_experiment_details
from dogo.plot_results import plot_experiment_metrics, plot_min_max_logvars, plot_evaluation_returns, plot_grouped_evaluation_returns, plot_min_max_penalty

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 5.0

# %%
HO745 = get_results("HO745") # No Rex
HO746 = get_results("HO746")
HO747 = get_results("HO747")
HO748 = get_results("HO748") # REx - 5.0
HO749 = get_results("HO749")
HO750 = get_results("HO750")
HO751 = get_results("HO751") # REx - 10.0
HO752 = get_results("HO752")
HO753 = get_results("HO753")
HO754 = get_results("HO754") # REx - 20.0
HO755 = get_results("HO755")
HO756 = get_results("HO756")

# %%
plot_evaluation_returns([
    HO745,
    HO746,
    HO747,
    HO748,
    HO749,
    HO750,
    HO751,
    HO752,
    HO753,
    HO754,
    HO755,
    HO756,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$')
# Out:
# HO745: 428.35235595703125
# HO746: 708.5936889648438
# HO747: 608.5065307617188
# HO748: 769.9600830078125
# HO749: 557.2164306640625
# HO750: 723.0136108398438
# HO751: 651.6837158203125
# HO752: 419.87261962890625
# HO753: 208.2593536376953
# HO754: 682.0991821289062
# HO755: 576.9964599609375
# HO756: 756.1677856445312

# %%
plot_grouped_evaluation_returns([
    ((HO745, HO746, HO747), 'No REx'),
    ((HO748, HO749, HO750), 'REx - $\\beta=5.0$'),
    ((HO751, HO752, HO753), 'REx - $\\beta=10.0$'),
    ((HO754, HO755, HO756), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$', max_timestep=1000000)
# Out:
# {'No REx': {'mean': 709, 'std': 0, 'count': 1, 'text': '709 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': 557, 'std': 0, 'count': 1, 'text': '557 ± 0'},
#  'REx - $\\beta=10.0$': {'mean': 208, 'std': 0, 'count': 1, 'text': '208 ± 0'},
#  'REx - $\\beta=20.0$': {'mean': 756, 'std': 0, 'count': 1, 'text': '756 ± 0'}}

# %% [markdown]
# # MOPO: 1.0 - Rollout-Length: 5.0

# %%
HO757 = get_results("HO757") # No Rex
HO758 = get_results("HO758")
HO759 = get_results("HO759")
HO760 = get_results("HO760") # REx - 5.0
HO761 = get_results("HO761")
HO762 = get_results("HO762")
HO763 = get_results("HO763") # REx - 10.0
HO764 = get_results("HO764")
HO765 = get_results("HO765")
HO766 = get_results("HO766") # REx - 20.0
HO767 = get_results("HO767")
HO768 = get_results("HO768")

# %%
plot_evaluation_returns([
    HO757,
    HO758,
    HO759,
    HO760,
    HO761,
    HO762,
    HO763,
    HO764,
    HO765,
    HO766,
    HO767,
    HO768,
], title='MOPO Hyperparameters: $\\lambda=1.0$, $h=5$')
# Out:
# HO757: 861.6458129882812
# HO758: 794.06689453125
# HO759: 742.9994506835938
# HO760: 1073.643798828125
# HO761: 684.9940795898438
# HO762: 873.3812255859375
# HO763: 488.51873779296875
# HO764: 655.7313232421875
# HO765: 950.0439453125
# HO766: 693.9217529296875
# HO767: 646.0452270507812
# HO768: 628.168212890625

# %%
plot_grouped_evaluation_returns([
    ((HO757, HO758, HO759), 'No REx'),
    ((HO760, HO761, HO762), 'REx - $\\beta=5.0$'),
    ((HO763, HO764, HO765), 'REx - $\\beta=10.0$'),
    ((HO766, HO767, HO768), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=1.0$, $h=5$', max_timestep=1000000)
# Out:
# {'No REx': {'mean': 862, 'std': 0, 'count': 1, 'text': '862 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': 685, 'std': 0, 'count': 1, 'text': '685 ± 0'},
#  'REx - $\\beta=10.0$': {'mean': 950, 'std': 0, 'count': 1, 'text': '950 ± 0'},
#  'REx - $\\beta=20.0$': {'mean': 694, 'std': 0, 'count': 1, 'text': '694 ± 0'}}

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 5.0

# %%
HO769 = get_results("HO769") # No Rex
HO770 = get_results("HO770")
HO771 = get_results("HO771")
HO772 = get_results("HO772") # REx - 5.0
HO773 = get_results("HO773")
HO774 = get_results("HO774")
HO775 = get_results("HO775") # REx - 10.0
HO776 = get_results("HO776")
HO777 = get_results("HO777")
HO778 = get_results("HO778") # REx - 20.0
HO779 = get_results("HO779")
HO780 = get_results("HO780")

# %%
plot_evaluation_returns([
    HO769,
    HO770,
    HO771,
    HO772,
    HO773,
    HO774,
    HO775,
    HO776,
    HO777,
    HO778,
    HO779,
    HO780,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$')
# Out:
# HO769: 625.2544555664062
# HO770: 551.8394775390625
# HO771: 768.4498901367188
# HO772: 722.1600952148438
# HO773: 427.955322265625
# HO774: 686.3694458007812
# HO775: 789.5656127929688
# HO776: 787.7999267578125
# HO777: 698.6727905273438
# HO778: 546.0333862304688
# HO779: 546.2574462890625
# HO780: 781.588623046875

# %%
plot_grouped_evaluation_returns([
    ((HO769, HO770, HO771), 'No REx'),
    ((HO772, HO773, HO774), 'REx - $\\beta=5.0$'),
    ((HO775, HO776, HO777), 'REx - $\\beta=10.0$'),
    ((HO778, HO779, HO780), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$', max_timestep=1000000)
# Out:
# {'No REx': {'mean': 768, 'std': 0, 'count': 1, 'text': '768 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': 722, 'std': 0, 'count': 1, 'text': '722 ± 0'},
#  'REx - $\\beta=10.0$': {'mean': 790, 'std': 0, 'count': 1, 'text': '790 ± 0'},
#  'REx - $\\beta=20.0$': {'mean': 546, 'std': 0, 'count': 1, 'text': '546 ± 0'}}

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 10.0

# %%
HO781 = get_results("HO781") # No Rex
HO782 = get_results("HO782")
HO783 = get_results("HO783")
HO784 = get_results("HO784") # REx - 5.0
HO785 = get_results("HO785")
HO786 = get_results("HO786")
HO787 = get_results("HO787") # REx - 10.0
HO788 = get_results("HO788")
HO789 = get_results("HO789")
HO790 = get_results("HO790") # REx - 20.0
HO791 = get_results("HO791")
HO792 = get_results("HO792")

# %%
plot_evaluation_returns([
    HO781,
    HO782,
    HO783,
    HO784,
    HO785,
    HO786,
    HO787,
    HO788,
    HO789,
    HO790,
    HO791,
    HO792,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$')
# Out:
# HO781: 765.1090087890625
# HO782: 656.0234985351562
# HO783: 851.5113525390625
# HO784: 754.7452392578125
# HO785: 737.2686767578125
# HO786: 807.6029052734375
# HO787: 886.6580200195312
# HO788: 809.7922973632812
# HO789: 768.7713012695312
# HO790: 830.7591552734375
# HO791: 721.4447021484375
# HO792: 1208.208740234375

# %%
plot_grouped_evaluation_returns([
    ((HO781, HO782, HO783), 'No REx'),
    ((HO784, HO785, HO786), 'REx - $\\beta=5.0$'),
    ((HO787, HO788, HO789), 'REx - $\\beta=10.0$'),
    ((HO790, HO791, HO792), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$', max_timestep=1000000)
# Out:
# {'No REx': {'mean': 656, 'std': 0, 'count': 1, 'text': '656 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': 737, 'std': 0, 'count': 1, 'text': '737 ± 0'},
#  'REx - $\\beta=10.0$': {'mean': 810, 'std': 0, 'count': 1, 'text': '810 ± 0'},
#  'REx - $\\beta=20.0$': {'mean': 776,
#   'std': 55,
#   'count': 2,
#   'text': '776 ± 55'}}

# %% [markdown]
# # MOPO: 1.0 - Rollout-Length: 10.0

# %%
HO793 = get_results("HO793") # No Rex
HO794 = get_results("HO794")
HO795 = get_results("HO795")
HO796 = get_results("HO796") # REx - 5.0
HO797 = get_results("HO797")
HO798 = get_results("HO798")
HO799 = get_results("HO799") # REx - 10.0
HO800 = get_results("HO800")
HO801 = get_results("HO801")
HO802 = get_results("HO802") # REx - 20.0
HO803 = get_results("HO803")
HO804 = get_results("HO804")

# %%
plot_evaluation_returns([
    HO793,
    HO794,
    HO795,
    HO796,
    HO797,
    HO798,
    HO799,
    HO800,
    HO801,
    HO802,
    HO803,
    HO804,
], title='MOPO Hyperparameters: $\\lambda=1.0$, $h=10$')
# Out:
# HO793: 852.0380859375
# HO794: 718.9588012695312
# HO795: 755.5358276367188
# HO796: 904.9959106445312
# HO797: 774.3578491210938
# HO798: 1099.771484375
# HO799: 2090.2431640625
# HO800: 675.451904296875
# HO801: 1126.5570068359375
# HO802: 656.8165893554688
# HO803: 760.6271362304688
# HO804: 1022.6901245117188

# %%
plot_grouped_evaluation_returns([
    ((HO793, HO794, HO795), 'No REx'),
    ((HO796, HO797, HO798), 'REx - $\\beta=5.0$'),
    ((HO799, HO800, HO801), 'REx - $\\beta=10.0$'),
    ((HO802, HO803, HO804), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=1.0$, $h=10$', max_timestep=1000000)
# Out:
# {'No REx': {'mean': 719, 'std': 0, 'count': 1, 'text': '719 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': 774, 'std': 0, 'count': 1, 'text': '774 ± 0'},
#  'REx - $\\beta=10.0$': {'mean': 675, 'std': 0, 'count': 1, 'text': '675 ± 0'},
#  'REx - $\\beta=20.0$': {'mean': 1023,
#   'std': 0,
#   'count': 1,
#   'text': '1023 ± 0'}}

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 10.0

# %%
HO805 = get_results("HO805") # No Rex
HO806 = get_results("HO806")
HO807 = get_results("HO807")
HO808 = get_results("HO808") # REx - 5.0
HO809 = get_results("HO809")
HO810 = get_results("HO810")
HO811 = get_results("HO811") # REx - 10.0
HO812 = get_results("HO812")
HO813 = get_results("HO813")
HO814 = get_results("HO814") # REx - 20.0
HO815 = get_results("HO815")
HO816 = get_results("HO816")

# %%
plot_evaluation_returns([
    HO805,
    HO806,
    HO807,
    HO808,
    HO809,
    HO810,
    HO811,
    HO812,
    HO813,
    HO814,
    HO815,
    HO816,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$')
# Out:
# HO805: 2104.27490234375
# HO806: 1297.5416259765625
# HO807: 795.8410034179688
# HO808: 805.4735107421875
# HO809: 803.5699462890625
# HO810: 1622.4385986328125
# HO811: 1030.235107421875
# HO812: 825.1692504882812
# HO813: 1407.2252197265625
# HO814: 759.323486328125
# HO815: 802.3335571289062
# HO816: 1994.377197265625

# %%
plot_grouped_evaluation_returns([
    ((HO805, HO806, HO807), 'No REx'),
    ((HO808, HO809, HO810), 'REx - $\\beta=5.0$'),
    ((HO811, HO812, HO813), 'REx - $\\beta=10.0$'),
    ((HO814, HO815, HO816), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', max_timestep=1000000)
# Out:
# {'No REx': {'mean': 1298, 'std': 0, 'count': 1, 'text': '1298 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': 804, 'std': 0, 'count': 1, 'text': '804 ± 0'},
#  'REx - $\\beta=10.0$': {'mean': 825, 'std': 0, 'count': 1, 'text': '825 ± 0'},
#  'REx - $\\beta=20.0$': {'mean': 802, 'std': 0, 'count': 1, 'text': '802 ± 0'}}
