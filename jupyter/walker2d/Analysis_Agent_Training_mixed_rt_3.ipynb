# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
from itertools import zip_longest

import numpy as np
import matplotlib.pyplot as plt

from dogo.results import get_results, get_experiment_details
from dogo.plot_results import plot_experiment_metrics, plot_min_max_logvars, plot_evaluation_returns, plot_grouped_evaluation_returns, plot_min_max_penalty

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
#######################################
# MOPO - Penalty 0.0 - Rollout Length 5
#######################################

WA061 = get_results("WA061") # No Rex
WA062 = get_results("WA062")
WA063 = get_results("WA063")
WA064 = get_results("WA064") # REx - 5.0
WA065 = get_results("WA065")
WA066 = get_results("WA066")
WA067 = get_results("WA067") # REx - 10.0
WA068 = get_results("WA068")
WA069 = get_results("WA069")
WA070 = get_results("WA070") # REx - 20.0
WA071 = get_results("WA071")
WA072 = get_results("WA072")

# %%
########################################
# MOPO - Penalty 0.0 - Rollout Length 10
########################################

WA073 = get_results("WA073") # No Rex
WA074 = get_results("WA074")
WA075 = get_results("WA075")
WA076 = get_results("WA076") # REx - 5.0
WA077 = get_results("WA077")
WA078 = get_results("WA078")
WA079 = get_results("WA079") # REx - 10.0
WA080 = get_results("WA080")
WA081 = get_results("WA081")
WA082 = get_results("WA082") # REx - 20.0
WA083 = get_results("WA083")
WA084 = get_results("WA084")

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 5.0

# %%
plot_evaluation_returns([
    WA061,
    WA062,
    WA063,
    WA064,
    WA065,
    WA066,
    WA067,
    WA068,
    WA069,
    WA070,
    WA071,
    WA072,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$')
# Out:
# WA061: 163.7151641845703
# WA062: 549.8892822265625
# WA063: 465.56689453125
# WA064: 341.70574951171875
# WA065: 262.90057373046875
# WA066: 277.28509521484375
# WA067: 363.5375671386719
# WA068: 438.21246337890625
# WA069: 492.40087890625
# WA070: 424.6593322753906
# WA071: 215.50765991210938
# WA072: 641.0792236328125

# %%
plot_grouped_evaluation_returns([
    ((WA061, WA062, WA063), 'No REx'),
    ((WA064, WA065, WA066), 'REx - $\\beta=5.0$'),
    ((WA067, WA068, WA069), 'REx - $\\beta=10.0$'),
    ((WA070, WA071, WA072), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$', max_timestep=650000)
# Out:
# {'No REx': {'mean': 393, 'std': 133, 'count': 3, 'text': '393 ± 133'},
#  'REx - $\\beta=5.0$': {'mean': 215,
#   'std': 122,
#   'count': 3,
#   'text': '215 ± 122'},
#  'REx - $\\beta=10.0$': {'mean': 427,
#   'std': 11,
#   'count': 3,
#   'text': '427 ± 11'},
#  'REx - $\\beta=20.0$': {'mean': 362,
#   'std': 218,
#   'count': 3,
#   'text': '362 ± 218'}}

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 10.0

# %%
plot_evaluation_returns([
    WA073,
    WA074,
    WA075,
    WA076,
    WA077,
    WA078,
    WA079,
    WA080,
    WA081,
    WA082,
    WA083,
    WA084,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$')
# Out:
# WA073: 286.4304504394531
# WA074: 356.94342041015625
# WA075: 449.31719970703125
# WA076: 237.1465301513672
# WA077: 274.01971435546875
# WA078: 730.1150512695312
# WA079: 471.37554931640625
# WA080: 566.8961791992188
# WA081: 565.7686767578125
# WA082: 317.1780700683594
# WA083: 292.8734130859375
# WA084: 729.510498046875

# %%
plot_grouped_evaluation_returns([
    ((WA073, WA074, WA075), 'No REx'),
    ((WA076, WA077, WA078), 'REx - $\\beta=5.0$'),
    ((WA079, WA080, WA081), 'REx - $\\beta=10.0$'),
    ((WA082, WA083, WA084), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$', max_timestep=650000)
# Out:
# {'No REx': {'mean': 425, 'std': 170, 'count': 3, 'text': '425 ± 170'},
#  'REx - $\\beta=5.0$': {'mean': 260,
#   'std': 31,
#   'count': 3,
#   'text': '260 ± 31'},
#  'REx - $\\beta=10.0$': {'mean': 498,
#   'std': 141,
#   'count': 3,
#   'text': '498 ± 141'},
#  'REx - $\\beta=20.0$': {'mean': 368,
#   'std': 45,
#   'count': 3,
#   'text': '368 ± 45'}}

# %% [markdown]
# # RAND-1

# %%
#######################################
# MOPO - Penalty 0.0 - Rollout Length 5
#######################################

WA121 = get_results("WA121") # No Rex
WA122 = get_results("WA122")
WA123 = get_results("WA123")
WA124 = get_results("WA124") # REx - 5.0
WA125 = get_results("WA125")
WA126 = get_results("WA126")
WA127 = get_results("WA127") # REx - 10.0
WA128 = get_results("WA128")
WA129 = get_results("WA129")
WA130 = get_results("WA130") # REx - 20.0
WA131 = get_results("WA131")
WA132 = get_results("WA132")

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 5.0

# %%
plot_evaluation_returns([
    WA121,
    WA122,
    WA123,
    WA124,
    WA125,
    WA126,
    WA127,
    WA128,
    WA129,
    WA130,
    WA131,
    WA132,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$')
# Out:
# WA121: -1.233866453170776
# WA122: 234.6370391845703
# WA123: 764.3331298828125
# WA124: 66.50078582763672
# WA125: 2.359983205795288
# WA126: 173.3975372314453
# WA127: 13.36015510559082
# WA128: 94.69001770019531
# WA129: -4.326189041137695
# WA130: -8.194137573242188
# WA131: 97.73748016357422
# WA132: 14.062141418457031

# %%
plot_grouped_evaluation_returns([
    ((WA121, WA122, WA123), 'No REx'),
    ((WA124, WA125, WA126), 'REx - $\\beta=5.0$'),
    ((WA127, WA128, WA129), 'REx - $\\beta=10.0$'),
    ((WA130, WA131, WA132), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$', max_timestep=1000000)
# Out:
# {'No REx': {'mean': 97, 'std': 105, 'count': 3, 'text': '97 ± 105'},
#  'REx - $\\beta=5.0$': {'mean': -3, 'std': 4, 'count': 3, 'text': '-3 ± 4'},
#  'REx - $\\beta=10.0$': {'mean': 319,
#   'std': 455,
#   'count': 3,
#   'text': '319 ± 455'},
#  'REx - $\\beta=20.0$': {'mean': 21, 'std': 45, 'count': 3, 'text': '21 ± 45'}}
