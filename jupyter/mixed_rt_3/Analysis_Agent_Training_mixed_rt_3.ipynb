# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
from itertools import zip_longest

import numpy as np
import matplotlib.pyplot as plt

from dogo.results import get_results, get_experiment_details
from dogo.plot_results import plot_experiment_metrics, plot_min_max_logvars, plot_evaluation_returns, plot_grouped_evaluation_returns, plot_min_max_penalty

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
#######################################
# MOPO - Penalty 0.0 - Rollout Length 5
#######################################

HC073 = get_results("HC073") # No Rex
HC074 = get_results("HC074")
HC075 = get_results("HC075")
HC076 = get_results("HC076") # REx - 5.0
HC077 = get_results("HC077")
HC078 = get_results("HC078")
HC079 = get_results("HC079") # REx - 10.0
HC080 = get_results("HC080")
HC081 = get_results("HC081")
HC082 = get_results("HC082") # REx - 20.0
HC083 = get_results("HC083")
HC084 = get_results("HC084")

# %%
########################################
# MOPO - Penalty 0.0 - Rollout Length 10
########################################

HC085 = get_results("HC085") # No Rex
HC086 = get_results("HC086")
HC087 = get_results("HC087")
HC088 = get_results("HC088") # REx - 5.0
HC089 = get_results("HC089")
HC090 = get_results("HC090")
HC091 = get_results("HC091") # REx - 10.0
HC092 = get_results("HC092")
HC093 = get_results("HC093")
HC094 = get_results("HC094") # REx - 20.0
HC095 = get_results("HC095")
HC096 = get_results("HC096")

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 5.0

# %%
plot_evaluation_returns([
    HC073,
    HC074,
    HC075,
    HC076,
    HC077,
    HC078,
    HC079,
    HC080,
    HC081,
    HC082,
    HC083,
    HC084,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$')
# Out:
# HC073: 6414.978515625
# HC074: 8066.9951171875
# HC075: 7555.35546875
# HC076: 7035.23583984375
# HC077: 6478.05126953125
# HC078: 6158.5361328125
# HC079: 6727.09912109375
# HC080: 7530.70166015625
# HC081: 7763.6455078125
# HC082: 7006.68603515625
# HC083: 7657.703125
# HC084: 6253.3203125

# %%
plot_grouped_evaluation_returns([
    ((HC073, HC074, HC075), 'No REx'),
    ((HC076, HC077, HC078), 'REx - $\\beta=5.0$'),
    ((HC079, HC080, HC081), 'REx - $\\beta=10.0$'),
    ((HC082, HC083, HC084), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$')
# Out:
# {'No REx': {'mean': 7346, 'std': 691, 'count': 3, 'text': '7346 ± 691'},
#  'REx - $\\beta=5.0$': {'mean': 6557,
#   'std': 362,
#   'count': 3,
#   'text': '6557 ± 362'},
#  'REx - $\\beta=10.0$': {'mean': 7340,
#   'std': 444,
#   'count': 3,
#   'text': '7340 ± 444'},
#  'REx - $\\beta=20.0$': {'mean': 6973,
#   'std': 574,
#   'count': 3,
#   'text': '6973 ± 574'}}

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 10.0

# %%
plot_evaluation_returns([
    HC085,
    HC086,
    HC087,
    HC088,
    HC089,
    HC090,
    HC091,
    HC092,
    HC093,
    HC094,
    HC095,
    HC096,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$')
# Out:
# HC085: -283.9916687011719
# HC086: 91.44083404541016
# HC087: -236.540771484375
# HC088: 5979.00244140625
# HC089: -90.91165161132812
# HC090: 7836.14990234375
# HC091: 5615.43896484375
# HC092: 7178.2900390625
# HC093: 8058.60400390625
# HC094: 5504.23046875
# HC095: 7637.8671875
# HC096: 7457.5654296875

# %%
plot_grouped_evaluation_returns([
    ((HC085, HC086, HC087), 'No REx'),
    ((HC088, HC089, HC090), 'REx - $\\beta=5.0$'),
    ((HC091, HC092, HC093), 'REx - $\\beta=10.0$'),
    ((HC094, HC095, HC096), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=10$')
# Out:
# {'No REx': {'mean': -260, 'std': 24, 'count': 2, 'text': '-260 ± 24'},
#  'REx - $\\beta=5.0$': {'mean': 4575,
#   'std': 3385,
#   'count': 3,
#   'text': '4575 ± 3385'},
#  'REx - $\\beta=10.0$': {'mean': 6951,
#   'std': 1010,
#   'count': 3,
#   'text': '6951 ± 1010'},
#  'REx - $\\beta=20.0$': {'mean': 6867,
#   'std': 966,
#   'count': 3,
#   'text': '6867 ± 966'}}

# %% [markdown]
# # RAND-1

# %%
#######################################
# MOPO - Penalty 0.0 - Rollout Length 5
#######################################

HC127 = get_results("HC127") # No Rex
HC128 = get_results("HC128")
HC129 = get_results("HC129")
HC130 = get_results("HC130") # REx - 5.0
HC131 = get_results("HC131")
HC132 = get_results("HC132")
HC133 = get_results("HC133") # REx - 10.0
HC134 = get_results("HC134")
HC135 = get_results("HC135")
HC136 = get_results("HC136") # REx - 20.0
HC137 = get_results("HC137")
HC138 = get_results("HC138")

# %% [markdown]
# # MOPO: 0.0 - Rollout-Length: 5.0

# %%
plot_evaluation_returns([
    HC127,
    HC128,
    HC129,
    HC130,
    HC131,
    HC132,
    HC133,
    HC134,
    HC135,
    HC136,
    HC137,
    HC138,
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$')
# Out:
# HC127: -452.4208984375
# HC128: -526.2803344726562
# HC129: -548.5006103515625
# HC130: -330.93359375
# HC131: -202.6939239501953
# HC132: -402.78338623046875
# HC133: -363.178955078125
# HC134: -466.805908203125
# HC135: -1974.435546875
# HC136: -430.9921875
# HC137: -2486.405029296875
# HC138: -1979.801513671875

# %%
plot_grouped_evaluation_returns([
    ((HC127, HC128, HC129), 'No REx'),
    ((HC130, HC131, HC132), 'REx - $\\beta=5.0$'),
    ((HC133, HC134, HC135), 'REx - $\\beta=10.0$'),
    ((HC136, HC137, HC138), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=0.0$, $h=5$')
# Out:
# {'No REx': {'mean': -452, 'std': 0, 'count': 1, 'text': '-452 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': -312,
#   'std': 83,
#   'count': 3,
#   'text': '-312 ± 83'},
#  'REx - $\\beta=10.0$': {'mean': -935,
#   'std': 736,
#   'count': 3,
#   'text': '-935 ± 736'},
#  'REx - $\\beta=20.0$': {'mean': -1632,
#   'std': 874,
#   'count': 3,
#   'text': '-1632 ± 874'}}
