# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dogo.results import get_results, get_experiment_details, average_scores_over_seeds

# %%
plt.rc('font', size=12)

# %%
##############################
# SAC Model Training - MIXED 2
##############################
# No REx
MP301 = get_results("MP301")
MP302 = get_results("MP302")
MP303 = get_results("MP303")

# REx - 0.1
MP304 = get_results("MP304")
MP305 = get_results("MP305")
MP306 = get_results("MP306")

# REx - 1.0
MP307 = get_results("MP307")
MP308 = get_results("MP308")
MP309 = get_results("MP309")

# REx - 5.0
MP720 = get_results("MP720")
MP721 = get_results("MP721")
MP722 = get_results("MP722")

# REx - 10.0
MP310 = get_results("MP310")
MP311 = get_results("MP311")
MP312 = get_results("MP312")

# %%
##############################
# SAC Model Training - MIXED 1
##############################
# No REx
MP313 = get_results("MP313")
MP314 = get_results("MP314")
MP315 = get_results("MP315")

# REx - 0.1
MP316 = get_results("MP316")
MP317 = get_results("MP317")
MP318 = get_results("MP318")

# REx - 1.0
MP319 = get_results("MP319")
MP320 = get_results("MP320")
MP321 = get_results("MP321")

# REx - 10.0
MP322 = get_results("MP322")
MP323 = get_results("MP323")
MP324 = get_results("MP324")

# REx - 10.0
MP322 = get_results("MP322")
MP323 = get_results("MP323")
MP324 = get_results("MP324")

# %% [markdown]
# ## MIXED-2

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'evaluation/return-average'
for exp, rex, beta in [
    (MP301, False, 0.0),
    (MP302, False, 0.0),
    (MP303, False, 0.0),
    (MP304, True, 0.1),
    (MP305, True, 0.1),
    (MP306, True, 0.1),
    (MP307, True, 1.0),
    (MP308, True, 1.0),
    (MP309, True, 1.0),
    (MP720, True, 5.0),
    (MP721, True, 5.0),
    (MP722, True, 5.0),
    (MP310, True, 10.0),
    (MP311, True, 10.0),
    (MP312, True, 10.0),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], ls='-' if rex else '--', label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'evaluation/return-average'
for exp, rex, beta in [
    (MP301, False, 0.0),
    (MP302, False, 0.0),
    (MP303, False, 0.0),
    # (MP304, True, 0.1),
    # (MP305, True, 0.1),
    # (MP306, True, 0.1),
    # (MP307, True, 1.0),
    # (MP308, True, 1.0),
    # (MP309, True, 1.0),
    (MP720, True, 5.0),
    (MP721, True, 5.0),
    (MP722, True, 5.0),
    (MP310, True, 10.0),
    (MP311, True, 10.0),
    (MP312, True, 10.0),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], ls='-' if rex else '--', label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %% [markdown]
# ## MIXED-1

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'evaluation/return-average'
for exp, rex, beta in [
    (MP313, False, 0.0),
    (MP314, False, 0.0),
    (MP315, False, 0.0),
    (MP316, True, 0.1),
    (MP317, True, 0.1),
    (MP318, True, 0.1),
    (MP319, True, 1.0),
    (MP320, True, 1.0),
    (MP321, True, 1.0),
    (MP322, True, 10.0),
    (MP323, True, 10.0),
    (MP324, True, 10.0),
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], ls='-' if rex else '--', label=f'{exp.name} - {exp.dataset} - REx: {rex} - Beta: {beta} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass
