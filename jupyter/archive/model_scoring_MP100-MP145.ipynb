# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dogo.results import get_scores_df

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
evaluation_datasets = [
    "D3RLPY-MP1",
    "D3RLPY-MP1_100000",
    "D3RLPY-MP1-P0-3",
    "D3RLPY-MP1-P1-4",
    "D3RLPY-MP1-P0_25000",
    "D3RLPY-MP1-P1_25000",
    "D3RLPY-MP1-P2_25000",
    "D3RLPY-MP1-P3_25000",
    "D3RLPY-MP1-P4_25000",
    "D3RLPY-MP1-P0_100000",
    "D3RLPY-MP1-P1_100000",
    "D3RLPY-MP1-P2_100000",
    "D3RLPY-MP1-P3_100000",
    "D3RLPY-MP1-P4_100000",
    "D3RLPY-MP2-P0_100000",
    "D3RLPY-MP2-P1_100000",
    "D3RLPY-MP2-P2_100000",
    "D3RLPY-MP2-P3_100000",
    "D3RLPY-MP2-P4_100000",
    "D3RLPY-MP3-P0_100000",
    "D3RLPY-MP3-P1_100000",
    "D3RLPY-MP3-P2_100000",
    "D3RLPY-MP3-P3_100000",
    "D3RLPY-MP3-P4_100000",
    "D3RLPY-PAP5",
    "D3RLPY-PAP5_100000",
    "D3RLPY-PAP5-P0-3",
    "D3RLPY-PAP5-P1-4",
    "D3RLPY-PAP5-P0_25000",
    "D3RLPY-PAP5-P1_25000",
    "D3RLPY-PAP5-P2_25000",
    "D3RLPY-PAP5-P3_25000",
    "D3RLPY-PAP5-P4_25000",
    "D3RLPY-PAP5-P0_100000",
    "D3RLPY-PAP5-P1_100000",
    "D3RLPY-PAP5-P2_100000",
    "D3RLPY-PAP5-P3_100000",
    "D3RLPY-PAP5-P4_100000",
    "D3RLPY-PAP6-P0_100000",
    "D3RLPY-PAP6-P1_100000",
    "D3RLPY-PAP6-P2_100000",
    "D3RLPY-PAP6-P3_100000",
    "D3RLPY-PAP6-P4_100000",
    "D3RLPY-PAP7-P0_100000",
    "D3RLPY-PAP7-P1_100000",
    "D3RLPY-PAP7-P2_100000",
    "D3RLPY-PAP7-P3_100000",
    "D3RLPY-PAP7-P4_100000",
    "RAND-1",
    "RAND-2",
    "RAND-3",
    "RAND-4",
    "RAND-5",
    "RAND-6",
    "RAND-7",
    "RAND-8",
    "RAND-9",
    "RAND-10",
    "RAND-D3RLPY-MP1-P0-1",
    "RAND-D3RLPY-MP1-P1-1",
    "RAND-D3RLPY-MP1-P2-1",
    "RAND-D3RLPY-MP1-P3-1",
    "RAND-D3RLPY-MP1-P4-1",
    "RAND-D3RLPY-PAP5-P0-1",
    "RAND-D3RLPY-PAP5-P1-1",
    "RAND-D3RLPY-PAP5-P2-1",
    "RAND-D3RLPY-PAP5-P3-1",
    "RAND-D3RLPY-PAP5-P4-1",
    # "NOISE-D3RLPY-MP1-P0-1",
    # "NOISE-D3RLPY-MP1-P1-1",
    # "NOISE-D3RLPY-MP1-P2-1",
    # "NOISE-D3RLPY-MP1-P3-1",
    # "NOISE-D3RLPY-MP1-P4-1",
    # "NOISE-D3RLPY-PAP5-P0-1",
    # "NOISE-D3RLPY-PAP5-P1-1",
    # "NOISE-D3RLPY-PAP5-P2-1",
    # "NOISE-D3RLPY-PAP5-P3-1",
    # "NOISE-D3RLPY-PAP5-P4-1",
]

d3rlpy_pap5_p0_3_training_datasets = [
    "D3RLPY-PAP5-P0_25000",
    "D3RLPY-PAP5-P1_25000",
    "D3RLPY-PAP5-P2_25000",
    "D3RLPY-PAP5-P3_25000",
]

d3rlpy_pap5_p1_4_training_datasets = [
    "D3RLPY-PAP5-P1_25000",
    "D3RLPY-PAP5-P2_25000",
    "D3RLPY-PAP5-P3_25000",
    "D3RLPY-PAP5-P4_25000",
]

d3rlpy_mp1_p0_3_training_datasets = [
    "D3RLPY-MP1-P0_25000",
    "D3RLPY-MP1-P1_25000",
    "D3RLPY-MP1-P2_25000",
    "D3RLPY-MP1-P3_25000",
]

d3rlpy_mp1_p1_4_training_datasets = [
    "D3RLPY-MP1-P1_25000",
    "D3RLPY-MP1-P2_25000",
    "D3RLPY-MP1-P3_25000",
    "D3RLPY-MP1-P4_25000",
]

experiments_pap5_p0_3_no_rex = ['MP134', 'MP135', 'MP136']
experiments_pap5_p0_3 = ['MP101', 'MP105', 'MP109']

experiments_pap5_p1_4_no_rex = ['MP137', 'MP138', 'MP139']
experiments_pap5_p1_4 = ['MP103', 'MP107', 'MP111']

experiments_mp1_p0_3_no_rex = ['MP140', 'MP141', 'MP142']
experiments_mp1_p0_3 = ['MP113', 'MP117', 'MP121']

experiments_mp1_p1_4_no_rex = ['MP143', 'MP144', 'MP145']
experiments_mp1_p1_4 = ['MP115', 'MP119', 'MP123']

# %%
experiments_pap5_p0_3_no_rex_df = get_scores_df(experiments_pap5_p0_3_no_rex, evaluation_datasets)
experiments_pap5_p0_3_df = get_scores_df(experiments_pap5_p0_3, evaluation_datasets)

experiments_pap5_p1_4_no_rex_df = get_scores_df(experiments_pap5_p1_4_no_rex, evaluation_datasets)
experiments_pap5_p1_4_df = get_scores_df(experiments_pap5_p1_4, evaluation_datasets)

experiments_mp1_p0_3_no_rex_df = get_scores_df(experiments_mp1_p0_3_no_rex, evaluation_datasets)
experiments_mp1_p0_3_df = get_scores_df(experiments_mp1_p0_3, evaluation_datasets)

experiments_mp1_p1_4_no_rex_df = get_scores_df(experiments_mp1_p1_4_no_rex, evaluation_datasets)
experiments_mp1_p1_4_df = get_scores_df(experiments_mp1_p1_4, evaluation_datasets)

# %%
experiments_pap5_p0_3_no_rex_groups = (
    experiments_pap5_p0_3_no_rex_df.groupby(['training_dataset', 'rex', 'rex_beta', 'evaluation_dataset'])
)
experiments_pap5_p0_3_no_rex_avgs_df = experiments_pap5_p0_3_no_rex_groups.mean().reset_index()
experiments_pap5_p0_3_no_rex_mins_df = experiments_pap5_p0_3_no_rex_groups.min().reset_index()
experiments_pap5_p0_3_no_rex_maxs_df = experiments_pap5_p0_3_no_rex_groups.max().reset_index()

experiments_pap5_p0_3_groups = (
    experiments_pap5_p0_3_df.groupby(['training_dataset', 'rex', 'rex_beta', 'evaluation_dataset'])
)
experiments_pap5_p0_3_avgs_df = experiments_pap5_p0_3_groups.mean().reset_index()
experiments_pap5_p0_3_mins_df = experiments_pap5_p0_3_groups.min().reset_index()
experiments_pap5_p0_3_maxs_df = experiments_pap5_p0_3_groups.max().reset_index()

experiments_pap5_p1_4_no_rex_groups = (
    experiments_pap5_p1_4_no_rex_df.groupby(['training_dataset', 'rex', 'rex_beta', 'evaluation_dataset'])
)
experiments_pap5_p1_4_no_rex_avgs_df = experiments_pap5_p1_4_no_rex_groups.mean().reset_index()
experiments_pap5_p1_4_no_rex_mins_df = experiments_pap5_p1_4_no_rex_groups.min().reset_index()
experiments_pap5_p1_4_no_rex_maxs_df = experiments_pap5_p1_4_no_rex_groups.max().reset_index()

experiments_pap5_p1_4_groups = (
    experiments_pap5_p1_4_df.groupby(['training_dataset', 'rex', 'rex_beta', 'evaluation_dataset'])
)
experiments_pap5_p1_4_avgs_df = experiments_pap5_p1_4_groups.mean().reset_index()
experiments_pap5_p1_4_mins_df = experiments_pap5_p1_4_groups.min().reset_index()
experiments_pap5_p1_4_maxs_df = experiments_pap5_p1_4_groups.max().reset_index()

experiments_mp1_p0_3_no_rex_groups = (
    experiments_mp1_p0_3_no_rex_df.groupby(['training_dataset', 'rex', 'rex_beta', 'evaluation_dataset'])
)
experiments_mp1_p0_3_no_rex_avgs_df = experiments_mp1_p0_3_no_rex_groups.mean().reset_index()
experiments_mp1_p0_3_no_rex_mins_df = experiments_mp1_p0_3_no_rex_groups.min().reset_index()
experiments_mp1_p0_3_no_rex_maxs_df = experiments_mp1_p0_3_no_rex_groups.max().reset_index()

experiments_mp1_p0_3_groups = (
    experiments_mp1_p0_3_df.groupby(['training_dataset', 'rex', 'rex_beta', 'evaluation_dataset'])
)
experiments_mp1_p0_3_avgs_df = experiments_mp1_p0_3_groups.mean().reset_index()
experiments_mp1_p0_3_mins_df = experiments_mp1_p0_3_groups.min().reset_index()
experiments_mp1_p0_3_maxs_df = experiments_mp1_p0_3_groups.max().reset_index()

experiments_mp1_p1_4_no_rex_groups = (
    experiments_mp1_p1_4_no_rex_df.groupby(['training_dataset', 'rex', 'rex_beta', 'evaluation_dataset'])
)
experiments_mp1_p1_4_no_rex_avgs_df = experiments_mp1_p1_4_no_rex_groups.mean().reset_index()
experiments_mp1_p1_4_no_rex_mins_df = experiments_mp1_p1_4_no_rex_groups.min().reset_index()
experiments_mp1_p1_4_no_rex_maxs_df = experiments_mp1_p1_4_no_rex_groups.max().reset_index()

experiments_mp1_p1_4_groups = (
    experiments_mp1_p1_4_df.groupby(['training_dataset', 'rex', 'rex_beta', 'evaluation_dataset'])
)
experiments_mp1_p1_4_avgs_df = experiments_mp1_p1_4_groups.mean().reset_index()
experiments_mp1_p1_4_mins_df = experiments_mp1_p1_4_groups.min().reset_index()
experiments_mp1_p1_4_maxs_df = experiments_mp1_p1_4_groups.max().reset_index()

# %% [markdown]
# # PAP5

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 10))

lss =  ['-', '--']
labels = ['D3RLPY-PAP5-P0-3 - No REx', 'D3RLPY-PAP5-P0-3 - Beta 10.0', 'D3RLPY-PAP5-P1-4 - No REx', 'D3RLPY-PAP5-P1-4 - Beta 10.0']

metric = 'overall_mse'
for i, (exp_avgs, exp_mins, exp_maxs) in enumerate([
    (experiments_pap5_p0_3_no_rex_avgs_df, experiments_pap5_p0_3_no_rex_mins_df, experiments_pap5_p0_3_no_rex_maxs_df),
    (experiments_pap5_p0_3_avgs_df, experiments_pap5_p0_3_mins_df, experiments_pap5_p0_3_maxs_df),
    (experiments_pap5_p1_4_no_rex_avgs_df, experiments_pap5_p1_4_no_rex_mins_df, experiments_pap5_p1_4_no_rex_maxs_df),
    (experiments_pap5_p1_4_avgs_df, experiments_pap5_p1_4_mins_df, experiments_pap5_p1_4_maxs_df),
]):
    plot_avgs = exp_avgs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_mins = exp_mins.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_maxs = exp_maxs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    ax.plot(evaluation_datasets, plot_avgs, label=labels[i], c=cols[i], ls='--' if 'Beta' in labels[i] else '-')
    ax.fill_between(evaluation_datasets, plot_mins, plot_maxs, alpha=0.25, color=cols[i])
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=80)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Overall MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 10))

lss =  ['-', '--']
labels = ['D3RLPY-PAP5-P0-3 - No REx', 'D3RLPY-PAP5-P0-3 - Beta 10.0', 'D3RLPY-PAP5-P1-4 - No REx', 'D3RLPY-PAP5-P1-4 - Beta 10.0']

metric = 'overall_mse'
for i, (exp_avgs, exp_mins, exp_maxs) in enumerate([
    (experiments_pap5_p0_3_no_rex_avgs_df, experiments_pap5_p0_3_no_rex_mins_df, experiments_pap5_p0_3_no_rex_maxs_df),
    (experiments_pap5_p0_3_avgs_df, experiments_pap5_p0_3_mins_df, experiments_pap5_p0_3_maxs_df),
    (experiments_pap5_p1_4_no_rex_avgs_df, experiments_pap5_p1_4_no_rex_mins_df, experiments_pap5_p1_4_no_rex_maxs_df),
    (experiments_pap5_p1_4_avgs_df, experiments_pap5_p1_4_mins_df, experiments_pap5_p1_4_maxs_df),
]):
    plot_avgs = exp_avgs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_mins = exp_mins.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_maxs = exp_maxs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    ax.plot(evaluation_datasets, plot_avgs, label=labels[i], c=cols[i], ls='--' if 'Beta' in labels[i] else '-')
    ax.fill_between(evaluation_datasets, plot_mins, plot_maxs, alpha=0.25, color=cols[i])
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=80)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Overall MSE')
ax.set_ylim(0.,10.)
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 10))

lss =  ['-', '--']
labels = ['D3RLPY-PAP5-P0-3 - No REx', 'D3RLPY-PAP5-P0-3 - Beta 10.0', 'D3RLPY-PAP5-P1-4 - No REx', 'D3RLPY-PAP5-P1-4 - Beta 10.0']

metric = 'log_prob'
for i, (exp_avgs, exp_mins, exp_maxs) in enumerate([
    (experiments_pap5_p0_3_no_rex_avgs_df, experiments_pap5_p0_3_no_rex_mins_df, experiments_pap5_p0_3_no_rex_maxs_df),
    (experiments_pap5_p0_3_avgs_df, experiments_pap5_p0_3_mins_df, experiments_pap5_p0_3_maxs_df),
    (experiments_pap5_p1_4_no_rex_avgs_df, experiments_pap5_p1_4_no_rex_mins_df, experiments_pap5_p1_4_no_rex_maxs_df),
    (experiments_pap5_p1_4_avgs_df, experiments_pap5_p1_4_mins_df, experiments_pap5_p1_4_maxs_df),
]):
    plot_avgs = exp_avgs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_mins = exp_mins.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_maxs = exp_maxs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    ax.plot(evaluation_datasets, plot_avgs, label=labels[i], c=cols[i], ls='--' if 'Beta' in labels[i] else '-')
    ax.fill_between(evaluation_datasets, plot_mins, plot_maxs, alpha=0.25, color=cols[i])
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=80)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Log Probability')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 10))

lss =  ['-', '--']
labels = ['D3RLPY-PAP5-P0-3 - No REx', 'D3RLPY-PAP5-P0-3 - Beta 10.0', 'D3RLPY-PAP5-P1-4 - No REx', 'D3RLPY-PAP5-P1-4 - Beta 10.0']

metric = 'log_prob'
for i, (exp_avgs, exp_mins, exp_maxs) in enumerate([
    (experiments_pap5_p0_3_no_rex_avgs_df, experiments_pap5_p0_3_no_rex_mins_df, experiments_pap5_p0_3_no_rex_maxs_df),
    (experiments_pap5_p0_3_avgs_df, experiments_pap5_p0_3_mins_df, experiments_pap5_p0_3_maxs_df),
    (experiments_pap5_p1_4_no_rex_avgs_df, experiments_pap5_p1_4_no_rex_mins_df, experiments_pap5_p1_4_no_rex_maxs_df),
    (experiments_pap5_p1_4_avgs_df, experiments_pap5_p1_4_mins_df, experiments_pap5_p1_4_maxs_df),
]):
    plot_avgs = exp_avgs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_mins = exp_mins.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_maxs = exp_maxs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    ax.plot(evaluation_datasets, plot_avgs, label=labels[i], c=cols[i], ls='--' if 'Beta' in labels[i] else '-')
    ax.fill_between(evaluation_datasets, plot_mins, plot_maxs, alpha=0.25, color=cols[i])
ax.axhline(0, ls='--', color='gray')
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=80)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Log Probability')
ax.set_ylim(-2000.,50.)
ax.legend()

# %% [markdown]
# # MP1

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 10))

lss =  ['-', '--']
labels = ['D3RLPY-MP1-P0-3 - No REx', 'D3RLPY-MP1-P0-3 - Beta 10.0', 'D3RLPY-MP1-P1-4 - No REx', 'D3RLPY-MP1-P1-4 - Beta 10.0']

metric = 'overall_mse'
for i, (exp_avgs, exp_mins, exp_maxs) in enumerate([
    (experiments_mp1_p0_3_no_rex_avgs_df, experiments_mp1_p0_3_no_rex_mins_df, experiments_mp1_p0_3_no_rex_maxs_df),
    (experiments_mp1_p0_3_avgs_df, experiments_mp1_p0_3_mins_df, experiments_mp1_p0_3_maxs_df),
    (experiments_mp1_p1_4_no_rex_avgs_df, experiments_mp1_p1_4_no_rex_mins_df, experiments_mp1_p1_4_no_rex_maxs_df),
    (experiments_mp1_p1_4_avgs_df, experiments_mp1_p1_4_mins_df, experiments_mp1_p1_4_maxs_df),
]):
    plot_avgs = exp_avgs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_mins = exp_mins.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_maxs = exp_maxs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    ax.plot(evaluation_datasets, plot_avgs, label=labels[i], c=cols[i], ls='--' if 'Beta' in labels[i] else '-')
    ax.fill_between(evaluation_datasets, plot_mins, plot_maxs, alpha=0.25, color=cols[i])
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=80)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Overall MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 10))

lss =  ['-', '--']
labels = ['D3RLPY-MP1-P0-3 - No REx', 'D3RLPY-MP1-P0-3 - Beta 10.0', 'D3RLPY-MP1-P1-4 - No REx', 'D3RLPY-MP1-P1-4 - Beta 10.0']

metric = 'overall_mse'
for i, (exp_avgs, exp_mins, exp_maxs) in enumerate([
    (experiments_mp1_p0_3_no_rex_avgs_df, experiments_mp1_p0_3_no_rex_mins_df, experiments_mp1_p0_3_no_rex_maxs_df),
    (experiments_mp1_p0_3_avgs_df, experiments_mp1_p0_3_mins_df, experiments_mp1_p0_3_maxs_df),
    (experiments_mp1_p1_4_no_rex_avgs_df, experiments_mp1_p1_4_no_rex_mins_df, experiments_mp1_p1_4_no_rex_maxs_df),
    (experiments_mp1_p1_4_avgs_df, experiments_mp1_p1_4_mins_df, experiments_mp1_p1_4_maxs_df),
]):
    plot_avgs = exp_avgs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_mins = exp_mins.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_maxs = exp_maxs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    ax.plot(evaluation_datasets, plot_avgs, label=labels[i], c=cols[i], ls='--' if 'Beta' in labels[i] else '-')
    ax.fill_between(evaluation_datasets, plot_mins, plot_maxs, alpha=0.25, color=cols[i])
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=80)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Overall MSE')
ax.set_ylim(0.,6.)
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 10))

lss =  ['-', '--']
labels = ['D3RLPY-MP1-P0-3 - No REx', 'D3RLPY-MP1-P0-3 - Beta 10.0', 'D3RLPY-MP1-P1-4 - No REx', 'D3RLPY-MP1-P1-4 - Beta 10.0']

metric = 'log_prob'
for i, (exp_avgs, exp_mins, exp_maxs) in enumerate([
    (experiments_mp1_p0_3_no_rex_avgs_df, experiments_mp1_p0_3_no_rex_mins_df, experiments_mp1_p0_3_no_rex_maxs_df),
    (experiments_mp1_p0_3_avgs_df, experiments_mp1_p0_3_mins_df, experiments_mp1_p0_3_maxs_df),
    (experiments_mp1_p1_4_no_rex_avgs_df, experiments_mp1_p1_4_no_rex_mins_df, experiments_mp1_p1_4_no_rex_maxs_df),
    (experiments_mp1_p1_4_avgs_df, experiments_mp1_p1_4_mins_df, experiments_mp1_p1_4_maxs_df),
]):
    plot_avgs = exp_avgs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_mins = exp_mins.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_maxs = exp_maxs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    ax.plot(evaluation_datasets, plot_avgs, label=labels[i], c=cols[i], ls='--' if 'Beta' in labels[i] else '-')
    ax.fill_between(evaluation_datasets, plot_mins, plot_maxs, alpha=0.25, color=cols[i])
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=80)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Log Probability')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 10))

lss =  ['-', '--']
labels = ['D3RLPY-MP1-P0-3 - No REx', 'D3RLPY-MP1-P0-3 - Beta 10.0', 'D3RLPY-MP1-P1-4 - No REx', 'D3RLPY-MP1-P1-4 - Beta 10.0']

metric = 'log_prob'
for i, (exp_avgs, exp_mins, exp_maxs) in enumerate([
    (experiments_mp1_p0_3_no_rex_avgs_df, experiments_mp1_p0_3_no_rex_mins_df, experiments_mp1_p0_3_no_rex_maxs_df),
    (experiments_mp1_p0_3_avgs_df, experiments_mp1_p0_3_mins_df, experiments_mp1_p0_3_maxs_df),
    (experiments_mp1_p1_4_no_rex_avgs_df, experiments_mp1_p1_4_no_rex_mins_df, experiments_mp1_p1_4_no_rex_maxs_df),
    (experiments_mp1_p1_4_avgs_df, experiments_mp1_p1_4_mins_df, experiments_mp1_p1_4_maxs_df),
]):
    plot_avgs = exp_avgs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_mins = exp_mins.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    plot_maxs = exp_maxs.set_index('evaluation_dataset').loc[evaluation_datasets][metric]
    ax.plot(evaluation_datasets, plot_avgs, label=labels[i], c=cols[i], ls='--' if 'Beta' in labels[i] else '-')
    ax.fill_between(evaluation_datasets, plot_mins, plot_maxs, alpha=0.25, color=cols[i])
ax.axhline(0, ls='--', color='gray')
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=80)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Log Probability')
ax.set_ylim(-200.,50.)
ax.legend()

# %% [markdown]
# # Training

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 10))

lss =  ['-', '--']
labels = ['D3RLPY-PAP5-P0-3 - No REx', 'D3RLPY-PAP5-P0-3 - Beta 10.0', 'D3RLPY-PAP5-P1-4 - No REx', 'D3RLPY-PAP5-P1-4 - Beta 10.0', 'D3RLPY-MP1-P0-3 - No REx', 'D3RLPY-MP1-P0-3 - Beta 10.0', 'D3RLPY-MP1-P1-4 - No REx', 'D3RLPY-MP1-P1-4 - Beta 10.0']

metric = 'overall_mse'
for i, (exp_avgs, exp_mins, exp_maxs, train_set) in enumerate([
    (experiments_pap5_p0_3_no_rex_avgs_df, experiments_pap5_p0_3_no_rex_mins_df, experiments_pap5_p0_3_no_rex_maxs_df, d3rlpy_pap5_p0_3_training_datasets),
    (experiments_pap5_p0_3_avgs_df, experiments_pap5_p0_3_mins_df, experiments_pap5_p0_3_maxs_df, d3rlpy_pap5_p0_3_training_datasets),
    (experiments_pap5_p1_4_no_rex_avgs_df, experiments_pap5_p1_4_no_rex_mins_df, experiments_pap5_p1_4_no_rex_maxs_df, d3rlpy_pap5_p1_4_training_datasets),
    (experiments_pap5_p1_4_avgs_df, experiments_pap5_p1_4_mins_df, experiments_pap5_p1_4_maxs_df, d3rlpy_pap5_p1_4_training_datasets),
    (experiments_mp1_p0_3_no_rex_avgs_df, experiments_mp1_p0_3_no_rex_mins_df, experiments_mp1_p0_3_no_rex_maxs_df, d3rlpy_mp1_p0_3_training_datasets),
    (experiments_mp1_p0_3_avgs_df, experiments_mp1_p0_3_mins_df, experiments_mp1_p0_3_maxs_df, d3rlpy_mp1_p0_3_training_datasets),
    (experiments_mp1_p1_4_no_rex_avgs_df, experiments_mp1_p1_4_no_rex_mins_df, experiments_mp1_p1_4_no_rex_maxs_df, d3rlpy_mp1_p1_4_training_datasets),
    (experiments_mp1_p1_4_avgs_df, experiments_mp1_p1_4_mins_df, experiments_mp1_p1_4_maxs_df, d3rlpy_mp1_p1_4_training_datasets),
]):
    plot_avgs = exp_avgs.set_index('evaluation_dataset').loc[train_set][metric]
    plot_mins = exp_mins.set_index('evaluation_dataset').loc[train_set][metric]
    plot_maxs = exp_maxs.set_index('evaluation_dataset').loc[train_set][metric]
    ax.plot(train_set, plot_avgs, label=labels[i], c=cols[i], ls='--' if 'Beta' in labels[i] else '-')
    ax.fill_between(train_set, plot_mins, plot_maxs, alpha=0.25, color=cols[i])
# ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=80)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Overall MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 10))

lss =  ['-', '--']
labels = ['D3RLPY-PAP5-P0-3 - No REx', 'D3RLPY-PAP5-P0-3 - Beta 10.0', 'D3RLPY-PAP5-P1-4 - No REx', 'D3RLPY-PAP5-P1-4 - Beta 10.0', 'D3RLPY-MP1-P0-3 - No REx', 'D3RLPY-MP1-P0-3 - Beta 10.0', 'D3RLPY-MP1-P1-4 - No REx', 'D3RLPY-MP1-P1-4 - Beta 10.0']

metric = 'log_prob'
for i, (exp_avgs, exp_mins, exp_maxs, train_set) in enumerate([
    (experiments_pap5_p0_3_no_rex_avgs_df, experiments_pap5_p0_3_no_rex_mins_df, experiments_pap5_p0_3_no_rex_maxs_df, d3rlpy_pap5_p0_3_training_datasets),
    (experiments_pap5_p0_3_avgs_df, experiments_pap5_p0_3_mins_df, experiments_pap5_p0_3_maxs_df, d3rlpy_pap5_p0_3_training_datasets),
    (experiments_pap5_p1_4_no_rex_avgs_df, experiments_pap5_p1_4_no_rex_mins_df, experiments_pap5_p1_4_no_rex_maxs_df, d3rlpy_pap5_p1_4_training_datasets),
    (experiments_pap5_p1_4_avgs_df, experiments_pap5_p1_4_mins_df, experiments_pap5_p1_4_maxs_df, d3rlpy_pap5_p1_4_training_datasets),
    (experiments_mp1_p0_3_no_rex_avgs_df, experiments_mp1_p0_3_no_rex_mins_df, experiments_mp1_p0_3_no_rex_maxs_df, d3rlpy_mp1_p0_3_training_datasets),
    (experiments_mp1_p0_3_avgs_df, experiments_mp1_p0_3_mins_df, experiments_mp1_p0_3_maxs_df, d3rlpy_mp1_p0_3_training_datasets),
    (experiments_mp1_p1_4_no_rex_avgs_df, experiments_mp1_p1_4_no_rex_mins_df, experiments_mp1_p1_4_no_rex_maxs_df, d3rlpy_mp1_p1_4_training_datasets),
    (experiments_mp1_p1_4_avgs_df, experiments_mp1_p1_4_mins_df, experiments_mp1_p1_4_maxs_df, d3rlpy_mp1_p1_4_training_datasets),
]):
    plot_avgs = exp_avgs.set_index('evaluation_dataset').loc[train_set][metric]
    plot_mins = exp_mins.set_index('evaluation_dataset').loc[train_set][metric]
    plot_maxs = exp_maxs.set_index('evaluation_dataset').loc[train_set][metric]
    ax.plot(train_set, plot_avgs, label=labels[i], c=cols[i], ls='--' if 'Beta' in labels[i] else '-')
    ax.fill_between(train_set, plot_mins, plot_maxs, alpha=0.25, color=cols[i])
# ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=80)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Log Probability')
ax.legend()
