# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/home/ajc348/rds/hpc-work/mopo')

# %%
from dogo.visualisation.policy_dynamics_plotting import (
    plot_policy_values,
    plot_cumulative_reward,
    plot_reward_mse,
    plot_returns_comparison_pol_dep_groups,
    policy_dynamics_pool_visitation_pca,
    policy_dynamics_pool_visitation_2dhist,
)

# %%
mixed_rt_1_dynamics_experiment_groups_labels=(
    (("MP748", "MP749", "MP750"), "No REx"),
    (("MP772", "MP773", "MP774"), "REx - Beta 5.0"),
    (("MP757", "MP758", "MP759"), "REx - Beta 10.0"),
)

d3rlpy_policy_experiment_groups_labels=(
    (("MP461", "MP462", "MP463"),  "0.1M Steps"),
    (("MP464", "MP465", "MP466"),  "0.2M Steps"),
    (("MP467", "MP468", "MP469"),  "0.5M Steps"),
    (("MP470", "MP471", "MP472"),  "1M Steps"),
    # (("MP542", "MP543", "MP544"),  "2M Steps"),
)

sac_policy_experiment_groups_labels=(
    (("MP677", "MP678", "MP679"), "0.1M Steps"),
    (("MP566", "MP567", "MP568"), "0.25M Steps"),
    (("MP569", "MP570", "MP571"), "0.5M Steps"),
    (("MP572", "MP573", "MP574"), "1M Steps"),
    # (("MP575", "MP576", "MP577"), "2M Steps"),
    # (("MP578", "MP579", "MP580"), "3M Steps"),
)

# %%
plot_returns_comparison_pol_dep_groups(dynamics_exp_groups_labels=mixed_rt_1_dynamics_experiment_groups_labels, policy_exp_groups_labels=sac_policy_experiment_groups_labels)

# %%
plot_returns_comparison_pol_dep_groups(dynamics_exp_groups_labels=mixed_rt_1_dynamics_experiment_groups_labels, policy_exp_groups_labels=d3rlpy_policy_experiment_groups_labels)

# %% [markdown]
# ## MOPO Penalty Coefficient 0.0 - Rollout Length 5

# %%
plot_policy_values(["MP919", "MP920", "MP921", "MP922", "MP923", "MP924", "MP925", "MP926", "MP927"])

# %% [markdown]
# ## MOPO Penalty Coefficient 0.0 - Rollout Length 10

# %%
plot_policy_values(["MP982", "MP983", "MP984", "MP985", "MP986", "MP987", "MP988", "MP989", "MP990"])
# Out:
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_fake_unpen_rewards.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_fake_unpen_rewards.npy

# %% [markdown]
# ### Dynamics

# %%
exp_list_label_set = [
    (("MP982", "MP983", "MP984"), '0'),
    (("MP985", "MP986", "MP987"), '5'),
    (("MP988", "MP989", "MP990"), '10.0'),
]
exp_pca_2d = policy_dynamics_pool_visitation_pca(exp_list_label_set)
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='visitation', eval_env='fake', vmax=2, pca_model=exp_pca_2d)
# Out:
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_fake_state_action.npy

# %%
exp_list_label_set = [
    (("MP982", "MP983", "MP984"), '0'),
    (("MP985", "MP986", "MP987"), '5'),
    (("MP988", "MP989", "MP990"), '10.0'),
]
exp_pca_2d = policy_dynamics_pool_visitation_pca(exp_list_label_set)
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='unpen-rewards', eval_env='fake', vmax=2, pca_model=exp_pca_2d)
# Out:
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_fake_state_action.npy
# /home/ajc348/rds/hpc-work/mopo/dogo/visualisation/model_pool_plotting.py:53: RuntimeWarning: invalid value encountered in true_divide
#   hist_arr = np.where(counts_arr==0., 0., hist_arr/counts_arr)

# %%
exp_list_label_set = [
    (("MP982", "MP983", "MP984"), '0'),
    (("MP985", "MP986", "MP987"), '5'),
    (("MP988", "MP989", "MP990"), '10.0'),
]
exp_pca_2d = policy_dynamics_pool_visitation_pca(exp_list_label_set)
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='rmse', eval_env='fake', vmax=0.1, pca_model=exp_pca_2d)
# Out:
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_fake_state_action.npy
# /home/ajc348/rds/hpc-work/mopo/dogo/visualisation/model_pool_plotting.py:53: RuntimeWarning: invalid value encountered in true_divide
#   hist_arr = np.where(counts_arr==0., 0., hist_arr/counts_arr)

# %% [markdown]
# ### Gym

# %%
exp_list_label_set = [
    (("MP982", "MP983", "MP984"), '0'),
    (("MP985", "MP986", "MP987"), '5'),
    (("MP988", "MP989", "MP990"), '10.0'),
]
exp_pca_2d = policy_dynamics_pool_visitation_pca(exp_list_label_set)
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='visitation', eval_env='gym', vmax=2, pca_model=exp_pca_2d)
# Out:
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_gym_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_gym_state_action.npy

# %%
exp_list_label_set = [
    (("MP982", "MP983", "MP984"), '0'),
    (("MP985", "MP986", "MP987"), '5'),
    (("MP988", "MP989", "MP990"), '10.0'),
]
exp_pca_2d = policy_dynamics_pool_visitation_pca(exp_list_label_set)
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='unpen-rewards', eval_env='gym', pca_model=exp_pca_2d)
# Out:
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_fake_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP749_MP983_dmTrue_dpTrue_gym_state_action.npy
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP986_dmTrue_dpTrue_gym_state_action.npy
# /home/ajc348/rds/hpc-work/mopo/dogo/visualisation/model_pool_plotting.py:53: RuntimeWarning: invalid value encountered in true_divide
#   hist_arr = np.where(counts_arr==0., 0., hist_arr/counts_arr)

# %% [markdown]
# ## MOPO Penalty Coefficient 1.0 - Rollout Length 10

# %%
plot_policy_values(["MP991", "MP992", "MP993", "MP994", "MP995", "MP996", "MP997", "MP998", "MP999"])
# Out:
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP995_dmTrue_dpTrue_fake_unpen_rewards.npy

# %%
exp_list_label_set = [
    (("MP991", "MP992", "MP993"), '0'),
    (("MP994", "MP995", "MP996"), '5'),
    (("MP997", "MP998", "MP999"), '10.0'),
]
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='visitation', eval_env='fake', vmax=10, pca_model=None)
# Out:
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/MP773_MP995_dmTrue_dpTrue_fake_state_action.npy

# %% [markdown]
# ## MOPO Penalty Coefficient 5.0 - Rollout Length 5

# %%
plot_policy_values(["MP796", "MP797", "MP798", "MP802", "MP803", "MP804", "MP799", "MP800", "MP801"])

# %%
plot_policy_values(["MP796", "MP797", "MP798", "MP802", "MP803", "MP804", "MP799", "MP800", "MP801"], show_penalised=False)

# %% [markdown]
# ## MOPO Penalty Coefficient 5.0 - Rollout Length 10

# %%
plot_policy_values(["MP862", "MP863", "MP864", "MP823", "MP824", "MP825", "MP865", "MP866", "MP867"])

# %%
plot_policy_values(["MP862", "MP863", "MP864", "MP823", "MP824", "MP825", "MP865", "MP866", "MP867"], show_penalised=False)

# %%
exp_list_label_set = [
    (("MP862", "MP863", "MP864"), '0'),
    (("MP823", "MP824", "MP825"), '5.0'),
    (("MP865", "MP866", "MP867"), '10.0'),
]
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='visitation', eval_env='gym', vmax=2, pca_model=None)

# %%
exp_list_label_set = [
    (("MP862", "MP863", "MP864"), '0'),
    (("MP823", "MP824", "MP825"), '5.0'),
    (("MP865", "MP866", "MP867"), '10.0'),
]
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='unpen-rewards', eval_env='gym', pca_model=exp_pca_2d)
# Out:
# /home/ajc348/rds/hpc-work/mopo/dogo/visualisation/model_pool_plotting.py:53: RuntimeWarning: invalid value encountered in true_divide
#   hist_arr = np.where(counts_arr==0., 0., hist_arr/counts_arr)

# %%
exp_list_label_set = [
    (("MP862", "MP863", "MP864"), '0'),
    (("MP823", "MP824", "MP825"), '5.0'),
    (("MP865", "MP866", "MP867"), '10.0'),
]
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='rmse', eval_env='fake', pca_model=exp_pca_2d, vmax=0.25)
# Out:
# /home/ajc348/rds/hpc-work/mopo/dogo/visualisation/model_pool_plotting.py:53: RuntimeWarning: invalid value encountered in true_divide
#   hist_arr = np.where(counts_arr==0., 0., hist_arr/counts_arr)
