# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dogo.results import get_results, get_experiment_details, average_scores_over_seeds

# %%
# D3RLPY-PAP5-P0-3 - Original - no model loading
MP134 = get_results("MP134")
MP135 = get_results("MP135")
MP136 = get_results("MP136")

# D3RLPY-PAP5-P0-3 - Original model loading
MP247 = get_results("MP247")
MP248 = get_results("MP248")
MP249 = get_results("MP249")

# D3RLPY-PAP5-P0-3 - New model loading
MP268 = get_results("MP268")
MP269 = get_results("MP269")
MP270 = get_results("MP270")

# MIXED-1 - Original model loading
MP265 = get_results("MP265")
MP266 = get_results("MP266")
MP267 = get_results("MP267")

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(20,10))

labels = [
    *['No Model Loading - D3RLPY-PAP1-P0-3']*3,
    *['Model Loading - Original - D3RLPY-PAP1-P0-3']*3,
    *['Model Loading - New - D3RLPY-PAP1-P0-3']*3,
    *['Model Loading - New - MIXED 1']*3,
]

for i, exp in enumerate([
    MP134,
    MP135,
    MP136,
    MP247,
    MP248,
    MP249,
    MP268,
    MP269,
    MP270,
    MP265,
    MP266,
    MP267,
]):
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {labels[i]} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(20,10))

labels = [
    *['No Model Loading - D3RLPY-PAP1-P0-3']*3,
    *['Model Loading - Original - D3RLPY-PAP1-P0-3']*3,
    *['Model Loading - New - D3RLPY-PAP1-P0-3']*3,
    *['Model Loading - New - MIXED 1']*3,
]

for i, exp in enumerate([
    MP134,
    MP135,
    MP136,
    MP247,
    MP248,
    MP249,
    MP268,
    MP269,
    MP270,
    MP265,
    MP266,
    MP267,
]):
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {labels[i]} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
feature = 'Q_loss'
fig, ax = plt.subplots(1, 1, figsize=(20,10))

labels = [
    *['No Model Loading - D3RLPY-PAP1-P0-3']*3,
    *['Model Loading - Original - D3RLPY-PAP1-P0-3']*3,
    *['Model Loading - New - D3RLPY-PAP1-P0-3']*3,
    *['Model Loading - New - MIXED 1']*3,
]

for i, exp in enumerate([
    MP134,
    MP135,
    MP136,
    MP247,
    MP248,
    MP249,
    MP268,
    MP269,
    MP270,
    MP265,
    MP266,
    MP267,
]):
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {labels[i]} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass
