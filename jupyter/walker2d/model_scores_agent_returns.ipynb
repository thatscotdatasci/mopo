# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
import numpy as np
import matplotlib.pyplot as plt

from dogo.plot_results import plot_dynamics_score_vs_agent_return

# %%
plt.rc('font', size=24)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
evaluation_datasets_lables = [
    ("W-D3RLPY-RT-0.1M-1-P0_10000", "D3RLPY: 0.1M"),
    ("W-D3RLPY-RT-0.2M-1-P0_10000", "D3RLPY: 0.2M"),
    ("W-D3RLPY-RT-0.5M-1-P0_10000", "D3RLPY: 0.5M"),
    ("W-D3RLPY-RT-1M-1-P0_10000", "D3RLPY: 1M"),
    ("W-D3RLPY-RT-2M-1-P0_10000", "D3RLPY: 2M"),
    ("W-D3RLPY-RT-0.1M-2-P0_10000", "D3RLPY 2 - 0.1M Steps"),
    ("W-D3RLPY-RT-0.2M-2-P0_10000", "D3RLPY 2 - 0.2M Steps"),
    ("W-D3RLPY-RT-0.5M-2-P0_10000", "D3RLPY 2 - 0.5M Steps"),
    ("W-D3RLPY-RT-1M-2-P0_10000", "D3RLPY 2 - 1M Steps"),
    ("W-D3RLPY-RT-2M-2-P0_10000", "D3RLPY 2 - 2M Steps"),
    ("W-D3RLPY-RT-0.1M-3-P0_10000", "D3RLPY 3 - 0.1M Steps"),
    ("W-D3RLPY-RT-0.2M-3-P0_10000", "D3RLPY 3 - 0.2M Steps"),
    ("W-D3RLPY-RT-0.5M-3-P0_10000", "D3RLPY 3 - 0.5M Steps"),
    ("W-D3RLPY-RT-1M-3-P0_10000", "D3RLPY 3 - 1M Steps"),
    ("W-D3RLPY-RT-2M-3-P0_10000", "D3RLPY 3 - 2M Steps"),
    ("W-SAC-RT-0.1M-1-P0_10000", "SL: 0.1M"),
    ("W-SAC-RT-0.25M-1-P0_10000", "SL: 0.25M"),
    ("W-SAC-RT-0.5M-1-P0_10000", "SL: 0.5M"),
    ("W-SAC-RT-1M-1-P0_10000", "SL: 1M"),
    ("W-SAC-RT-2M-1-P0_10000", "SL: 2M"),
    ("W-SAC-RT-3M-1-P0_10000", "SL: 3M"),
    ("W-SAC-RT-0.25M-2-P0_10000", "Softlearning 2 - 0.25M Steps"),
    ("W-SAC-RT-0.5M-2-P0_10000", "Softlearning 2 - 0.5M Steps"),
    ("W-SAC-RT-1M-2-P0_10000", "Softlearning 2 - 1M Steps"),
    ("W-SAC-RT-2M-2-P0_10000", "Softlearning 2 - 2M Steps"),
    ("W-SAC-RT-3M-2-P0_10000", "Softlearning 2 - 3M Steps"),
    ("W-SAC-RT-0.25M-3-P0_10000", "Softlearning 3 - 0.25M Steps"),
    ("W-SAC-RT-0.5M-3-P0_10000", "Softlearning 3 - 0.5M Steps"),
    ("W-SAC-RT-1M-3-P0_10000", "Softlearning 3 - 1M Steps"),
    ("W-SAC-RT-2M-3-P0_10000", "Softlearning 3 - 2M Steps"),
    ("W-SAC-RT-3M-3-P0_10000", "Softlearning 3 - 3M Steps"),
    ("D4RL-W-M_10000", "D4RL: M"),
    ("D4RL-W-ME_10000", "D4RL: ME"),
    ("D4RL-W-MR_10000", "D4RL: MR"),
    ("D4RL-W-R_10000", "D4RL: R"),
    ("W-RAND-1_10000", "Random 1"),
    ("W-RAND-2_10000", "Random 2"),
    ("W-RAND-3_10000", "Random 3"),
]
evaluation_datasets = [i[0] for i in evaluation_datasets_lables]
evaluation_labels = [i[1] for i in evaluation_datasets_lables]

rt_1_training_datasets_labels = [
    ("W-RAND-2_10000", "Random 2"),
    ("W-SAC-RT-0.25M-1-P0_10000", "SL: 0.25M"),
    ("W-SAC-RT-1M-1-P0_10000", "SL: 1M"),
    ("W-D3RLPY-RT-0.2M-1-P0_10000", "D3RLPY: 0.2M"),
    ("W-D3RLPY-RT-2M-1-P0_10000", "D3RLPY: 2M"),
]
rt_1_training_datasets = [i[0] for i in rt_1_training_datasets_labels]
rt_1_training_labels = [i[1] for i in rt_1_training_datasets_labels]

rt_3_training_datasets_labels = [
    ("W-RAND-2_10000", "Random 2"),
    ("W-RAND-3_10000", "Random 3"),
    ("W-SAC-RT-0.1M-1-P0_10000", "SL: 0.1M"),
    ("W-D3RLPY-RT-0.1M-1-P0_10000", "D3RLPY: 0.1M"),
    ("W-D3RLPY-RT-0.2M-1-P0_10000", "D3RLPY: 0.2M"),
]
rt_3_training_datasets = [i[0] for i in rt_3_training_datasets_labels]
rt_3_training_labels = [i[1] for i in rt_3_training_datasets_labels]

rt_4_training_datasets_labels = [
    ("W-SAC-RT-1M-1-P0_10000", "SL: 1M"),
    ("W-SAC-RT-2M-1-P0_10000", "SL: 2M"),
    ("W-SAC-RT-3M-1-P0_10000", "SL: 3M"),
    ("W-D3RLPY-RT-1M-1-P0_10000", "D3RLPY: 1M"),
    ("W-D3RLPY-RT-2M-1-P0_10000", "D3RLPY: 2M"),
]
rt_4_training_datasets = [i[0] for i in rt_4_training_datasets_labels]
rt_4_training_labels = [i[1] for i in rt_4_training_datasets_labels]

# %% [markdown]
# # All Datasets

# %% [markdown]
# ## h=5

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA325', 'WA326', 'WA327', 'WA349', 'WA350', 'WA351', 'WA157', 'WA158', 'WA159'), 'No REx'),
    (('WA328', 'WA329', 'WA330', 'WA352', 'WA353', 'WA354', 'WA160', 'WA161', 'WA162'), 'REx - $\\beta=5.0$'),
    (('WA331', 'WA332', 'WA333', 'WA355', 'WA356', 'WA357', 'WA163', 'WA164', 'WA165'), 'REx - $\\beta=10.0$'),
    (('WA334', 'WA335', 'WA336', 'WA358', 'WA359', 'WA360', 'WA166', 'WA167', 'WA168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-4000, xmax=50, agent_score_timesteps=3000000, save_path='workshop/env_model_log_lik_policy_eval_w2d_h5.png', fig_size=(10,12))

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA325', 'WA326', 'WA327', 'WA349', 'WA350', 'WA351', 'WA157', 'WA158', 'WA159'), 'No REx'),
    # (('WA328', 'WA329', 'WA330', 'WA352', 'WA353', 'WA354', 'WA160', 'WA161', 'WA162'), 'REx - $\\beta=5.0$'),
    (('WA331', 'WA332', 'WA333', 'WA355', 'WA356', 'WA357', 'WA163', 'WA164', 'WA165'), 'REx - $\\beta=10.0$'),
    (('WA334', 'WA335', 'WA336', 'WA358', 'WA359', 'WA360', 'WA166', 'WA167', 'WA168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-5000, agent_score_timesteps=3000000)

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA325', 'WA326', 'WA327', 'WA349', 'WA350', 'WA351', 'WA157', 'WA158', 'WA159'), 'No REx'),
    (('WA328', 'WA329', 'WA330', 'WA352', 'WA353', 'WA354', 'WA160', 'WA161', 'WA162'), 'REx - $\\beta=5.0$'),
    (('WA331', 'WA332', 'WA333', 'WA355', 'WA356', 'WA357', 'WA163', 'WA164', 'WA165'), 'REx - $\\beta=10.0$'),
    (('WA334', 'WA335', 'WA336', 'WA358', 'WA359', 'WA360', 'WA166', 'WA167', 'WA168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-5000, agent_score_timesteps=3000000, mode='id')

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA325', 'WA326', 'WA327', 'WA349', 'WA350', 'WA351', 'WA157', 'WA158', 'WA159'), 'No REx'),
    (('WA328', 'WA329', 'WA330', 'WA352', 'WA353', 'WA354', 'WA160', 'WA161', 'WA162'), 'REx - $\\beta=5.0$'),
    (('WA331', 'WA332', 'WA333', 'WA355', 'WA356', 'WA357', 'WA163', 'WA164', 'WA165'), 'REx - $\\beta=10.0$'),
    (('WA334', 'WA335', 'WA336', 'WA358', 'WA359', 'WA360', 'WA166', 'WA167', 'WA168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-5000, agent_score_timesteps=3000000, mode='all')

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA325', 'WA326', 'WA327', 'WA349', 'WA350', 'WA351', 'WA157', 'WA158', 'WA159'), 'No REx'),
    (('WA328', 'WA329', 'WA330', 'WA352', 'WA353', 'WA354', 'WA160', 'WA161', 'WA162'), 'REx - $\\beta=5.0$'),
    (('WA331', 'WA332', 'WA333', 'WA355', 'WA356', 'WA357', 'WA163', 'WA164', 'WA165'), 'REx - $\\beta=10.0$'),
    (('WA334', 'WA335', 'WA336', 'WA358', 'WA359', 'WA360', 'WA166', 'WA167', 'WA168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, xmax=15, agent_score_timesteps=3000000)

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA325', 'WA326', 'WA327', 'WA349', 'WA350', 'WA351', 'WA157', 'WA158', 'WA159'), 'No REx'),
    (('WA328', 'WA329', 'WA330', 'WA352', 'WA353', 'WA354', 'WA160', 'WA161', 'WA162'), 'REx - $\\beta=5.0$'),
    (('WA331', 'WA332', 'WA333', 'WA355', 'WA356', 'WA357', 'WA163', 'WA164', 'WA165'), 'REx - $\\beta=10.0$'),
    (('WA334', 'WA335', 'WA336', 'WA358', 'WA359', 'WA360', 'WA166', 'WA167', 'WA168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, xmax=15, agent_score_timesteps=3000000, mode='id')

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA325', 'WA326', 'WA327', 'WA349', 'WA350', 'WA351', 'WA157', 'WA158', 'WA159'), 'No REx'),
    (('WA328', 'WA329', 'WA330', 'WA352', 'WA353', 'WA354', 'WA160', 'WA161', 'WA162'), 'REx - $\\beta=5.0$'),
    (('WA331', 'WA332', 'WA333', 'WA355', 'WA356', 'WA357', 'WA163', 'WA164', 'WA165'), 'REx - $\\beta=10.0$'),
    (('WA334', 'WA335', 'WA336', 'WA358', 'WA359', 'WA360', 'WA166', 'WA167', 'WA168'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, xmax=15, agent_score_timesteps=3000000, mode='all')

# %% [markdown]
# ## h=10

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA337', 'WA338', 'WA339', 'WA361', 'WA362', 'WA363', 'WA169', 'WA170', 'WA171'), 'No REx'),
    (('WA340', 'WA341', 'WA342', 'WA364', 'WA365', 'WA366', 'WA172', 'WA173', 'WA174'), 'REx - $\\beta=5.0$'),
    (('WA343', 'WA344', 'WA345', 'WA367', 'WA368', 'WA369', 'WA175', 'WA176', 'WA177'), 'REx - $\\beta=10.0$'),
    (('WA346', 'WA347', 'WA348', 'WA370', 'WA371', 'WA372', 'WA178', 'WA179', 'WA180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-10000, xmax=200, agent_score_timesteps=3000000)

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA337', 'WA338', 'WA339', 'WA361', 'WA362', 'WA363', 'WA169', 'WA170', 'WA171'), 'No REx'),
    (('WA340', 'WA341', 'WA342', 'WA364', 'WA365', 'WA366', 'WA172', 'WA173', 'WA174'), 'REx - $\\beta=5.0$'),
    (('WA343', 'WA344', 'WA345', 'WA367', 'WA368', 'WA369', 'WA175', 'WA176', 'WA177'), 'REx - $\\beta=10.0$'),
    (('WA346', 'WA347', 'WA348', 'WA370', 'WA371', 'WA372', 'WA178', 'WA179', 'WA180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-2000, xmax=200, agent_score_timesteps=3000000, mode='id')

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA337', 'WA338', 'WA339', 'WA361', 'WA362', 'WA363', 'WA169', 'WA170', 'WA171'), 'No REx'),
    (('WA340', 'WA341', 'WA342', 'WA364', 'WA365', 'WA366', 'WA172', 'WA173', 'WA174'), 'REx - $\\beta=5.0$'),
    (('WA343', 'WA344', 'WA345', 'WA367', 'WA368', 'WA369', 'WA175', 'WA176', 'WA177'), 'REx - $\\beta=10.0$'),
    (('WA346', 'WA347', 'WA348', 'WA370', 'WA371', 'WA372', 'WA178', 'WA179', 'WA180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, show_secondary_metric=False, xmin=-10000, xmax=200, agent_score_timesteps=3000000, mode='all')

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA337', 'WA338', 'WA339', 'WA361', 'WA362', 'WA363', 'WA169', 'WA170', 'WA171'), 'No REx'),
    (('WA340', 'WA341', 'WA342', 'WA364', 'WA365', 'WA366', 'WA172', 'WA173', 'WA174'), 'REx - $\\beta=5.0$'),
    (('WA343', 'WA344', 'WA345', 'WA367', 'WA368', 'WA369', 'WA175', 'WA176', 'WA177'), 'REx - $\\beta=10.0$'),
    (('WA346', 'WA347', 'WA348', 'WA370', 'WA371', 'WA372', 'WA178', 'WA179', 'WA180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, xmax=15, agent_score_timesteps=3000000)

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA337', 'WA338', 'WA339', 'WA361', 'WA362', 'WA363', 'WA169', 'WA170', 'WA171'), 'No REx'),
    (('WA340', 'WA341', 'WA342', 'WA364', 'WA365', 'WA366', 'WA172', 'WA173', 'WA174'), 'REx - $\\beta=5.0$'),
    (('WA343', 'WA344', 'WA345', 'WA367', 'WA368', 'WA369', 'WA175', 'WA176', 'WA177'), 'REx - $\\beta=10.0$'),
    (('WA346', 'WA347', 'WA348', 'WA370', 'WA371', 'WA372', 'WA178', 'WA179', 'WA180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, xmax=15, agent_score_timesteps=3000000, mode='id')

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA337', 'WA338', 'WA339', 'WA361', 'WA362', 'WA363', 'WA169', 'WA170', 'WA171'), 'No REx'),
    (('WA340', 'WA341', 'WA342', 'WA364', 'WA365', 'WA366', 'WA172', 'WA173', 'WA174'), 'REx - $\\beta=5.0$'),
    (('WA343', 'WA344', 'WA345', 'WA367', 'WA368', 'WA369', 'WA175', 'WA176', 'WA177'), 'REx - $\\beta=10.0$'),
    (('WA346', 'WA347', 'WA348', 'WA370', 'WA371', 'WA372', 'WA178', 'WA179', 'WA180'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, primary_metric='overall_mse', show_secondary_metric=False, xmax=15, agent_score_timesteps=3000000, mode='all')

# %% [markdown]
# # MIXED-RT-1

# %% [markdown]
# ## h=5

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA037', 'WA038', 'WA039'), 'No REx'),
    (('WA040', 'WA041', 'WA042'), 'REx - $\\beta=5.0$'),
    (('WA043', 'WA044', 'WA045'), 'REx - $\\beta=10.0$'),
    (('WA046', 'WA047', 'WA048'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=650000)

# %% [markdown]
# ## h=10

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA048', 'WA050', 'WA051'), 'No REx'),
    (('WA052', 'WA053', 'WA054'), 'REx - $\\beta=5.0$'),
    (('WA054', 'WA056', 'WA057'), 'REx - $\\beta=10.0$'),
    (('WA057', 'WA059', 'WA060'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=650000)

# %% [markdown]
# # MIXED-RT-3

# %% [markdown]
# ## h=5

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA061', 'WA062', 'WA063'), 'No REx'),
    (('WA064', 'WA065', 'WA066'), 'REx - $\\beta=5.0$'),
    (('WA067', 'WA068', 'WA069'), 'REx - $\\beta=10.0$'),
    (('WA070', 'WA071', 'WA072'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=650000)

# %% [markdown]
# ## h=10

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA073', 'WA074', 'WA075'), 'No REx'),
    (('WA076', 'WA077', 'WA078'), 'REx - $\\beta=5.0$'),
    (('WA079', 'WA080', 'WA081'), 'REx - $\\beta=10.0$'),
    (('WA082', 'WA083', 'WA084'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=650000)

# %% [markdown]
# # MIXED-RT-4

# %% [markdown]
# ## h=5

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA085', 'WA086', 'WA087'), 'No REx'),
    (('WA088', 'WA089', 'WA090'), 'REx - $\\beta=5.0$'),
    (('WA091', 'WA092', 'WA093'), 'REx - $\\beta=10.0$'),
    (('WA094', 'WA095', 'WA096'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=650000)

# %% [markdown]
# ## h=10

# %%
plot_dynamics_score_vs_agent_return([
    # (('WA097', 'WA098', 'WA099'), 'No REx'),
    (('WA100', 'WA101', 'WA102'), 'REx - $\\beta=5.0$'),
    (('WA103', 'WA104', 'WA105'), 'REx - $\\beta=10.0$'),
    (('WA106', 'WA107', 'WA108'), 'REx - $\\beta=20.0$'),
], eval_ds=evaluation_datasets, train_eval_ds=rt_1_training_datasets, agent_score_timesteps=650000)
