# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dogo.results import get_results

# %%
plt.rc('font', size=12)

# %% [markdown]
# # MP157-MP161

# %%
MP100 = get_results("MP100")
MP101 = get_results("MP101")
MP102 = get_results("MP102")
MP103 = get_results("MP103")
MP104 = get_results("MP104")
MP105 = get_results("MP105")
MP106 = get_results("MP106")
MP107 = get_results("MP107")
MP108 = get_results("MP108")
MP109 = get_results("MP109")
MP110 = get_results("MP110")
MP111 = get_results("MP111")
MP134 = get_results("MP134")
MP135 = get_results("MP135")
MP136 = get_results("MP136")
MP137 = get_results("MP137")
MP138 = get_results("MP138")
MP139 = get_results("MP139")
MP146 = get_results("MP146")
MP157 = get_results("MP157")
MP158 = get_results("MP158")
MP159 = get_results("MP159")
MP160 = get_results("MP160")
MP161 = get_results("MP161")

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
# plt.rc('font', size=18)

for (exp, label) in [
    (MP100, 'No REx'),
    (MP134, 'Discounted Sum of Risks'),
    (MP101, 'REx'),
    (MP146, 'Discounted REx'),
]:
    ax.plot(exp.dynamics.model_pol_total_loss_history.mean(axis=1), label=label)
ax.set_xlabel('Epochs')
ax.set_ylabel('Sum of Policy Risks - Held-out Data')
ax.set_ylim(0.2,1.2)
ax.legend()
fig.savefig(os.path.join('dogo_plots', f'sum_of_policy_losses_PAP5_P0_3.png'), pad_inches=0.2, bbox_inches='tight')
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
# plt.rc('font', size=18)

for (exp, label) in [
    (MP100, 'No REx'),
    (MP134, 'Discounted Sum of Risks'),
    (MP101, 'REx'),
    (MP146, 'Discounted REx'),
]:
    ax.plot(exp.dynamics.model_holdout_pol_total_loss_history.mean(axis=1), label=label)
ax.set_xlabel('Epochs')
ax.set_ylabel('Sum of Policy Risks - Held-out Data')
ax.set_ylim(0.2,1.5)
ax.legend()
fig.savefig(os.path.join('dogo_plots', f'sum_of_heldout_policy_losses_PAP5_P0_3.png'), pad_inches=0.2, bbox_inches='tight')
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
plt.rc('font', size=24)

feature = 'model_pol_total_loss_history'
d3rlpy_pap5_p0_3_no_rex       = np.vstack((getattr(MP100.dynamics, feature).mean(axis=1)[-350:], getattr(MP104.dynamics, feature).mean(axis=1)[-350:], getattr(MP108.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_no_rex_decay = np.vstack((getattr(MP134.dynamics, feature).mean(axis=1)[-350:], getattr(MP135.dynamics, feature).mean(axis=1)[-350:], getattr(MP136.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_rex          = np.vstack((getattr(MP101.dynamics, feature).mean(axis=1)[-350:], getattr(MP105.dynamics, feature).mean(axis=1)[-350:], getattr(MP109.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_rex_decay    = np.vstack((getattr(MP146.dynamics, feature).mean(axis=1)[-350:], getattr(MP157.dynamics, feature).mean(axis=1)[-350:], getattr(MP158.dynamics, feature).mean(axis=1)[-350:]))

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex.mean(axis=0), label='No REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex.min(axis=0), d3rlpy_pap5_p0_3_no_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex_decay.mean(axis=0), label='Discounted Sum of Risks')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex_decay.min(axis=0), d3rlpy_pap5_p0_3_no_rex_decay.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_rex.mean(axis=0), label='REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_rex.min(axis=0), d3rlpy_pap5_p0_3_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_rex_decay.mean(axis=0), label='Discounted REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_rex_decay.min(axis=0), d3rlpy_pap5_p0_3_rex_decay.max(axis=0), alpha=0.3)

ax.set_xlabel('Final Epochs')
ax.set_ylabel('Sum of Policy Risks - Training Data')
ax.set_xticklabels(np.arange(-400,1,50))
ax.set_ylim(0.2,1.5)
ax.legend(loc='upper left', prop={'size': 18})
fig.savefig(os.path.join('dogo_plots', f'sum_of_policy_losses_avg_PAP5_P0_3.png'), pad_inches=0.2, bbox_inches='tight')
pass
# Out:
# /tmp/ipykernel_141996/386048527.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.arange(-400,1,50))

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
plt.rc('font', size=24)

feature = 'model_holdout_pol_total_loss_history'
d3rlpy_pap5_p0_3_no_rex       = np.vstack((getattr(MP100.dynamics, feature).mean(axis=1)[-350:], getattr(MP104.dynamics, feature).mean(axis=1)[-350:], getattr(MP108.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_no_rex_decay = np.vstack((getattr(MP134.dynamics, feature).mean(axis=1)[-350:], getattr(MP135.dynamics, feature).mean(axis=1)[-350:], getattr(MP136.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_rex          = np.vstack((getattr(MP101.dynamics, feature).mean(axis=1)[-350:], getattr(MP105.dynamics, feature).mean(axis=1)[-350:], getattr(MP109.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_rex_decay    = np.vstack((getattr(MP146.dynamics, feature).mean(axis=1)[-350:], getattr(MP157.dynamics, feature).mean(axis=1)[-350:], getattr(MP158.dynamics, feature).mean(axis=1)[-350:]))

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex.mean(axis=0), label='No REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex.min(axis=0), d3rlpy_pap5_p0_3_no_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex_decay.mean(axis=0), label='Discounted Sum of Risks')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex_decay.min(axis=0), d3rlpy_pap5_p0_3_no_rex_decay.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_rex.mean(axis=0), label='REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_rex.min(axis=0), d3rlpy_pap5_p0_3_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_rex_decay.mean(axis=0), label='Discounted REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_rex_decay.min(axis=0), d3rlpy_pap5_p0_3_rex_decay.max(axis=0), alpha=0.3)

ax.set_xlabel('Final Steps')
ax.set_ylabel('Sum of Policy Risks - Held-out Data')
ax.set_xticklabels(np.arange(-400,1,50))
ax.set_ylim(0.2,1.5)
ax.legend(loc='upper left', prop={'size': 18})
fig.savefig(os.path.join('dogo_plots', f'sum_of_heldout_policy_losses_avg_PAP5_P0_3.png'), pad_inches=0.2, bbox_inches='tight')
pass
# Out:
# /tmp/ipykernel_141996/1679160916.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.arange(-400,1,50))

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

feature = 'model_pol_var_loss_history'
d3rlpy_pap5_p0_3_no_rex       = np.vstack((getattr(MP100.dynamics, feature).mean(axis=1)[-350:], getattr(MP104.dynamics, feature).mean(axis=1)[-350:], getattr(MP108.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_no_rex_decay = np.vstack((getattr(MP134.dynamics, feature).mean(axis=1)[-350:], getattr(MP135.dynamics, feature).mean(axis=1)[-350:], getattr(MP136.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_rex          = np.vstack((getattr(MP101.dynamics, feature).mean(axis=1)[-350:], getattr(MP105.dynamics, feature).mean(axis=1)[-350:], getattr(MP109.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_rex_decay    = np.vstack((getattr(MP146.dynamics, feature).mean(axis=1)[-350:], getattr(MP157.dynamics, feature).mean(axis=1)[-350:], getattr(MP158.dynamics, feature).mean(axis=1)[-350:]))

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex.mean(axis=0), label='Episode Splits - Policies 0-3 - No REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex.min(axis=0), d3rlpy_pap5_p0_3_no_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex_decay.mean(axis=0), label='Episode Splits - Policies 0-3 - Discounted Sum of Risks')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex_decay.min(axis=0), d3rlpy_pap5_p0_3_no_rex_decay.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_rex.mean(axis=0), label='Episode Splits - Policies 0-3 - REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_rex.min(axis=0), d3rlpy_pap5_p0_3_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_rex_decay.mean(axis=0), label='Episode Splits - Policies 0-3 - Discounted REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_rex_decay.min(axis=0), d3rlpy_pap5_p0_3_rex_decay.max(axis=0), alpha=0.3)

ax.set_xlabel('Final Steps')
ax.set_ylabel('Variance of Policy Losses - Training Data')
ax.set_xticklabels(np.arange(-400,1,50))
ax.set_ylim(0,0.01)
ax.legend()
pass
# Out:
# /tmp/ipykernel_187674/863508879.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.arange(-400,1,50))

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

feature = 'model_holdout_pol_var_loss_history'
d3rlpy_pap5_p0_3_no_rex       = np.vstack((getattr(MP100.dynamics, feature).mean(axis=1)[-350:], getattr(MP104.dynamics, feature).mean(axis=1)[-350:], getattr(MP108.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_no_rex_decay = np.vstack((getattr(MP134.dynamics, feature).mean(axis=1)[-350:], getattr(MP135.dynamics, feature).mean(axis=1)[-350:], getattr(MP136.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_rex          = np.vstack((getattr(MP101.dynamics, feature).mean(axis=1)[-350:], getattr(MP105.dynamics, feature).mean(axis=1)[-350:], getattr(MP109.dynamics, feature).mean(axis=1)[-350:]))
d3rlpy_pap5_p0_3_rex_decay    = np.vstack((getattr(MP146.dynamics, feature).mean(axis=1)[-350:], getattr(MP157.dynamics, feature).mean(axis=1)[-350:], getattr(MP158.dynamics, feature).mean(axis=1)[-350:]))

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex.mean(axis=0), label='Episode Splits - Policies 0-3 - No REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex.min(axis=0), d3rlpy_pap5_p0_3_no_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex_decay.mean(axis=0), label='Episode Splits - Policies 0-3 - Discounted Sum of Risks')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_no_rex_decay.min(axis=0), d3rlpy_pap5_p0_3_no_rex_decay.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_rex.mean(axis=0), label='Episode Splits - Policies 0-3 - REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_rex.min(axis=0), d3rlpy_pap5_p0_3_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 350), d3rlpy_pap5_p0_3_rex_decay.mean(axis=0), label='Episode Splits - Policies 0-3 - Discounted REx')
ax.fill_between(np.arange(0, 350), d3rlpy_pap5_p0_3_rex_decay.min(axis=0), d3rlpy_pap5_p0_3_rex_decay.max(axis=0), alpha=0.3)

ax.set_xlabel('Final Steps')
ax.set_ylabel('Variance of Policy Losses - Held-out Data')
ax.set_xticklabels(np.arange(-400,1,50))
ax.set_ylim(0,0.01)
ax.legend()
pass
# Out:
# /tmp/ipykernel_187674/518209044.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.arange(-400,1,50))

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

feature = 'model_pol_total_loss_history'
d3rlpy_pap5_p1_4_no_rex       = np.vstack((getattr(MP102.dynamics, feature).mean(axis=1)[-300:], getattr(MP106.dynamics, feature).mean(axis=1)[-300:], getattr(MP110.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_no_rex_decay = np.vstack((getattr(MP137.dynamics, feature).mean(axis=1)[-300:], getattr(MP138.dynamics, feature).mean(axis=1)[-300:], getattr(MP139.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_rex          = np.vstack((getattr(MP103.dynamics, feature).mean(axis=1)[-300:], getattr(MP107.dynamics, feature).mean(axis=1)[-300:], getattr(MP111.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_rex_decay    = np.vstack((getattr(MP159.dynamics, feature).mean(axis=1)[-300:], getattr(MP160.dynamics, feature).mean(axis=1)[-300:], getattr(MP161.dynamics, feature).mean(axis=1)[-300:]))

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - No REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex.min(axis=0), d3rlpy_pap5_p1_4_no_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex_decay.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - Discounted Sum of Risks')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex_decay.min(axis=0), d3rlpy_pap5_p1_4_no_rex_decay.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_rex.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_rex.min(axis=0), d3rlpy_pap5_p1_4_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_rex_decay.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - Discounted REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_rex_decay.min(axis=0), d3rlpy_pap5_p1_4_rex_decay.max(axis=0), alpha=0.3)

ax.set_xlabel('Final Steps')
ax.set_ylabel('Sum of Policy Risks - Training Data')
ax.set_xticklabels(np.arange(-350,1,50))
ax.set_ylim(0.2,3.)
ax.legend()
pass
# Out:
# /tmp/ipykernel_187674/2242620137.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.arange(-350,1,50))

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

feature = 'model_holdout_pol_total_loss_history'
d3rlpy_pap5_p1_4_no_rex       = np.vstack((getattr(MP102.dynamics, feature).mean(axis=1)[-300:], getattr(MP106.dynamics, feature).mean(axis=1)[-300:], getattr(MP110.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_no_rex_decay = np.vstack((getattr(MP137.dynamics, feature).mean(axis=1)[-300:], getattr(MP138.dynamics, feature).mean(axis=1)[-300:], getattr(MP139.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_rex          = np.vstack((getattr(MP103.dynamics, feature).mean(axis=1)[-300:], getattr(MP107.dynamics, feature).mean(axis=1)[-300:], getattr(MP111.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_rex_decay    = np.vstack((getattr(MP159.dynamics, feature).mean(axis=1)[-300:], getattr(MP160.dynamics, feature).mean(axis=1)[-300:], getattr(MP161.dynamics, feature).mean(axis=1)[-300:]))

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - No REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex.min(axis=0), d3rlpy_pap5_p1_4_no_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex_decay.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - Discounted Sum of Risks')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex_decay.min(axis=0), d3rlpy_pap5_p1_4_no_rex_decay.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_rex.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_rex.min(axis=0), d3rlpy_pap5_p1_4_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_rex_decay.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - Discounted REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_rex_decay.min(axis=0), d3rlpy_pap5_p1_4_rex_decay.max(axis=0), alpha=0.3)

ax.set_xlabel('Final Steps')
ax.set_ylabel('Sum of Policy Risks - Held-out Data')
ax.set_xticklabels(np.arange(-350,1,50))
ax.set_ylim(0.2,5.)
ax.legend()
pass
# Out:
# /tmp/ipykernel_187674/350634053.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.arange(-350,1,50))

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

feature = 'model_pol_var_loss_history'
d3rlpy_pap5_p1_4_no_rex       = np.vstack((getattr(MP102.dynamics, feature).mean(axis=1)[-300:], getattr(MP106.dynamics, feature).mean(axis=1)[-300:], getattr(MP110.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_no_rex_decay = np.vstack((getattr(MP137.dynamics, feature).mean(axis=1)[-300:], getattr(MP138.dynamics, feature).mean(axis=1)[-300:], getattr(MP139.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_rex          = np.vstack((getattr(MP103.dynamics, feature).mean(axis=1)[-300:], getattr(MP107.dynamics, feature).mean(axis=1)[-300:], getattr(MP111.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_rex_decay    = np.vstack((getattr(MP159.dynamics, feature).mean(axis=1)[-300:], getattr(MP160.dynamics, feature).mean(axis=1)[-300:], getattr(MP161.dynamics, feature).mean(axis=1)[-300:]))

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - No REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex.min(axis=0), d3rlpy_pap5_p1_4_no_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex_decay.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - Discounted Sum of Risks')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex_decay.min(axis=0), d3rlpy_pap5_p1_4_no_rex_decay.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_rex.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_rex.min(axis=0), d3rlpy_pap5_p1_4_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_rex_decay.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - Discounted REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_rex_decay.min(axis=0), d3rlpy_pap5_p1_4_rex_decay.max(axis=0), alpha=0.3)

ax.set_xlabel('Final Steps')
ax.set_ylabel('Variance of Policy Losses - Training Data')
ax.set_xticklabels(np.arange(-350,1,50))
ax.set_ylim(0,0.015)
ax.legend()
pass
# Out:
# /tmp/ipykernel_187674/943393478.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.arange(-350,1,50))

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

feature = 'model_holdout_pol_var_loss_history'
d3rlpy_pap5_p1_4_no_rex       = np.vstack((getattr(MP102.dynamics, feature).mean(axis=1)[-300:], getattr(MP106.dynamics, feature).mean(axis=1)[-300:], getattr(MP110.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_no_rex_decay = np.vstack((getattr(MP137.dynamics, feature).mean(axis=1)[-300:], getattr(MP138.dynamics, feature).mean(axis=1)[-300:], getattr(MP139.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_rex          = np.vstack((getattr(MP103.dynamics, feature).mean(axis=1)[-300:], getattr(MP107.dynamics, feature).mean(axis=1)[-300:], getattr(MP111.dynamics, feature).mean(axis=1)[-300:]))
d3rlpy_pap5_p1_4_rex_decay    = np.vstack((getattr(MP159.dynamics, feature).mean(axis=1)[-300:], getattr(MP160.dynamics, feature).mean(axis=1)[-300:], getattr(MP161.dynamics, feature).mean(axis=1)[-300:]))

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - No REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex.min(axis=0), d3rlpy_pap5_p1_4_no_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex_decay.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - Discounted Sum of Risks')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_no_rex_decay.min(axis=0), d3rlpy_pap5_p1_4_no_rex_decay.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_rex.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_rex.min(axis=0), d3rlpy_pap5_p1_4_rex.max(axis=0), alpha=0.3)

ax.plot(np.arange(0, 300), d3rlpy_pap5_p1_4_rex_decay.mean(axis=0), label='Mixed SAC Agents - Policies 1-4 - Discounted REx')
ax.fill_between(np.arange(0, 300), d3rlpy_pap5_p1_4_rex_decay.min(axis=0), d3rlpy_pap5_p1_4_rex_decay.max(axis=0), alpha=0.3)

ax.set_xlabel('Final Steps')
ax.set_ylabel('Variance of Policy Losses - Held-out Data')
ax.set_xticklabels(np.arange(-350,1,50))
ax.set_ylim(0,0.015)
ax.legend()
pass
# Out:
# /tmp/ipykernel_187674/3949822249.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.arange(-350,1,50))

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))

for exp, loss_decay_term in [
    (MP110, 1.),
    (MP111, 1.),
    # (MP146, 10.),
]:
    ax[0].plot(exp.dynamics.model_pol_total_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    ax[1].plot(exp.dynamics.model_holdout_pol_total_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    
    ax[0].set_ylabel('Sum of Policy Risks')
    ax[1].set_ylabel('Sum of Holdout Policy Losses')

for i in range(2):
    ax[i].set_xlabel('Epochs')
    ax[i].set_xlim(100)
    ax[i].set_ylim(0,3.)
    ax[i].legend()
pass

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))

for exp, loss_decay_term in [
    (MP100, 1.),
    (MP134, 10.),
    (MP101, 1.),
    (MP146, 10.),
]:
    ax[0].plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    ax[1].plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    
    ax[0].set_ylabel('Variance of Policy Losses')
    ax[1].set_ylabel('Variance of Holdout Policy Losses')

for i in range(2):
    ax[i].set_xlabel('Epochs')
    ax[i].set_xlim(100)
    ax[i].set_ylim(0,0.02)
    ax[i].legend()
pass

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))

for exp, loss_decay_term in [
    (MP104, 1.),
    (MP135, 10.),
    (MP105, 1.),
    (MP157, 10.),
]:
    ax[0].plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    ax[1].plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    
    ax[0].set_ylabel('Variance of Policy Losses')
    ax[1].set_ylabel('Variance of Holdout Policy Losses')

for i in range(2):
    ax[i].set_xlabel('Epochs')
    ax[i].set_xlim(200)
    ax[i].set_ylim(0,0.02)
    ax[i].legend()
pass

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))

for exp, loss_decay_term in [
    (MP108, 1.),
    (MP136, 10.),
    (MP109, 1.),
    (MP158, 10.),
]:
    ax[0].plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    ax[1].plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    
    ax[0].set_ylabel('Variance of Policy Losses')
    ax[1].set_ylabel('Variance of Holdout Policy Losses')

for i in range(2):
    ax[i].set_xlabel('Epochs')
    ax[i].set_xlim(200)
    ax[i].set_ylim(0,0.02)
    ax[i].legend()
pass

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))

for exp, loss_decay_term in [
    (MP102, 1.),
    (MP137, 10.),
    (MP103, 1.),
    (MP159, 10.),
]:
    ax[0].plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    ax[1].plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    
    ax[0].set_ylabel('Variance of Policy Losses')
    ax[1].set_ylabel('Variance of Holdout Policy Losses')

for i in range(2):
    ax[i].set_xlabel('Epochs')
    ax[i].set_xlim(200)
    ax[i].set_ylim(0,0.02)
    ax[i].legend()
pass

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))

for exp, loss_decay_term in [
    (MP106, 1.),
    (MP138, 10.),
    (MP107, 1.),
    (MP160, 10.),
]:
    ax[0].plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    ax[1].plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    
    ax[0].set_ylabel('Variance of Policy Losses')
    ax[1].set_ylabel('Variance of Holdout Policy Losses')

for i in range(2):
    ax[i].set_xlabel('Epochs')
    ax[i].set_xlim(200)
    ax[i].set_ylim(0,0.02)
    ax[i].legend()
pass

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))

for exp, loss_decay_term in [
    (MP110, 1.),
    (MP139, 10.),
    (MP111, 1.),
    (MP161, 10.),
]:
    ax[0].plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    ax[1].plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
    
    ax[0].set_ylabel('Variance of Policy Losses')
    ax[1].set_ylabel('Variance of Holdout Policy Losses')

for i in range(2):
    ax[i].set_xlabel('Epochs')
    ax[i].set_xlim(200)
    ax[i].set_ylim(0,0.02)
    ax[i].legend()
pass
