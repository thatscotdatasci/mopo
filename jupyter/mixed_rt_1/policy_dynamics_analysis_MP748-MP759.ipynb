# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dogo.visualisation.policy_dynamics_plotting import (
    plot_returns_comparison_pol_dep_groups,
    policy_dynamics_pool_visitation_pca,
    policy_dynamics_pool_visitation_2dhist,
)

# %%
mixed_rt_1_dynamics_experiment_groups_labels=(
    (("MP748", "MP749", "MP750"), "No REx"),
    (("MP772", "MP773", "MP774"), "REx - Beta 5.0"),
    (("MP757", "MP758", "MP759"), "REx - Beta 10.0"),
)

d3rlpy_policy_experiment_groups_labels=(
    (("MP461", "MP462", "MP463"),  "0.1M Steps"),
    (("MP464", "MP465", "MP466"),  "0.2M Steps"),
    (("MP467", "MP468", "MP469"),  "0.5M Steps"),
    (("MP470", "MP471", "MP472"),  "1M Steps"),
    # (("MP542", "MP543", "MP544"),  "2M Steps"),
)

sac_policy_experiment_groups_labels=(
    (("MP677", "MP678", "MP679"), "0.1M Steps"),
    (("MP566", "MP567", "MP568"), "0.25M Steps"),
    (("MP569", "MP570", "MP571"), "0.5M Steps"),
    (("MP572", "MP573", "MP574"), "1M Steps"),
    # (("MP575", "MP576", "MP577"), "2M Steps"),
    # (("MP578", "MP579", "MP580"), "3M Steps"),
)

# %%
plot_returns_comparison_pol_dep_groups(dynamics_exp_groups_labels=mixed_rt_1_dynamics_experiment_groups_labels, policy_exp_groups_labels=sac_policy_experiment_groups_labels)

# %%
plot_returns_comparison_pol_dep_groups(dynamics_exp_groups_labels=mixed_rt_1_dynamics_experiment_groups_labels, policy_exp_groups_labels=d3rlpy_policy_experiment_groups_labels)

# %%
exp_list_label_set = [
    (("MP862", "MP863", "MP864"), '0'),
    # (("MP823", "MP824", "MP825"), '5.0'),
    # (("MP865", "MP866", "MP867"), '10.0'),
]
exp_pca_2d = policy_dynamics_pool_visitation_pca(exp_list_label_set)

# %%
exp_list_label_set = [
    (("MP862", "MP863", "MP864"), '0'),
    # (("MP823", "MP824", "MP825"), '5.0'),
    (("MP865", "MP866", "MP867"), '10.0'),
]
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='visitation', eval_env='gym', vmax=10, pca_model=exp_pca_2d)

# %%
exp_list_label_set = [
    (("MP862", "MP863", "MP864"), '0'),
    # (("MP823", "MP824", "MP825"), '5.0'),
    (("MP865", "MP866", "MP867"), '10.0'),
]
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='unpen-rewards', pca_model=exp_pca_2d)
# Out:
# /rds/user/ajc348/hpc-work/mopo/dogo/visualisation/model_pool_plotting.py:42: RuntimeWarning: invalid value encountered in true_divide
#   hist_arr = np.where(counts_arr==0., 0., hist_arr/counts_arr)

# %%
exp_list_label_set = [
    (("MP862", "MP863", "MP864"), '0'),
    # (("MP823", "MP824", "MP825"), '5.0'),
    (("MP865", "MP866", "MP867"), '10.0'),
]
policy_dynamics_pool_visitation_2dhist(exp_list_label_set, mode='rmse', pca_model=exp_pca_2d, vmax=0.25)
# Out:
# /rds/user/ajc348/hpc-work/mopo/dogo/visualisation/model_pool_plotting.py:42: RuntimeWarning: invalid value encountered in true_divide
#   hist_arr = np.where(counts_arr==0., 0., hist_arr/counts_arr)
