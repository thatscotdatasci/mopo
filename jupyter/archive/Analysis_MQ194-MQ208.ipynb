# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dogo.results import get_results, get_experiment_details, average_scores_over_seeds
from dogo.plot_results import plot_grouped_evaluation_returns

# %%
plt.rc('font', size=12)

# %%
######
# MOPO
######

# 0.1M Records
MQ194 = get_results("MQ194")
MQ195 = get_results("MQ195")
MQ196 = get_results("MQ196")# 0.2M Records
MQ197 = get_results("MQ197")
MQ198 = get_results("MQ198")
MQ199 = get_results("MQ199")# 0.5M Records
MQ200 = get_results("MQ200")
MQ201 = get_results("MQ201")
MQ202 = get_results("MQ202")# 1M Records
MQ203 = get_results("MQ203")
MQ204 = get_results("MQ204")
MQ205 = get_results("MQ205")# 2M Records
MQ206 = get_results("MQ206")
MQ207 = get_results("MQ207")
MQ208 = get_results("MQ208")

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'evaluation/return-average'
for exp in [
    MQ194,
    MQ195,
    MQ196,
    MQ197,
    MQ198,
    MQ199,
    MQ200,
    MQ201,
    MQ202,
    MQ203,
    MQ204,
    MQ205,
    MQ206,
    MQ207,
    MQ208
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {exp.dataset} - Seed: {exp.seed}'
    )
    print(f'{exp.name}: {exp.sac.result["timesteps_total"].max()}')
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass
# Out:
# MQ194: 500000
# MQ195: 500000
# MQ196: 500000
# MQ197: 500000
# MQ198: 500000
# MQ199: 500000
# MQ200: 500000
# MQ201: 500000
# MQ202: 500000
# MQ203: 500000
# MQ204: 438000
# MQ205: 500000
# MQ206: 500000
# MQ207: 379000
# MQ208: 483000

# %%
plot_grouped_evaluation_returns([
    ((MQ194, MQ195, MQ196), 'Steps: 0.1M'),
    ((MQ197, MQ198, MQ199), 'Steps: 0.2M'),
    ((MQ200, MQ201, MQ202), 'Steps: 0.5M'),
    ((MQ203, MQ204, MQ205), 'Steps: 1M'),
    ((MQ206, MQ207, MQ208), 'Steps: 2M'),
], save_path='ch4/d3rlpy_0.1M_records_extended_training_sac.png', show_ends=True)
# Out:
# {'Steps: 0.1M': {'mean': -226, 'std': 328},
#  'Steps: 0.2M': {'mean': 115, 'std': 868},
#  'Steps: 0.5M': {'mean': -259, 'std': 35},
#  'Steps: 1M': {'mean': -395, 'std': 135},
#  'Steps: 2M': {'mean': -202, 'std': 0}}

# %%
plot_grouped_evaluation_returns([
    ((MQ194, MQ195, MQ196), 'Steps: 0.1M'),
    ((MQ197, MQ198, MQ199), 'Steps: 0.2M'),
    ((MQ200, MQ201, MQ202), 'Steps: 0.5M'),
    # ((MQ203, MQ204, MQ205), 'Steps: 1M'),
    # ((MQ206, MQ207, MQ208), 'Steps: 2M'),
], feature='Q_loss', ymin=-1e3, ymax=1e3)#, save_path='ch4/d3rlpy_0.1M_records_extended_training_d4rl.png')
# Out:
# {'Steps: 0.1M': {'mean': 6915571406202, 'std': 5521044869467},
#  'Steps: 0.2M': {'mean': 1426935757199, 'std': 2017991567992},
#  'Steps: 0.5M': {'mean': 284810911416320, 'std': 337150930863001}}
