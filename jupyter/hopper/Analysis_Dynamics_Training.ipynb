# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/home/ajc348/rds/hpc-work/mopo')

# %%
from itertools import zip_longest

import numpy as np
import matplotlib.pyplot as plt

from dogo.results import get_results
from dogo.plot_results import plot_experiment_metrics, plot_min_max_logvars, plot_grouped_evaluation_returns, plot_min_max_penalty

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# # H-MIXED-RT-1

# %%
HO001 = get_results("HO001") # No REx
HO002 = get_results("HO002")
HO003 = get_results("HO003")
HO004 = get_results("HO004") # REx 5.0
HO005 = get_results("HO005")
HO006 = get_results("HO006")
HO007 = get_results("HO007") # REx 10.0
HO008 = get_results("HO008")
HO009 = get_results("HO009")
HO010 = get_results("HO010") # REx 20.0
HO011 = get_results("HO011")
HO012 = get_results("HO012")

# %%
plot_experiment_metrics(
    [
        ('model_loss_history',                   'Loss - Training Data',                      (0,5.0)),
        ('model_holdout_loss_history',           'Loss - Holdout Data',                       (0,5.0)),
        ('model_pol_total_loss_history',         'Sum of Policy Losses - Training Data',      (0,5.0)),
        ('model_holdout_pol_total_loss_history', 'Sum of Policy Losses - Holdout Data',       (0,5.0)),
        ('model_pol_var_loss_history',           'Variance of Policy Losses - Training Data', (0,0.02)),
        ('model_holdout_pol_var_loss_history',   'Variance of Policy Losses - Holdout Data',  (0,0.02)),
    ],
    [[
        ((HO001, HO002, HO003), 'No REx'),
        ((HO004, HO005, HO006), 'REx: $\\beta=5.0$'),
        ((HO007, HO008, HO009), 'REx: $\\beta=10.0$'),
        ((HO010, HO011, HO012), 'REx: $\\beta=20.0$'),
    ]],
    (3,2)
)

# %%
plot_experiment_metrics(
    [
        ('model_train_loss_history',           'Total Loss',                 (-510,200)),
        ('model_train_core_loss_history',      'Core Loss',                  (-510,200)),
        ('model_train_pol_total_loss_history', 'Sum of Policy Losses',       (-65,150)),
        ('model_train_pol_var_loss_history',   'Variance of Policy Losses',  (0,2)),
        ('model_train_decay_loss_history',     'Weight Regularisation Loss', (0,2.5)),
        ('model_train_var_lim_loss_history',   'Variance Bounding Loss',     (0,2)),
    ],
    [[
        ((HO010, HO011, HO012), 'REx: $\\beta=20.0$'),
        ((HO007, HO008, HO009), 'REx: $\\beta=10.0$'),
        ((HO004, HO005, HO006), 'REx: $\\beta=5.0$'),
        ((HO001, HO002, HO003), 'No REx'),
    ]],
    (3,2),
    x_label='Training Batches',
)

# %% [markdown]
# # H-MIXED-RT-3

# %%
HO013 = get_results("HO013") # No REx
HO014 = get_results("HO014")
HO015 = get_results("HO015")
HO016 = get_results("HO016") # REx 5.0
HO017 = get_results("HO017")
HO018 = get_results("HO018")
HO019 = get_results("HO019") # REx 10.0
HO020 = get_results("HO020")
HO021 = get_results("HO021")
HO022 = get_results("HO022") # REx 20.0
HO023 = get_results("HO023")
HO024 = get_results("HO024")

# %%
plot_experiment_metrics(
    [
        ('model_loss_history',                   'Loss - Training Data',                      (0,5.0)),
        ('model_holdout_loss_history',           'Loss - Holdout Data',                       (0,5.0)),
        ('model_pol_total_loss_history',         'Sum of Policy Losses - Training Data',      (0,5.0)),
        ('model_holdout_pol_total_loss_history', 'Sum of Policy Losses - Holdout Data',       (0,5.0)),
        ('model_pol_var_loss_history',           'Variance of Policy Losses - Training Data', (0,0.02)),
        ('model_holdout_pol_var_loss_history',   'Variance of Policy Losses - Holdout Data',  (0,0.02)),
    ],
    [[
        ((HO013, HO014, HO015), 'No REx'),
        ((HO016, HO017, HO018), 'REx: $\\beta=5.0$'),
        ((HO019, HO020, HO021), 'REx: $\\beta=10.0$'),
        ((HO022, HO023, HO024), 'REx: $\\beta=20.0$'),
    ]],
    (3,2)
)

# %%
plot_experiment_metrics(
    [
        ('model_train_loss_history',           'Total Loss',                 (-510,200)),
        ('model_train_core_loss_history',      'Core Loss',                  (-510,200)),
        ('model_train_pol_total_loss_history', 'Sum of Policy Losses',       (-65,150)),
        ('model_train_pol_var_loss_history',   'Variance of Policy Losses',  (0,2)),
        ('model_train_decay_loss_history',     'Weight Regularisation Loss', (0,2.5)),
        ('model_train_var_lim_loss_history',   'Variance Bounding Loss',     (0,2)),
    ],
    [[
        ((HO022, HO023, HO024), 'REx: $\\beta=20.0$'),
        ((HO019, HO020, HO021), 'REx: $\\beta=10.0$'),
        ((HO016, HO017, HO018), 'REx: $\\beta=5.0$'),
        ((HO013, HO014, HO015), 'No REx'),
    ]],
    (3,2),
    x_label='Training Batches',
)

# %% [markdown]
# # H-MIXED-RT-4

# %%
HO025 = get_results("HO025") # No REx
HO026 = get_results("HO026")
HO027 = get_results("HO027")
HO028 = get_results("HO028") # REx 5.0
HO029 = get_results("HO029")
HO030 = get_results("HO030")
HO031 = get_results("HO031") # REx 10.0
HO032 = get_results("HO032")
HO033 = get_results("HO033")
HO034 = get_results("HO034") # REx 20.0
HO035 = get_results("HO035")
HO036 = get_results("HO036")

# %%
plot_experiment_metrics(
    [
        ('model_loss_history',                   'Loss - Training Data',                      (0,5.0)),
        ('model_holdout_loss_history',           'Loss - Holdout Data',                       (0,5.0)),
        ('model_pol_total_loss_history',         'Sum of Policy Losses - Training Data',      (0,5.0)),
        ('model_holdout_pol_total_loss_history', 'Sum of Policy Losses - Holdout Data',       (0,5.0)),
        ('model_pol_var_loss_history',           'Variance of Policy Losses - Training Data', (0,0.02)),
        ('model_holdout_pol_var_loss_history',   'Variance of Policy Losses - Holdout Data',  (0,0.02)),
    ],
    [[
        ((HO025, HO026, HO027), 'No REx'),
        ((HO028, HO029, HO030), 'REx: $\\beta=5.0$'),
        ((HO031, HO032, HO033), 'REx: $\\beta=10.0$'),
        ((HO034, HO035, HO036), 'REx: $\\beta=20.0$'),
    ]],
    (3,2)
)

# %%
plot_experiment_metrics(
    [
        ('model_train_loss_history',           'Total Loss',                 (-210,35)),
        ('model_train_core_loss_history',      'Core Loss',                  (-210,35)),
        ('model_train_pol_total_loss_history', 'Sum of Policy Losses',       (-40,40)),
        ('model_train_pol_var_loss_history',   'Variance of Policy Losses',  (0,2)),
        ('model_train_decay_loss_history',     'Weight Regularisation Loss', (0,2.5)),
        ('model_train_var_lim_loss_history',   'Variance Bounding Loss',     (0,2)),
    ],
    [[
        ((HO034, HO035, HO036), 'REx: $\\beta=20.0$'),
        ((HO031, HO032, HO033), 'REx: $\\beta=10.0$'),
        ((HO028, HO029, HO030), 'REx: $\\beta=5.0$'),
        ((HO025, HO026, HO027), 'No REx'),
    ]],
    (3,2),
    x_label='Training Batches',
)
