# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dogo.results import get_score, get_experiment_details

# %%
plt.rc('font', size=16)

# %%
def plot_score(results_dicts, metric, title):
    fig, ax = plt.subplots(1, 1, figsize=(10,10))

    if len(results_dicts) == 2:
        labels = ["                            All Data", ""]
    elif len(results_dicts) == 6:
        labels = ["                            All Data", "",  "                            Training Data", " ", "                            Heldout Data", "  "]
    
    barlist = ax.bar(
        labels,
        [i[metric] for i in results_dicts]
    )

    for i in range(0, len(results_dicts), 2):
        barlist[i].set_color('#1f77b4')
    barlist[0].set_label('No REx')

    for i in range(1, len(results_dicts), 2):
        barlist[i].set_color('#ff7f0e')
    barlist[1].set_label('REx')

    ax.set_title(title)
    ax.set_ylabel(metric)
    # ax.set_ylim(0, 60)
    ax.legend()
    # ax.tick_params(axis='x', labelrotation=45)

    patches = ax.patches
    for rect in patches:
        label = f'{rect.get_height():.4f}'
        ax.text(
            rect.get_x() + rect.get_width() / 2, rect.get_height(), label, ha="center", va="bottom", fontdict={'size': 16}
        )

# %% [markdown]
# # MP047/MP049 and D3RLPY-PEP2

# %%
mp047_d3rlpy_pep2 = get_score("MP047", "D3RLPY-PEP2")
mp049_d3rlpy_pep2 = get_score("MP049", "D3RLPY-PEP2")

# %%
plot_score([mp047_d3rlpy_pep2, mp049_d3rlpy_pep2], 'reward_mse', 'MP047/MP049 - D3RLPY-PEP2')

# %%
plot_score([mp047_d3rlpy_pep2, mp049_d3rlpy_pep2], 'observation_mse', 'MP047/MP049 - D3RLPY-PEP2')

# %%
plot_score([mp047_d3rlpy_pep2, mp049_d3rlpy_pep2], 'log_prob', 'MP047/MP049 - D3RLPY-PEP2')

# %% [markdown]
# # MP047/MP049 and SAC-PAP3

# %%
mp047_sac_pap3 = get_score("MP047", "SAC-PAP3")
mp049_sac_pap3 = get_score("MP049", "SAC-PAP3")

# %%
plot_score([mp047_sac_pap3, mp049_sac_pap3], 'reward_mse', 'MP047/MP049 - SAC-PAP3')

# %%
plot_score([mp047_sac_pap3, mp049_sac_pap3], 'observation_mse', 'MP047/MP049 - SAC-PAP3')

# %%
plot_score([mp047_sac_pap3, mp049_sac_pap3], 'log_prob', 'MP047/MP049 - SAC-PAP3')

# %% [markdown]
# # MP062/MP063 and SAC-PAP3

# %%
mp062_sac_pap3 = get_score("MP062", "SAC-PAP3")
mp063_sac_pap3 = get_score("MP063", "SAC-PAP3")

# %%
plot_score([mp062_sac_pap3, mp063_sac_pap3], 'reward_mse', 'MP062/MP063 - SAC-PAP3')

# %%
plot_score([mp062_sac_pap3, mp063_sac_pap3], 'observation_mse', 'MP062/MP063 - SAC-PAP3')

# %%
plot_score([mp062_sac_pap3, mp063_sac_pap3], 'log_prob', 'MP062/MP063 - SAC-PAP3')

# %% [markdown]
# # MP062/MP063 and D3RLPY-PEP2

# %%
mp062_d3rlpy_pep2 = get_score("MP062", "D3RLPY-PEP2")
mp063_d3rlpy_pep2 = get_score("MP063", "D3RLPY-PEP2")

# %%
plot_score([mp062_d3rlpy_pep2, mp063_d3rlpy_pep2], 'reward_mse', 'MP062/MP063 - D3RLPY-PEP2')

# %%
plot_score([mp062_d3rlpy_pep2, mp063_d3rlpy_pep2], 'observation_mse', 'MP062/MP063 - D3RLPY-PEP2')

# %%
plot_score([mp062_d3rlpy_pep2, mp063_d3rlpy_pep2], 'log_prob', 'MP062/MP063 - D3RLPY-PEP2')

# %% [markdown]
# # MP068-MP069, MP078 and D3RLPY-PEP3

# %%
mp0068_d3rlpy_pep3      = get_score("MP068", "D3RLPY-PEP3")
mp0068_d3rlpy_pep3_p0_2 = get_score("MP068", "D3RLPY-PEP3-P0-2")
mp0068_d3rlpy_pep3_p3   = get_score("MP068", "D3RLPY-PEP3-P3")

# %%
mp0069_d3rlpy_pep3      = get_score("MP069", "D3RLPY-PEP3")
mp0069_d3rlpy_pep3_p0_2 = get_score("MP069", "D3RLPY-PEP3-P0-2")
mp0069_d3rlpy_pep3_p3   = get_score("MP069", "D3RLPY-PEP3-P3")

# %%
mp0078_d3rlpy_pep3      = get_score("MP078", "D3RLPY-PEP3")
mp0078_d3rlpy_pep3_p0_2 = get_score("MP078", "D3RLPY-PEP3-P0-2")
mp0078_d3rlpy_pep3_p3   = get_score("MP078", "D3RLPY-PEP3-P3")

# %%
plot_score([mp0068_d3rlpy_pep3, mp0069_d3rlpy_pep3, mp0068_d3rlpy_pep3_p0_2, mp0069_d3rlpy_pep3_p0_2, mp0068_d3rlpy_pep3_p3, mp0069_d3rlpy_pep3_p3], 'reward_mse', 'MP068/MP069')

# %%
plot_score([mp0068_d3rlpy_pep3, mp0078_d3rlpy_pep3, mp0068_d3rlpy_pep3_p0_2, mp0078_d3rlpy_pep3_p0_2, mp0068_d3rlpy_pep3_p3, mp0078_d3rlpy_pep3_p3], 'reward_mse', 'MP068/MP078')

# %%
plot_score([mp0068_d3rlpy_pep3, mp0069_d3rlpy_pep3, mp0068_d3rlpy_pep3_p0_2, mp0069_d3rlpy_pep3_p0_2, mp0068_d3rlpy_pep3_p3, mp0069_d3rlpy_pep3_p3], 'observation_mse', 'MP068/MP069')

# %%
plot_score([mp0068_d3rlpy_pep3, mp0069_d3rlpy_pep3, mp0068_d3rlpy_pep3_p0_2, mp0069_d3rlpy_pep3_p0_2, mp0068_d3rlpy_pep3_p3, mp0069_d3rlpy_pep3_p3], 'log_prob', 'MP068/MP069')

# %% [markdown]
# # MP070-MP071, MP079 and D3RLPY-PEP4

# %%
mp0070_d3rlpy_pep4      = get_score("MP070", "D3RLPY-PEP4")
mp0070_d3rlpy_pep4_p0_3 = get_score("MP070", "D3RLPY-PEP4-P0-3")
mp0070_d3rlpy_pep4_p3   = get_score("MP070", "D3RLPY-PEP4-P4")

# %%
mp0071_d3rlpy_pep4      = get_score("MP071", "D3RLPY-PEP4")
mp0071_d3rlpy_pep4_p0_3 = get_score("MP071", "D3RLPY-PEP4-P0-3")
mp0071_d3rlpy_pep4_p4   = get_score("MP071", "D3RLPY-PEP4-P4")

# %%
mp0079_d3rlpy_pep4      = get_score("MP079", "D3RLPY-PEP4")
mp0079_d3rlpy_pep4_p0_3 = get_score("MP079", "D3RLPY-PEP4-P0-3")
mp0079_d3rlpy_pep4_p4   = get_score("MP079", "D3RLPY-PEP4-P4")

# %%
plot_score([mp0070_d3rlpy_pep4, mp0071_d3rlpy_pep4, mp0070_d3rlpy_pep4_p0_3, mp0071_d3rlpy_pep4_p0_3, mp0070_d3rlpy_pep4_p3, mp0071_d3rlpy_pep4_p4], 'reward_mse', 'MP070/MP071')

# %%
plot_score([mp0070_d3rlpy_pep4, mp0079_d3rlpy_pep4, mp0070_d3rlpy_pep4_p0_3, mp0079_d3rlpy_pep4_p0_3, mp0070_d3rlpy_pep4_p3, mp0079_d3rlpy_pep4_p4], 'reward_mse', 'MP070/MP079')

# %%
plot_score([mp0070_d3rlpy_pep4, mp0071_d3rlpy_pep4, mp0070_d3rlpy_pep4_p0_3, mp0071_d3rlpy_pep4_p0_3, mp0070_d3rlpy_pep4_p3, mp0071_d3rlpy_pep4_p4], 'observation_mse', 'MP070/MP071')

# %%
plot_score([mp0070_d3rlpy_pep4, mp0079_d3rlpy_pep4, mp0070_d3rlpy_pep4_p0_3, mp0079_d3rlpy_pep4_p0_3, mp0070_d3rlpy_pep4_p3, mp0079_d3rlpy_pep4_p4], 'observation_mse', 'MP070/MP079')

# %%
plot_score([mp0070_d3rlpy_pep4, mp0071_d3rlpy_pep4, mp0070_d3rlpy_pep4_p0_3, mp0071_d3rlpy_pep4_p0_3, mp0070_d3rlpy_pep4_p3, mp0071_d3rlpy_pep4_p4], 'log_prob', 'MP070/MP071')

# %%
plot_score([mp0070_d3rlpy_pep4, mp0079_d3rlpy_pep4, mp0070_d3rlpy_pep4_p0_3, mp0079_d3rlpy_pep4_p0_3, mp0070_d3rlpy_pep4_p3, mp0079_d3rlpy_pep4_p4], 'log_prob', 'MP070/MP079')

# %% [markdown]
# # MP086-MP087 and D3RLPY-PEP4

# %%
mp0086_d3rlpy_pep4      = get_score("MP086", "D3RLPY-PEP4")
mp0086_d3rlpy_pep4_p0_3 = get_score("MP086", "D3RLPY-PEP4-P0-3")
mp0086_d3rlpy_pep4_p4   = get_score("MP086", "D3RLPY-PEP4-P4")

# %%
mp0087_d3rlpy_pep4      = get_score("MP087", "D3RLPY-PEP4")
mp0087_d3rlpy_pep4_p0_3 = get_score("MP087", "D3RLPY-PEP4-P0-3")
mp0087_d3rlpy_pep4_p4   = get_score("MP087", "D3RLPY-PEP4-P4")

# %%
plot_score([mp0086_d3rlpy_pep4, mp0087_d3rlpy_pep4, mp0086_d3rlpy_pep4_p0_3, mp0087_d3rlpy_pep4_p0_3, mp0086_d3rlpy_pep4_p4, mp0087_d3rlpy_pep4_p4], 'reward_mse', 'MP088/MP089')

# %%
plot_score([mp0086_d3rlpy_pep4, mp0087_d3rlpy_pep4, mp0086_d3rlpy_pep4_p0_3, mp0087_d3rlpy_pep4_p0_3, mp0086_d3rlpy_pep4_p4, mp0087_d3rlpy_pep4_p4], 'observation_mse', 'MP088/MP089')

# %%
plot_score([mp0086_d3rlpy_pep4, mp0087_d3rlpy_pep4, mp0086_d3rlpy_pep4_p0_3, mp0087_d3rlpy_pep4_p0_3, mp0086_d3rlpy_pep4_p4, mp0087_d3rlpy_pep4_p4], 'log_prob', 'MP088/MP089')

# %% [markdown]
# # MP088-MP089 and D3RLPY-PEP4

# %%
mp0088_d3rlpy_pep4      = get_score("MP088", "D3RLPY-PEP4")
mp0088_d3rlpy_pep4_p1_4 = get_score("MP088", "D3RLPY-PEP4-P1-4")
mp0088_d3rlpy_pep4_p0   = get_score("MP088", "D3RLPY-PEP4-P0")

# %%
mp0089_d3rlpy_pep4      = get_score("MP089", "D3RLPY-PEP4")
mp0089_d3rlpy_pep4_p1_4 = get_score("MP089", "D3RLPY-PEP4-P1-4")
mp0089_d3rlpy_pep4_p0   = get_score("MP089", "D3RLPY-PEP4-P0")

# %%
plot_score([mp0088_d3rlpy_pep4, mp0089_d3rlpy_pep4, mp0088_d3rlpy_pep4_p1_4, mp0089_d3rlpy_pep4_p1_4, mp0088_d3rlpy_pep4_p0, mp0089_d3rlpy_pep4_p0], 'reward_mse', 'MP088/MP089')

# %%
plot_score([mp0088_d3rlpy_pep4, mp0089_d3rlpy_pep4, mp0088_d3rlpy_pep4_p1_4, mp0089_d3rlpy_pep4_p1_4, mp0088_d3rlpy_pep4_p0, mp0089_d3rlpy_pep4_p0], 'observation_mse', 'MP088/MP089')

# %%
plot_score([mp0088_d3rlpy_pep4, mp0089_d3rlpy_pep4, mp0088_d3rlpy_pep4_p1_4, mp0089_d3rlpy_pep4_p1_4, mp0088_d3rlpy_pep4_p0, mp0089_d3rlpy_pep4_p0], 'log_prob', 'MP088/MP089')

# %% [markdown]
# # D3RLPY-PAP5

# %%
d3rlpy_pap5_core_datasets = [
    "D3RLPY-PAP5-P0-3",
    "D3RLPY-PAP5-P1-4",
    "D3RLPY-PAP5-P0_100000",
    "D3RLPY-PAP5-P4_100000",
    "D3RLPY-PAP5_100000"
]

d3rlpy_pap5_training_datasets = [
    "D3RLPY-PAP5-P0_25000",
    "D3RLPY-PAP5-P1_25000",
    "D3RLPY-PAP5-P2_25000",
    "D3RLPY-PAP5-P3_25000",
    "D3RLPY-PAP5-P4_25000",
]

d3rlpy_pap5_pol_datasets = [
    "D3RLPY-PAP5-P0_100000",
    "D3RLPY-PAP5-P1_100000",
    "D3RLPY-PAP5-P2_100000",
    "D3RLPY-PAP5-P3_100000",
    "D3RLPY-PAP5-P4_100000",
]

d3rlpy_pap5_datasets = set(d3rlpy_pap5_core_datasets).union(set(d3rlpy_pap5_training_datasets)).union(set(d3rlpy_pap5_pol_datasets))
d3rlpy_pap5_experiments = ["MP100", "MP101", "MP102", "MP103", "MP104", "MP105", "MP106", "MP107", "MP108", "MP109", "MP110", "MP111", "MP124", "MP125", "MP126"]

# %%
d3rlpy_pap5_rex_scores = {}
for exp in d3rlpy_pap5_experiments:
    exp_details = get_experiment_details(exp)
    key = ' - '.join((exp_details.name, exp_details.dataset, f'REx: {exp_details.rex}'))
    for data in d3rlpy_pap5_datasets:
        score = get_score(exp, data)
        score['rex'] = exp_details.rex
        score['seed'] = exp_details.seed
        score['training_dataset'] = exp_details.dataset
        d3rlpy_pap5_rex_scores[(key, data)] = score
d3rlpy_pap5_rex_scores_df = pd.DataFrame().from_dict(d3rlpy_pap5_rex_scores, orient='index')

# %%
d3rlpy_pap5_rex_scores_groups = (
    d3rlpy_pap5_rex_scores_df[['training_dataset', 'rex', 'seed', 'observation_mse', 'reward_mse', 'log_prob', 'next_obs_log_prob', 'reward_log_prob']].
    reset_index().rename(columns={'level_0': 'experiment', 'level_1': 'evaluation_dataset'}).
    groupby(['training_dataset', 'rex', 'evaluation_dataset'])
    # groupby(['training_dataset', 'rex', 'evaluation_dataset', 'seed'])
)
d3rlpy_pap5_rex_scores_avgs_df = d3rlpy_pap5_rex_scores_groups.mean().reset_index()
d3rlpy_pap5_rex_scores_stds_df = d3rlpy_pap5_rex_scores_groups.std().reset_index().replace(np.NaN, 0)

# %%
fig, ax = plt.subplots(1, 3, figsize=(35,10))

training_datasets = d3rlpy_pap5_core_datasets
evaluation_datasets = d3rlpy_pap5_core_datasets
mask = (
    (d3rlpy_pap5_rex_scores_avgs_df['training_dataset'].isin(training_datasets)) &
    (d3rlpy_pap5_rex_scores_avgs_df['rex'] == False) &
    # (d3rlpy_pap5_rex_scores_avgs_df['seed'] == 1443) &
    (d3rlpy_pap5_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets))
)

for i, metric in enumerate(['observation_mse', 'reward_mse', 'log_prob']):
    metric_df = d3rlpy_pap5_rex_scores_avgs_df.loc[mask].pivot_table(columns='training_dataset', index='evaluation_dataset', values=metric).loc[evaluation_datasets][training_datasets]
    ax[i].matshow(metric_df, cmap='RdYlGn' if 'log_prob' in metric else 'RdYlGn_r')
    for (x, y), value in np.ndenumerate(metric_df):
        ax[i].text(y, x, f"{value:.6f}", va="center", ha="center", c='k')
    ax[i].set_title(metric)
    ax[i].set_xlabel('Training Data')
    ax[i].set_ylabel('Evaluation Data')
    ax[i].set_xticks(np.arange(0,5))
    ax[i].set_yticks(np.arange(0,5))
    ax[i].set_xticklabels(metric_df.columns.values, rotation=45)
    ax[i].set_yticklabels(metric_df.index.values, rotation=45)
pass

# %%
fig, ax = plt.subplots(1, 5, figsize=(40,10))

training_datasets = ['D3RLPY-PAP5-P0-3', 'D3RLPY-PAP5-P1-4']
evaluation_datasets = d3rlpy_pap5_core_datasets
mask = (
    (d3rlpy_pap5_rex_scores_avgs_df['training_dataset'].isin(training_datasets)) &
    # (d3rlpy_pap5_rex_scores_avgs_df['seed'] == 1443) &
    (d3rlpy_pap5_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets))
)

for i, metric in enumerate(['observation_mse', 'reward_mse', 'log_prob', 'next_obs_log_prob', 'reward_log_prob']):
    metric_df = d3rlpy_pap5_rex_scores_avgs_df.loc[mask].pivot_table(columns=['training_dataset', 'rex'], index='evaluation_dataset', values=metric).loc[evaluation_datasets][training_datasets]
    ax[i].matshow(metric_df, cmap='RdYlGn' if 'log_prob' in metric else 'RdYlGn_r')
    for (x, y), value in np.ndenumerate(metric_df):
        ax[i].text(y, x, f"{value:.6f}", va="center", ha="center", c='k')
    ax[i].set_title(metric)
    ax[i].set_xlabel('Training Data')
    ax[i].set_ylabel('Evaluation Data')
    ax[i].set_xticks(np.arange(0,4))
    ax[i].set_yticks(np.arange(0,5))
    ax[i].set_xticklabels([f'{i[0]} - REx: {i[1]}' for i in metric_df.columns], rotation=45)
    ax[i].set_yticklabels(metric_df.index.values, rotation=45)
pass

# %%
fig, ax = plt.subplots(1, 5, figsize=(40,10))

training_datasets = ['D3RLPY-PAP5-P0-3', 'D3RLPY-PAP5-P1-4']
evaluation_datasets = d3rlpy_pap5_pol_datasets
mask = (
    (d3rlpy_pap5_rex_scores_avgs_df['training_dataset'].isin(training_datasets)) &
    # (d3rlpy_pap5_rex_scores_avgs_df['seed'] == 1443) &
    (d3rlpy_pap5_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets))
)

for i, metric in enumerate(['observation_mse', 'reward_mse', 'log_prob', 'next_obs_log_prob', 'reward_log_prob']):
    metric_df = d3rlpy_pap5_rex_scores_avgs_df.loc[mask].pivot_table(columns=['training_dataset', 'rex'], index='evaluation_dataset', values=metric).loc[evaluation_datasets][training_datasets]
    ax[i].matshow(metric_df, cmap='RdYlGn' if 'log_prob' in metric else 'RdYlGn_r')
    for (x, y), value in np.ndenumerate(metric_df):
        ax[i].text(y, x, f"{value:.6f}", va="center", ha="center", c='k')
    ax[i].set_title(metric)
    ax[i].set_xlabel('Training Data')
    ax[i].set_ylabel('Evaluation Data')
    ax[i].set_xticks(np.arange(0,4))
    ax[i].set_yticks(np.arange(0,5))
    ax[i].set_xticklabels([f'{i[0]} - REx: {i[1]}' for i in metric_df.columns], rotation=45)
    ax[i].set_yticklabels(metric_df.index.values, rotation=45)
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-PAP5-P0-3', 'D3RLPY-PAP5-P1-4']
evaluation_datasets = [
    'D3RLPY-PAP5-P0_25000',
    'D3RLPY-PAP5-P1_25000',
    'D3RLPY-PAP5-P2_25000',
    'D3RLPY-PAP5-P3_25000',
    'D3RLPY-PAP5-P4_25000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_pap5_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_pap5_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_pap5_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_pap5_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'observation_mse'
        )
        plot_mean = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets[:4], plot_mean[:4], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets[1:], plot_mean[1:], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Training Dataset')
ax.set_ylabel('Observation MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-PAP5-P0-3', 'D3RLPY-PAP5-P1-4']
evaluation_datasets = [
    'D3RLPY-PAP5-P0_25000',
    'D3RLPY-PAP5-P1_25000',
    'D3RLPY-PAP5-P2_25000',
    'D3RLPY-PAP5-P3_25000',
    'D3RLPY-PAP5-P4_25000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_pap5_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_pap5_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_pap5_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_pap5_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'reward_mse'
        )
        plot_mean = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets[:4], plot_mean[:4], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets[1:], plot_mean[1:], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Training Dataset')
ax.set_ylabel('Reward MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-PAP5-P0-3', 'D3RLPY-PAP5-P1-4']
evaluation_datasets = [
    'D3RLPY-PAP5-P0_25000',
    'D3RLPY-PAP5-P1_25000',
    'D3RLPY-PAP5-P2_25000',
    'D3RLPY-PAP5-P3_25000',
    'D3RLPY-PAP5-P4_25000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_pap5_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_pap5_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_pap5_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_pap5_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'log_prob'
        )
        plot_mean = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets[:4], plot_mean[:4], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets[1:], plot_mean[1:], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Training Dataset')
ax.set_ylabel('Log Probability')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-PAP5-P0-3', 'D3RLPY-PAP5-P1-4']
evaluation_datasets = [
    'D3RLPY-PAP5-P0_100000',
    'D3RLPY-PAP5-P1_100000',
    'D3RLPY-PAP5-P2_100000',
    'D3RLPY-PAP5-P3_100000',
    'D3RLPY-PAP5-P4_100000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_pap5_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_pap5_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_pap5_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_pap5_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'observation_mse'
        )
        plot_mean = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)

        # if 'P0' in t_ds:
        #     p = ax.plot(evaluation_datasets[:4], plot_mean[:4], label=label, ls='--' if rex else '-')
        #     ax.fill_between(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4], alpha=0.2)
        # else:
        #     p = ax.plot(evaluation_datasets[1:], plot_mean[1:], label=label, ls='--' if rex else '-')
        #     ax.fill_between(evaluation_datasets[1:], plot_mean[1:]-2*plot_std[1:], plot_mean[1:]+2*plot_std[1:], alpha=0.2)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Observation MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-PAP5-P0-3', 'D3RLPY-PAP5-P1-4']
evaluation_datasets = [
    'D3RLPY-PAP5-P0_100000',
    'D3RLPY-PAP5-P1_100000',
    'D3RLPY-PAP5-P2_100000',
    'D3RLPY-PAP5-P3_100000',
    'D3RLPY-PAP5-P4_100000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_pap5_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_pap5_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_pap5_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_pap5_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'reward_mse'
        )
        plot_mean = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)

        # if 'P0' in t_ds:
        #     p = ax.plot(evaluation_datasets[:4], plot_mean[:4], label=label, ls='--' if rex else '-')
        #     ax.fill_between(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4], alpha=0.2)
        # else:
        #     p = ax.plot(evaluation_datasets[1:], plot_mean[1:], label=label, ls='--' if rex else '-')
        #     ax.fill_between(evaluation_datasets[1:], plot_mean[1:]-2*plot_std[1:], plot_mean[1:]+2*plot_std[1:], alpha=0.2)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Reward MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-PAP5-P0-3', 'D3RLPY-PAP5-P1-4']
evaluation_datasets = [
    'D3RLPY-PAP5-P0_100000',
    'D3RLPY-PAP5-P1_100000',
    'D3RLPY-PAP5-P2_100000',
    'D3RLPY-PAP5-P3_100000',
    'D3RLPY-PAP5-P4_100000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_pap5_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_pap5_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_pap5_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_pap5_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'log_prob'
        )
        plot_mean = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_pap5_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)

        # if 'P0' in t_ds:
        #     p = ax.plot(evaluation_datasets[:4], plot_mean[:4], label=label, ls='--' if rex else '-')
        #     ax.fill_between(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4], alpha=0.2)
        # else:
        #     p = ax.plot(evaluation_datasets[1:], plot_mean[1:], label=label, ls='--' if rex else '-')
        #     ax.fill_between(evaluation_datasets[1:], plot_mean[1:]-2*plot_std[1:], plot_mean[1:]+2*plot_std[1:], alpha=0.2)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Log Probability')
ax.legend()

# %% [markdown]
# # D3RLPY-MP1

# %%
d3rlpy_mp1_core_datasets = [
    "D3RLPY-MP1-P0-3",
    "D3RLPY-MP1-P1-4",
    "D3RLPY-MP1-P0_100000",
    "D3RLPY-MP1-P4_100000",
    "D3RLPY-MP1_100000"
] #, "D3RLPY-MP1",  "D3RLPY-MP1-P0_25000", "D3RLPY-MP1-P4_25000", ]

d3rlpy_mp1_training_datasets = [
    "D3RLPY-MP1-P0_25000",
    "D3RLPY-MP1-P1_25000",
    "D3RLPY-MP1-P2_25000",
    "D3RLPY-MP1-P3_25000",
    "D3RLPY-MP1-P4_25000",
]

d3rlpy_mp1_pol_datasets = [
    "D3RLPY-MP1-P0_100000",
    "D3RLPY-MP1-P1_100000",
    "D3RLPY-MP1-P2_100000",
    "D3RLPY-MP1-P3_100000",
    "D3RLPY-MP1-P4_100000",
]

d3rlpy_mp1_datasets = set(d3rlpy_mp1_core_datasets).union(set(d3rlpy_mp1_training_datasets)).union(set(d3rlpy_mp1_pol_datasets))
d3rlpy_mp1_experiments = ["MP112", "MP113", "MP114", "MP115", "MP116", "MP117", "MP118", "MP119", "MP120", "MP121", "MP122", "MP123", "MP127", "MP128", "MP129"]

# %%
d3rlpy_mp1_rex_scores = {}
for exp in d3rlpy_mp1_experiments:
    exp_details = get_experiment_details(exp)
    key = ' - '.join((exp_details.name, exp_details.dataset, f'REx: {exp_details.rex}'))
    for data in d3rlpy_mp1_datasets:
        score = get_score(exp, data)
        score['rex'] = exp_details.rex
        score['seed'] = exp_details.seed
        score['training_dataset'] = exp_details.dataset
        d3rlpy_mp1_rex_scores[(key, data)] = score
d3rlpy_mp1_rex_scores_df = pd.DataFrame().from_dict(d3rlpy_mp1_rex_scores, orient='index')

# %%
d3rlpy_mp1_rex_scores_groups = (
    d3rlpy_mp1_rex_scores_df[['training_dataset', 'rex', 'seed', 'observation_mse', 'reward_mse', 'log_prob', 'next_obs_log_prob', 'reward_log_prob']].
    reset_index().rename(columns={'level_0': 'experiment', 'level_1': 'evaluation_dataset'}).
    groupby(['training_dataset', 'rex', 'evaluation_dataset'])
    # groupby(['training_dataset', 'rex', 'evaluation_dataset', 'seed'])
)
d3rlpy_mp1_rex_scores_avgs_df = d3rlpy_mp1_rex_scores_groups.mean().reset_index()
d3rlpy_mp1_rex_scores_stds_df = d3rlpy_mp1_rex_scores_groups.std().reset_index().replace(np.NaN, 0)

# %%
fig, ax = plt.subplots(1, 3, figsize=(35,10))

training_datasets = d3rlpy_mp1_core_datasets
evaluation_datasets = d3rlpy_mp1_core_datasets
mask = (
    (d3rlpy_mp1_rex_scores_avgs_df['training_dataset'].isin(training_datasets)) &
    (d3rlpy_mp1_rex_scores_avgs_df['rex'] == False) &
    # (d3rlpy_mp1_rex_scores_avgs_df['seed'] == 1443) &
    (d3rlpy_mp1_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets))
)

for i, metric in enumerate(['observation_mse', 'reward_mse', 'log_prob']):
    metric_df = d3rlpy_mp1_rex_scores_avgs_df.loc[mask].pivot_table(columns='training_dataset', index='evaluation_dataset', values=metric).loc[evaluation_datasets][training_datasets]
    ax[i].matshow(metric_df, cmap='RdYlGn' if 'log_prob' in metric else 'RdYlGn_r')
    for (x, y), value in np.ndenumerate(metric_df):
        ax[i].text(y, x, f"{value:.6f}", va="center", ha="center", c='k')
    ax[i].set_title(metric)
    ax[i].set_xlabel('Training Data')
    ax[i].set_ylabel('Evaluation Data')
    ax[i].set_xticks(np.arange(0,5))
    ax[i].set_yticks(np.arange(0,5))
    ax[i].set_xticklabels(metric_df.columns.values, rotation=45)
    ax[i].set_yticklabels(metric_df.index.values, rotation=45)
pass

# %%
fig, ax = plt.subplots(1, 5, figsize=(40,10))

training_datasets = ['D3RLPY-MP1-P0-3', 'D3RLPY-MP1-P1-4']
evaluation_datasets = d3rlpy_mp1_core_datasets
mask = (
    (d3rlpy_mp1_rex_scores_avgs_df['training_dataset'].isin(training_datasets)) &
    # (d3rlpy_mp1_rex_scores_avgs_df['seed'] == 1443) &
    (d3rlpy_mp1_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets))
)

for i, metric in enumerate(['observation_mse', 'reward_mse', 'log_prob', 'next_obs_log_prob', 'reward_log_prob']):
    metric_df = d3rlpy_mp1_rex_scores_avgs_df.loc[mask].pivot_table(columns=['training_dataset', 'rex'], index='evaluation_dataset', values=metric).loc[evaluation_datasets][training_datasets]
    ax[i].matshow(metric_df, cmap='RdYlGn' if 'log_prob' in metric else 'RdYlGn_r')
    for (x, y), value in np.ndenumerate(metric_df):
        ax[i].text(y, x, f"{value:.6f}", va="center", ha="center", c='k')
    ax[i].set_title(metric)
    ax[i].set_xlabel('Training Data')
    ax[i].set_ylabel('Evaluation Data')
    ax[i].set_xticks(np.arange(0,4))
    ax[i].set_yticks(np.arange(0,5))
    ax[i].set_xticklabels([f'{i[0]} - REx: {i[1]}' for i in metric_df.columns], rotation=45)
    ax[i].set_yticklabels(metric_df.index.values, rotation=45)
pass

# %%
fig, ax = plt.subplots(1, 5, figsize=(40,10))

training_datasets = ['D3RLPY-MP1-P0-3', 'D3RLPY-MP1-P1-4']
evaluation_datasets = d3rlpy_mp1_pol_datasets
mask = (
    (d3rlpy_mp1_rex_scores_avgs_df['training_dataset'].isin(training_datasets)) &
    (d3rlpy_mp1_rex_scores_avgs_df['seed'] == 1443) &
    (d3rlpy_mp1_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets))
)

for i, metric in enumerate(['observation_mse', 'reward_mse', 'log_prob', 'next_obs_log_prob', 'reward_log_prob']):
    metric_df = d3rlpy_mp1_rex_scores_avgs_df.loc[mask].pivot_table(columns=['training_dataset', 'rex'], index='evaluation_dataset', values=metric).loc[evaluation_datasets][training_datasets]
    ax[i].matshow(metric_df, cmap='RdYlGn' if 'log_prob' in metric else 'RdYlGn_r')
    for (x, y), value in np.ndenumerate(metric_df):
        ax[i].text(y, x, f"{value:.6f}", va="center", ha="center", c='k')
    ax[i].set_title(metric)
    ax[i].set_xlabel('Training Data')
    ax[i].set_ylabel('Evaluation Data')
    ax[i].set_xticks(np.arange(0,4))
    ax[i].set_yticks(np.arange(0,5))
    ax[i].set_xticklabels([f'{i[0]} - REx: {i[1]}' for i in metric_df.columns], rotation=45)
    ax[i].set_yticklabels(metric_df.index.values, rotation=45)
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-MP1-P0-3', 'D3RLPY-MP1-P1-4']
evaluation_datasets = [
    'D3RLPY-MP1-P0_25000',
    'D3RLPY-MP1-P1_25000',
    'D3RLPY-MP1-P2_25000',
    'D3RLPY-MP1-P3_25000',
    'D3RLPY-MP1-P4_25000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_mp1_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_mp1_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_mp1_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_mp1_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'observation_mse'
        )
        plot_mean = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets[:4], plot_mean[:4], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets[1:], plot_mean[1:], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Training Dataset')
ax.set_ylabel('Observation MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-MP1-P0-3', 'D3RLPY-MP1-P1-4']
evaluation_datasets = [
    'D3RLPY-MP1-P0_25000',
    'D3RLPY-MP1-P1_25000',
    'D3RLPY-MP1-P2_25000',
    'D3RLPY-MP1-P3_25000',
    'D3RLPY-MP1-P4_25000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_mp1_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_mp1_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_mp1_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_mp1_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'reward_mse'
        )
        plot_mean = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets[:4], plot_mean[:4], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets[1:], plot_mean[1:], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Training Dataset')
ax.set_ylabel('Reward MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-MP1-P0-3', 'D3RLPY-MP1-P1-4']
evaluation_datasets = [
    'D3RLPY-MP1-P0_25000',
    'D3RLPY-MP1-P1_25000',
    'D3RLPY-MP1-P2_25000',
    'D3RLPY-MP1-P3_25000',
    'D3RLPY-MP1-P4_25000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_mp1_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_mp1_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_mp1_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_mp1_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'log_prob'
        )
        plot_mean = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets[:4], plot_mean[:4], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets[1:], plot_mean[1:], label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Training Dataset')
ax.set_ylabel('Log Probability')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-MP1-P0-3', 'D3RLPY-MP1-P1-4']
evaluation_datasets = [
    'D3RLPY-MP1-P0_100000',
    'D3RLPY-MP1-P1_100000',
    'D3RLPY-MP1-P2_100000',
    'D3RLPY-MP1-P3_100000',
    'D3RLPY-MP1-P4_100000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_mp1_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_mp1_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_mp1_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_mp1_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'observation_mse'
        )
        plot_mean = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Observation MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-MP1-P0-3', 'D3RLPY-MP1-P1-4']
evaluation_datasets = [
    'D3RLPY-MP1-P0_100000',
    'D3RLPY-MP1-P1_100000',
    'D3RLPY-MP1-P2_100000',
    'D3RLPY-MP1-P3_100000',
    'D3RLPY-MP1-P4_100000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_mp1_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_mp1_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_mp1_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_mp1_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'reward_mse'
        )
        plot_mean = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Reward MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

training_datasets = ['D3RLPY-MP1-P0-3', 'D3RLPY-MP1-P1-4']
evaluation_datasets = [
    'D3RLPY-MP1-P0_100000',
    'D3RLPY-MP1-P1_100000',
    'D3RLPY-MP1-P2_100000',
    'D3RLPY-MP1-P3_100000',
    'D3RLPY-MP1-P4_100000',
]
for t_ds in training_datasets:
    for rex in [False, True]:
        mask = (
            (d3rlpy_mp1_rex_scores_avgs_df['training_dataset'] == t_ds) &
            (d3rlpy_mp1_rex_scores_avgs_df['rex'] == rex) &
            # (d3rlpy_mp1_rex_scores_avgs_df['seed'] == 1443) &
            (d3rlpy_mp1_rex_scores_avgs_df['evaluation_dataset'].isin(evaluation_datasets)), 'log_prob'
        )
        plot_mean = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        plot_std = d3rlpy_mp1_rex_scores_avgs_df.loc[mask]
        label = f'{t_ds} - REx: {rex}'
        if 'P0' in t_ds:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
            # ax.errorbar(evaluation_datasets[:4], plot_mean[:4]-plot_std[:4], plot_mean[:4]+plot_std[:4])
        else:
            p = ax.plot(evaluation_datasets, plot_mean, label=label, ls='--' if rex else '-', c=p[0].get_color() if rex else None)
ax.set_xticks(ax.get_xticks(), evaluation_datasets, rotation=45)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Log Probability')
ax.legend()

# %%
d3rlpy_mp1_scores = {}
for exp in ["MP112", "MP113", "MP114", "MP115", "MP127", "MP128", "MP129"]:
    exp_details = get_experiment_details(exp)
    key = ' - '.join((exp_details.name, exp_details.dataset, f'REx: {exp_details.rex}'))
    for data in d3rlpy_mp1_datasets:
        score = get_score(exp, data)
        d3rlpy_mp1_scores[(key, data)] = score
d3rlpy_mp1_scores_df = pd.DataFrame().from_dict(d3rlpy_mp1_scores, orient='index')

# %%
d3rlpy_mp1_no_rex_scores = {}
for exp in ["MP112", "MP114", "MP127", "MP128", "MP129"]:
    exp_details = get_experiment_details(exp)
    key = ' - '.join((exp_details.name, exp_details.dataset))
    for data in d3rlpy_mp1_datasets:
        score = get_score(exp, data)
        d3rlpy_mp1_no_rex_scores[(key, data)] = score
d3rlpy_mp1_no_rex_scores_df = pd.DataFrame().from_dict(d3rlpy_mp1_no_rex_scores, orient='index')

# %%
d3rlpy_mp1_rex_scores = {}
for exp in ["MP112", "MP113", "MP114", "MP115"]:
    exp_details = get_experiment_details(exp)
    key = ' - '.join((exp_details.name, exp_details.dataset, f'REx: {exp_details.rex}'))
    for data in d3rlpy_mp1_datasets:
        score = get_score(exp, data)
        d3rlpy_mp1_rex_scores[(key, data)] = score
d3rlpy_mp1_rex_scores_df = pd.DataFrame().from_dict(d3rlpy_mp1_rex_scores, orient='index')

# %%
fig, ax = plt.subplots(1, 3, figsize=(26,13))
for i, metric in enumerate(['observation_mse', 'reward_mse', 'log_prob']):
    metric_df = d3rlpy_mp1_no_rex_scores_df[metric].unstack()[d3rlpy_mp1_core_datasets].T
    ax[i].matshow(metric_df, cmap='RdYlGn_r'if metric != 'log_prob' else 'RdYlGn')
    for (x, y), value in np.ndenumerate(metric_df):
        ax[i].text(y, x, f"{value:.6f}", va="center", ha="center", c='k')
    ax[i].set_title(metric)
    ax[i].set_xticks(np.arange(0,5))
    ax[i].set_yticks(np.arange(0,5))
    ax[i].set_xticklabels(metric_df.columns.values, rotation=45)
    ax[i].set_yticklabels(metric_df.index.values, rotation=45)
pass

# %%
fig, ax = plt.subplots(1, 5, figsize=(40,13))
for i, metric in enumerate(['observation_mse', 'reward_mse', 'log_prob', 'next_obs_log_prob', 'reward_log_prob']):
    metric_df = d3rlpy_mp1_rex_scores_df[metric].unstack()[d3rlpy_mp1_core_datasets].T
    ax[i].matshow(metric_df, cmap='RdYlGn' if 'log_prob' in metric else 'RdYlGn_r')
    for (x, y), value in np.ndenumerate(metric_df):
        ax[i].text(y, x, f"{value:.6f}", va="center", ha="center", c='k')
    ax[i].set_title(metric)
    ax[i].set_xticks(np.arange(0,4))
    ax[i].set_yticks(np.arange(0,5))
    ax[i].set_xticklabels(metric_df.columns.values, rotation=45)
    ax[i].set_yticklabels(metric_df.index.values, rotation=45)
pass

# %%
fig, ax = plt.subplots(1, 5, figsize=(40,13))
for i, metric in enumerate(['observation_mse', 'reward_mse', 'log_prob', 'next_obs_log_prob', 'reward_log_prob']):
    metric_df = d3rlpy_mp1_rex_scores_df[metric].unstack()[d3rlpy_mp1_pol_datasets].T
    ax[i].matshow(metric_df, cmap='RdYlGn' if 'log_prob' in metric else 'RdYlGn_r')
    for (x, y), value in np.ndenumerate(metric_df):
        ax[i].text(y, x, f"{value:.6f}", va="center", ha="center", c='k')
    ax[i].set_title(metric)
    ax[i].set_xticks(np.arange(0,4))
    ax[i].set_yticks(np.arange(0,5))
    ax[i].set_xticklabels(metric_df.columns.values, rotation=45)
    ax[i].set_yticklabels(metric_df.index.values, rotation=45)
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

d3rlpy_mp1_rex_scores_obs_mse_df = d3rlpy_mp1_rex_scores_df['observation_mse'].unstack()[d3rlpy_mp1_training_datasets].T
for i in d3rlpy_mp1_rex_scores_obs_mse_df:
    if 'P0' in i:
        p = ax.plot(d3rlpy_mp1_rex_scores_obs_mse_df[i][:4], label=i, ls='--' if 'REx: True' in i else '-', c=p[0].get_color() if 'REx: True' in i else None)
    else:
        p = ax.plot(d3rlpy_mp1_rex_scores_obs_mse_df[i][1:], label=i, ls='--' if 'REx: True' in i else '-', c=p[0].get_color() if 'REx: True' in i else None)
ax.set_xticks(ax.get_xticks(), d3rlpy_mp1_training_datasets, rotation=45)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Observation MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

d3rlpy_mp1_rex_scores_obs_mse_df = d3rlpy_mp1_rex_scores_df['observation_mse'].unstack()[d3rlpy_mp1_pol_datasets].T
for i in d3rlpy_mp1_rex_scores_obs_mse_df:
    if 'P0' in i:
        p = ax.plot(d3rlpy_mp1_rex_scores_obs_mse_df[i][:4], label=i, ls='--' if 'REx: True' in i else '-', c=p[0].get_color() if 'REx: True' in i else None)
    else:
        p = ax.plot(d3rlpy_mp1_rex_scores_obs_mse_df[i][1:], label=i, ls='--' if 'REx: True' in i else '-', c=p[0].get_color() if 'REx: True' in i else None)
ax.set_xticks(ax.get_xticks(), d3rlpy_mp1_pol_datasets, rotation=45)
ax.set_xlabel('Evaluation Dataset')
ax.set_ylabel('Observation MSE')
ax.legend()
