# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('/home/ajc348/rds/hpc-work/mopo')

# %%
from itertools import zip_longest

import numpy as np
import matplotlib.pyplot as plt

from dogo.results import get_results
from dogo.plot_results import plot_experiment_metrics, plot_min_max_logvars, plot_evaluation_returns, plot_grouped_evaluation_returns, plot_min_max_penalty

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 5.0 - SAC-RT-0.25M-1 - No Additional Training

# %%
##########################################################################
# MOPO - Penalty 5.0 - Rollout Length 5 - SAC-RT-0.25M-1 - No Additional Training
##########################################################################
MQ221 = get_results("MQ221") # No REx
MQ222 = get_results("MQ222")
MQ223 = get_results("MQ223")
MQ224 = get_results("MQ224") # REx - 10.0
MQ225 = get_results("MQ225")
MQ226 = get_results("MQ226")

# %%
plot_evaluation_returns([
    MQ221,
    MQ222,
    MQ223,
    MQ224,
    MQ225,
    MQ226,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$ - Original Model', ymin=-2500, ymax=4000)

# %%
plot_grouped_evaluation_returns([
    ((MQ221, MQ222, MQ223), 'No REx'),
    ((MQ224, MQ225, MQ226), 'REx - $\\beta=10.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$ - Original Model', ymin=-2500, ymax=4000)
# Out:
# {'No REx': {'mean': -285, 'std': 157},
#  'REx - $\\beta=10.0$': {'mean': -212, 'std': 50}}

# %%
plot_evaluation_returns([
    MQ221,
    MQ222,
    MQ223,
    MQ224,
    MQ225,
    MQ226,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$ - Original Model', feature='Q_loss', ymin=0, ymax=10000)

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 10.0 - SAC-RT-0.25M-1 - No Additional Training

# %%
##########################################################################
# MOPO - Penalty 5.0 - Rollout Length 10 - SAC-RT-0.25M-1 - No Additional Training
##########################################################################
MQ227 = get_results("MQ227") # No REx
MQ228 = get_results("MQ228")
MQ229 = get_results("MQ229")
MQ230 = get_results("MQ230") # REx - 10.0
MQ231 = get_results("MQ231")
MQ232 = get_results("MQ232")

# %%
plot_evaluation_returns([
    MQ227,
    MQ228,
    MQ229,
    MQ230,
    MQ231,
    MQ232,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$ - Original Model', ymin=-2500, ymax=4000)

# %%
plot_grouped_evaluation_returns([
    ((MQ227, MQ228, MQ229), 'No REx'),
    ((MQ230, MQ231, MQ232), 'REx - $\\beta=10.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$ - Original Model', ymin=-2500, ymax=4000)
# Out:
# {'No REx': {'mean': -1008, 'std': 0},
#  'REx - $\\beta=10.0$': {'mean': -310, 'std': 120}}

# %%
plot_evaluation_returns([
    MQ227,
    MQ228,
    MQ229,
    MQ230,
    MQ231,
    MQ232,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$ - Original Model', feature='Q_loss', ymin=0, ymax=10000)
