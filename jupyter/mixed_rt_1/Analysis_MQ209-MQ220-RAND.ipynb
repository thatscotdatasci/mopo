# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
from itertools import zip_longest

import numpy as np
import matplotlib.pyplot as plt

from dogo.results import get_results
from dogo.plot_results import plot_experiment_metrics, plot_min_max_logvars, plot_evaluation_returns, plot_grouped_evaluation_returns, plot_min_max_penalty

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 5.0 - RAND-1 - No Additional Training

# %%
##########################################################################
# MOPO - Penalty 5.0 - Rollout Length 5 - RAND-1 - No Additional Training
##########################################################################
MQ209 = get_results("MQ209") # No REx
MQ210 = get_results("MQ210")
MQ211 = get_results("MQ211")
MQ212 = get_results("MQ212") # REx - 10.0
MQ213 = get_results("MQ213")
MQ214 = get_results("MQ214")

# %%
plot_evaluation_returns([
    MQ209,
    MQ210,
    MQ211,
    MQ212,
    MQ213,
    MQ214,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$ - Original Model', ymin=-2500, ymax=4000)

# %%
plot_grouped_evaluation_returns([
    ((MQ209, MQ210, MQ211), 'No REx'),
    ((MQ212, MQ213, MQ214), 'REx - $\\beta=10.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$ - Original Model', ymin=-2500, ymax=4000)
# Out:
# {'No REx': {'mean': -15, 'std': 339},
#  'REx - $\\beta=10.0$': {'mean': -414, 'std': 85}}

# %%
plot_evaluation_returns([
    MQ209,
    MQ210,
    MQ211,
    MQ212,
    MQ213,
    MQ214,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$ - Original Model', feature='Q_loss', ymin=0, ymax=10000)

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 10.0 - RAND-1 - No Additional Training

# %%
##########################################################################
# MOPO - Penalty 5.0 - Rollout Length 10 - RAND-1 - No Additional Training
##########################################################################
MQ215 = get_results("MQ215") # No REx
MQ216 = get_results("MQ216")
MQ217 = get_results("MQ217")
MQ218 = get_results("MQ218") # REx - 10.0
MQ219 = get_results("MQ219")
MQ220 = get_results("MQ220")

# %%
plot_evaluation_returns([
    MQ215,
    MQ216,
    MQ217,
    MQ218,
    MQ219,
    MQ220,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$ - Original Model', ymin=-2500, ymax=4000)

# %%
plot_grouped_evaluation_returns([
    ((MQ215, MQ216, MQ217), 'No REx'),
    ((MQ218, MQ219, MQ220), 'REx - $\\beta=10.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$ - Original Model', ymin=-2500, ymax=4000)
# Out:
# {'No REx': {'mean': -456, 'std': 0},
#  'REx - $\\beta=10.0$': {'mean': -391, 'std': 35}}

# %%
plot_evaluation_returns([
    MQ215,
    MQ216,
    MQ217,
    MQ218,
    MQ219,
    MQ220,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=5$ - Original Model', feature='Q_loss', ymin=0, ymax=10000)
