# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/home/ajc348/rds/hpc-work/mopo')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rc('font', size=16)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
labels = ['$\\lambda=0.0$', '$\\lambda=1.0$', '$\\lambda=5.0$']

rt_1_rl_5_mean = [9728.163421728175, 7379.616192320947, 1589.0943586730414]
rt_1_rl_5_std = [4726.8470196419175, 4946.588865853447, 2815.070884309338]

rt_4_rl_5_mean = [12535.046272642418, 11369.417135089167, 6624.022758122299]
rt_4_rl_5_std =  [6848.235569161235, 6771.373029811355, 5555.918669536826]

rt_5_rl_5_mean = [3721.7171835704457, 2262.954591526197, 1311.983137747363]
rt_5_rl_5_std = [2426.534222731844, 2214.0245124594644, 2204.08756315158]

rt_1_rl_10_mean = [7570.443422794964, 6587.641035834739, 1292.6589191619641]
rt_1_rl_10_std = [6288.6161258430575, 5298.2346699117115, 2603.6129930912803]

rt_4_rl_10_mean = [14496.525744613184, 12527.836070908024, 7025.762314446923]
rt_4_rl_10_std = [4285.8247958761285, 5804.252758797355, 5699.471493868706]

rt_5_rl_10_mean = [3285.21906332683, 2651.937814983202, 800.3559868789486]
rt_5_rl_10_std = [2755.0110812936177, 2641.7602484523154, 1825.895702122007]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for mean_arr, std_err, label, c, ls in [
    (rt_1_rl_5_mean, rt_1_rl_5_std, 'Mixed - h=5', cols[0], '-'),
    (rt_4_rl_5_mean, rt_4_rl_5_std, 'Experienced - h=5', cols[1], '-'),
    (rt_5_rl_5_mean, rt_5_rl_5_std, 'Novice - h=5', cols[2], '-'),
    (rt_1_rl_10_mean, rt_1_rl_10_std, 'Mixed - h=10', cols[0], '--'),
    (rt_4_rl_10_mean, rt_4_rl_10_std, 'Experienced - h=10', cols[1], '--'),
    (rt_5_rl_10_mean, rt_5_rl_10_std, 'Novice - h=10', cols[2], '--'),
]:
    ax.errorbar(np.arange(3), mean_arr, std_err, color=c, ls=ls, label=label, capsize=10)
ax.set_xticks(np.arange(3))
ax.set_xticklabels(labels)
ax.set_title('HalfCheetah')
ax.set_xlabel('MOPO Penaly Coefficient')
ax.set_ylabel('Model Exploitation')
# ax.set_ylim(-150, 150)
ax.legend()
