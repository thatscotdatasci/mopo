# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dogo.results import get_results, get_experiment_details, average_scores_over_seeds
from dogo.plot_results import plot_grouped_evaluation_returns

# %%
plt.rc('font', size=12)

# %%
######
# MOPO
######

# 0.1M Records
MQ179 = get_results("MQ179")
MQ180 = get_results("MQ180")
MQ181 = get_results("MQ181")# 0.2M Records
MQ182 = get_results("MQ182")
MQ183 = get_results("MQ183")
MQ184 = get_results("MQ184")# 0.5M Records
MQ185 = get_results("MQ185")
MQ186 = get_results("MQ186")
MQ187 = get_results("MQ187")# 1M Records
MQ188 = get_results("MQ188")
MQ189 = get_results("MQ189")
MQ190 = get_results("MQ190")# 2M Records
MQ191 = get_results("MQ191")
MQ192 = get_results("MQ192")
MQ193 = get_results("MQ193")

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

feature = 'evaluation/return-average'
for exp in [
    MQ179,
    MQ180,
    MQ181,
    MQ182,
    MQ183,
    MQ184,
    MQ185,
    MQ186,
    MQ187,
    MQ188,
    MQ189,
    MQ190,
    MQ191,
    MQ192,
    MQ193
]:
    ax.plot(
        exp.sac.result['timesteps_total'], exp.sac.result[feature], label=f'{exp.name} - {exp.dataset} - Seed: {exp.seed}'
    )
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
ax.legend()
pass

# %%
plot_grouped_evaluation_returns([
    ((MQ179, MQ180, MQ181), 'Steps: 0.1M'),
    ((MQ182, MQ183, MQ184), 'Steps: 0.2M'),
    ((MQ185, MQ186, MQ187), 'Steps: 0.5M'),
    ((MQ188, MQ189, MQ190), 'Steps: 1M'),
    ((MQ191, MQ192, MQ193), 'Steps: 2M'),
], save_path='ch4/d3rlpy_0.1M_records_extended_training_rand.png', show_ends=True)
# Out:
# {'Steps: 0.1M': {'mean': 170, 'std': 0},
#  'Steps: 0.2M': {'mean': -243, 'std': 0},
#  'Steps: 0.5M': {'mean': 255, 'std': 0},
#  'Steps: 1M': {'mean': -255, 'std': 0},
#  'Steps: 2M': {'mean': -535, 'std': 0}}

# %%
plot_grouped_evaluation_returns([
    ((MQ179, MQ180, MQ181), 'Steps: 0.1M'),
    ((MQ182, MQ183, MQ184), 'Steps: 0.2M'),
    ((MQ185, MQ186, MQ187), 'Steps: 0.5M'),
    ((MQ188, MQ189, MQ190), 'Steps: 1M'),
    ((MQ191, MQ192, MQ193), 'Steps: 2M'),
], feature='Q_loss', ymin=0, ymax=1e3)#, save_path='ch4/d3rlpy_0.1M_records_extended_training_d4rl.png')
# Out:
# {'Steps: 0.1M': {'mean': -9223372036854775808, 'std': 0},
#  'Steps: 0.2M': {'mean': -9223372036854775808, 'std': 0},
#  'Steps: 0.5M': {'mean': -9223372036854775808, 'std': 0},
#  'Steps: 1M': {'mean': 1739897161484599040, 'std': 0},
#  'Steps: 2M': {'mean': 4149424666953383936, 'std': 0}}
