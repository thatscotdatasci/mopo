# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dogo.results import get_results

# %%
plt.rc('font', size=12)

# %% [markdown]
# # MP146-MP147

# %%
MP100 = get_results("MP100")
MP101 = get_results("MP101")
MP146 = get_results("MP146")
MP147 = get_results("MP147")

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.set_xlim(250)
ax.set_ylim(0,0.2)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_holdout_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Holdout Loss')
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_holdout_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Holdout Loss')
ax.set_xlim(250)
ax.set_ylim(0,0.2)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_pol_total_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Sum of Policy Risks')
ax.set_xlim(200)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_pol_total_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Sum of Policy Risks')
ax.set_xlim(200)
ax.set_ylim(0,2.)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_holdout_pol_total_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Sum of Holdout Policy Losses')
ax.set_xlim(200)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_holdout_pol_total_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Sum of Holdout Policy Losses')
ax.set_xlim(200)
ax.set_ylim(0,2.)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Variance of Policy Losses')
ax.set_xlim(200)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Variance of Policy Losses')
ax.set_xlim(200)
ax.set_ylim(0,0.02)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP100, 1.),
    # (MP101, 1.),
    # (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx: {exp.rex} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Variance of Policy Losses')
ax.set_xlim(200)
ax.set_ylim(0,0.003)
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
for exp, loss_decay_term in [
    (MP101, 1.),
    (MP147, 2.),
    (MP146, 10.),
]:
    ax.plot(exp.dynamics.model_holdout_pol_var_loss_history.mean(axis=1)[100:], label=f'{exp.name} - REx Beta: {exp.rex_beta} - Dataset: {exp.dataset} - Seed: {exp.seed} - Loss Decay: {loss_decay_term}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Variance of Holdout Policy Losses')
ax.set_xlim(200)
ax.set_ylim(0,0.02)
ax.legend()
pass
