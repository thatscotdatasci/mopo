# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/home/ajc348/rds/hpc-work/mopo')

# %%
from dogo.visualisation.policy_dynamics_plotting import (
    plot_policy_group_values,
)

# %%
# Rollout length 5
plot_policy_group_values([
    (("HC097", "HC098", "HC099"), 'No REx\n$\\lambda=0.0$'),
    (("HC100", "HC101", "HC102"), 'REx: $\\beta=5.0$\n$\\lambda=0.0$'),
    (("HC103", "HC104", "HC105"), 'REx: $\\beta=10.0$\n$\\lambda=0.0$'),
    (("HC106", "HC107", "HC108"), 'REx: $\\beta=20.0$\n$\\lambda=0.0$'),
    (("HC265", "HC266", "HC267"), 'No REx\n$\\lambda=1.0$'),
    (("HC268", "HC269", "HC270"), 'REx: $\\beta=5.0$\n$\\lambda=1.0$'),
    (("HC271", "HC272", "HC273"), 'REx: $\\beta=10.0$\n$\\lambda=1.0$'),
    (("HC274", "HC275", "HC276"), 'REx: $\\beta=20.0$\n$\\lambda=1.0$'),
    (("HC277", "HC278", "HC279"), 'No REx\n$\\lambda=5.0$'),
    (("HC280", "HC281", "HC282"), 'REx: $\\beta=5.0$\n$\\lambda=5.0$'),
    (("HC283", "HC284", "HC285"), 'REx: $\\beta=10.0$\n$\\lambda=5.0$'),
    (("HC286", "HC287", "HC288"), 'REx: $\\beta=20.0$\n$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(20,10))
# Out:
# Labels ['No REx\n$\\lambda=0.0$', 'REx: $\\beta=5.0$\n$\\lambda=0.0$', 'REx: $\\beta=10.0$\n$\\lambda=0.0$', 'REx: $\\beta=20.0$\n$\\lambda=0.0$', 'No REx\n$\\lambda=1.0$', 'REx: $\\beta=5.0$\n$\\lambda=1.0$', 'REx: $\\beta=10.0$\n$\\lambda=1.0$', 'REx: $\\beta=20.0$\n$\\lambda=1.0$', 'No REx\n$\\lambda=5.0$', 'REx: $\\beta=5.0$\n$\\lambda=5.0$', 'REx: $\\beta=10.0$\n$\\lambda=5.0$', 'REx: $\\beta=20.0$\n$\\lambda=5.0$']
# Fake [ 5863.50146484 17093.13671875 16413.66796875 16223.57324219
#  10740.79394531 15989.90039062 15752.44238281 15856.53417969
#   6170.87304688 13405.57519531 12438.07226562 12677.13769531] [7270.40820312 1480.06567383  219.34617615  473.29833984 5777.82324219
#   272.28009033  405.07537842  382.90530396 4887.63085938 2841.3671875
#  3329.11108398 3122.41455078]
# Eval [ 5911.23061004 17183.42687261 16400.26067089 16187.34435639
#  10696.72570255 15999.52095289 15752.34371035 15813.07699664
#   6137.96456593 13411.05335024 12438.36558749 12678.02800483] [7192.87888987 1548.78554094  213.37721617  458.90877582 5844.08076683
#   273.60083539  401.23892034  360.95007162 4923.21516287 2843.21960351
#  3329.40162147 3121.00644734]
# Real [ 151.55846946 2945.94929668 2338.78672826  247.34384023 4692.91976186
#  3177.58518335 3325.83843951 1665.65790728 3198.95686838 1907.57893781
#  6862.44183632 6226.58741427] [ 281.64141939 6233.14658883 5654.53898665  378.59060154 6676.45921253
#  6365.26339855 6298.1148041  4742.42238846 4742.12218783 2443.55575629
#  6006.33954937 5449.98656019]
# Diff [ 5714.53936749 14147.18690124 14074.88065456 15976.22793711
#   6047.87344289 12812.31393775 12426.60433393 14190.87682579
#   2971.9166037  11497.99404396  5575.62974571  6450.55063912] [7162.81826147 6616.58417929 5531.18126205  529.75069809 6453.44804171
#  6444.84990861 6169.96571979 4761.86453709 3005.74740643 4962.6318026
#  5050.00640004 5107.39038916]

# %%
# Rollout length 5
plot_policy_group_values([
    (("HC097", "HC098", "HC099", "HC100", "HC101", "HC102", "HC103", "HC104", "HC105", "HC106", "HC107", "HC108"), 'REx: $\\beta=20.0$\n$\\lambda=0.0$'),
    (("HC265", "HC266", "HC267", "HC268", "HC269", "HC270", "HC271", "HC272", "HC273", "HC274", "HC275", "HC276"), 'REx: $\\beta=20.0$\n$\\lambda=1.0$'),
    (("HC277", "HC278", "HC279", "HC280", "HC281", "HC282", "HC283", "HC284", "HC285", "HC286", "HC287", "HC288"), 'REx: $\\beta=20.0$\n$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(10,10))
# Out:
# Labels ['REx: $\\beta=20.0$\n$\\lambda=0.0$', 'REx: $\\beta=20.0$\n$\\lambda=1.0$', 'REx: $\\beta=20.0$\n$\\lambda=5.0$']
# Fake [13965.9892578125, 14584.9169921875, 11172.9150390625] [5895.91259765625, 3657.16650390625, 4654.65478515625]
# Eval [13987.870963762618, 14565.41684060943, 11166.352877120911] [5868.1819843724115, 3691.4865581938507, 4673.705406428979]
# Real [1420.9095836554015, 3215.5003230000275, 4548.891264196223] [4393.328284632826, 6161.308662031607, 5272.646161256632]
# Diff [12535.046272642418, 11369.417135089167, 6624.022758122299] [6848.235569161235, 6771.373029811355, 5555.918669536826]

# %%
# Rollout length 10
plot_policy_group_values([
    (("HC109", "HC110", "HC111"), 'No REx\n$\\lambda=0.0$'),
    (("HC112", "HC113", "HC114"), 'REx: $\\beta=5.0$\n$\\lambda=0.0$'),
    (("HC115", "HC116", "HC117"), 'REx: $\\beta=10.0$\n$\\lambda=0.0$'),
    (("HC118", "HC119", "HC120"), 'REx: $\\beta=20.0$\n$\\lambda=0.0$'),
    (("HC289", "HC290", "HC291"), 'No REx\n$\\lambda=1.0$'),
    (("HC292", "HC293", "HC294"), 'REx: $\\beta=5.0$\n$\\lambda=1.0$'),
    (("HC295", "HC296", "HC297"), 'REx: $\\beta=10.0$\n$\\lambda=1.0$'),
    (("HC298", "HC299", "HC300"), 'REx: $\\beta=20.0$\n$\\lambda=1.0$'),
    (("HC301", "HC302", "HC303"), 'No REx\n$\\lambda=5.0$'),
    (("HC304", "HC305", "HC306"), 'REx: $\\beta=5.0$\n$\\lambda=5.0$'),
    (("HC307", "HC308", "HC309"), 'REx: $\\beta=10.0$\n$\\lambda=5.0$'),
    (("HC310", "HC311", "HC312"), 'REx: $\\beta=20.0$\n$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(20,10))
# Out:
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/HC025_HC109_dmTrue_dpTrue_fake_unpen_rewards.npy
# Metric not found for: HC109
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/HC025_HC289_dmTrue_dpTrue_fake_unpen_rewards.npy
# Metric not found for: HC289
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/HC025_HC301_dmTrue_dpTrue_fake_unpen_rewards.npy
# Metric not found for: HC301
# Labels ['No REx\n$\\lambda=0.0$', 'REx: $\\beta=5.0$\n$\\lambda=0.0$', 'REx: $\\beta=10.0$\n$\\lambda=0.0$', 'REx: $\\beta=20.0$\n$\\lambda=0.0$', 'No REx\n$\\lambda=1.0$', 'REx: $\\beta=5.0$\n$\\lambda=1.0$', 'REx: $\\beta=10.0$\n$\\lambda=1.0$', 'REx: $\\beta=20.0$\n$\\lambda=1.0$', 'No REx\n$\\lambda=5.0$', 'REx: $\\beta=5.0$\n$\\lambda=5.0$', 'REx: $\\beta=10.0$\n$\\lambda=5.0$', 'REx: $\\beta=20.0$\n$\\lambda=5.0$']
# Fake [ 6175.73675537 17015.86523438 16532.11914062 15876.75488281
#   4463.23217131 16534.640625   15648.43652344 15800.23730469
#   5535.77677002 13033.59472656 11235.33789062 13278.65917969] [3522.83736098 1060.88391113  310.24676514  727.68328857 1312.88694878
#   719.56231689  727.42260742  566.62817383 2561.25889191 3531.54711914
#  3627.85668945 3073.43334961]
# Eval [ 5897.52365459 17069.54880193 16482.42683144 15843.27944753
#   4334.90931632 16560.19043075 15623.04755142 15776.52961783
#   5490.36009029 13034.8398141  11234.23225988 13280.45725826] [3560.45009762 1139.98068101  308.52987593  706.90162689 1164.69233702
#   782.8773981   713.82992603  555.11149043 2500.0559426  3536.82589673
#  3629.69929594 3073.65272144]
# Real [-1.52388885e+00  1.47580414e+02  1.77039853e+02  6.43650891e+01
#   2.28711675e+02  1.41170288e+02  2.38332066e+03  2.63171107e+03
#   2.33283041e+02  4.18599142e+03  6.64127782e+03  4.49418834e+03] [ 236.33260002  259.74501973  329.94829246  270.00806589  215.92956284
#   530.96864735 5495.0108887  5696.77774768  174.34448987 6485.89737726
#  5031.75521265 5053.44291505]
# Diff [ 6177.26064422 16868.28426738 16355.07967843 15812.39002162
#   4248.46159141 16393.47023913 13265.1153761  13168.52643452
#   5302.49372939  8847.60237397  4594.05910732  8784.47118542] [3574.73137856 1093.78944543  256.44093922  786.1703718  1343.05533008
#  1003.18554176 5262.56396429 5766.30909311 2588.88691576 6361.02204147
#  5053.45366658 5859.57183818]

# %%
# Rollout length 10
plot_policy_group_values([
    (("HC109", "HC110", "HC111", "HC112", "HC113", "HC114", "HC115", "HC116", "HC117", "HC118", "HC119", "HC120"), 'REx: $\\beta=20.0$\n$\\lambda=0.0$'),
    (("HC289", "HC290", "HC291", "HC292", "HC293", "HC294", "HC295", "HC296", "HC297", "HC298", "HC299", "HC300"), 'REx: $\\beta=20.0$\n$\\lambda=1.0$'),
    (("HC301", "HC302", "HC303", "HC304", "HC305", "HC306", "HC307", "HC308", "HC309", "HC310", "HC311", "HC312"), 'REx: $\\beta=20.0$\n$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(10,10))
# Out:
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/HC025_HC109_dmTrue_dpTrue_fake_unpen_rewards.npy
# Metric not found for: HC109
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/HC025_HC289_dmTrue_dpTrue_fake_unpen_rewards.npy
# Metric not found for: HC289
# Could not find: /home/ajc348/rds/hpc-work/dogo_results/mopo/analysis/policy/HC025_HC301_dmTrue_dpTrue_fake_unpen_rewards.npy
# Metric not found for: HC301
# Labels ['REx: $\\beta=20.0$\n$\\lambda=0.0$', 'REx: $\\beta=20.0$\n$\\lambda=1.0$', 'REx: $\\beta=20.0$\n$\\lambda=5.0$']
# Fake [14602.335589044744, 13984.411313118191, 11246.756753817472] [4323.399925199145, 4465.247617877025, 4322.802258744294]
# Eval [14543.710231990675, 13955.562431284072, 11239.028016114671] [4431.623467569586, 4506.559378379466, 4329.242015647735]
# Real [105.80984443155798, 1447.8208534686837, 4220.994439370549] [287.31814216434014, 4304.427188420218, 5464.21002802147]
# Diff [14496.525744613184, 12527.836070908024, 7025.762314446923] [4285.8247958761285, 5804.252758797355, 5699.471493868706]
