# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
from collections import namedtuple

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from dogo.results import get_sac_pools, get_experiment_details, PoolArrs

# %%
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
EXP_LIST = [
    # No REx - MOPO Pen 0 - Rollout Length 10 - 1 Retrain Epoch
    "MP982",
    "MP983",
    "MP984",
    # REx 10 - MOPO Pen 0 - Rollout Length 10 - 1 Retrain Epoch
    "MP988",
    "MP989",
    "MP990",
    # No REx - MOPO Pen 5 - Rollout Length 10 - 1 Retrain Epoch
    "MP862",
    "MP863",
    "MP864",
    # REx 10 - MOPO Pen 5 - Rollout Length 10 - 1 Retrain Epoch
    "MP865",
    "MP866",
    "MP867",
]
SUBSAMPLE_SIZE = None
training_results = {}
for exp in EXP_LIST:
    # print(exp)
    training_results[exp] = PoolArrs(*get_sac_pools(exp, subsample_size=SUBSAMPLE_SIZE))

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

labels = []
rmse_arrs = []
for i, (exp, rex, beta) in enumerate([
    ("MP982", False, 0.0),
    ("MP983", False, 0.0),
    ("MP984", False, 0.0),
    ("MP988", True, 10.0),
    ("MP989", True, 10.0),
    ("MP990", True, 10.0),
]):
    rmse_vals = np.sqrt(training_results[exp].mse_results).flatten()
    labels.append(f'{exp} - REx: {rex} - Beta: {beta}\nMean: {np.nanmean(rmse_vals):.2f}')

    rmse_vals = np.nan_to_num(rmse_vals, nan=1e6)
    rmse_arrs.append(rmse_vals)

ax.boxplot(rmse_arrs, showmeans=False, showfliers=False, labels=labels)

ax.set_title('MOPO Penalty: 0.0 - Rollout-Length: 10')
ax.set_xlabel('Experiment')
ax.set_ylabel('Overall RMSE')
# ax.set_ylim(-0.01,0.35)
# Out:
# Text(0, 0.5, 'Overall RMSE')

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

labels = []
rmse_arrs = []
for i, (exp, rex, beta) in enumerate([
    ("MP982", False, 0.0),
    ("MP983", False, 0.0),
    ("MP984", False, 0.0),
    ("MP988", True, 10.0),
    ("MP989", True, 10.0),
    ("MP990", True, 10.0),
]):
    rmse_vals = np.sqrt(training_results[exp].mse_results).flatten()
    labels.append(f'{exp} - REx: {rex} - Beta: {beta}\nMean: {np.nanmean(rmse_vals):.2f}')

    rmse_vals = np.nan_to_num(rmse_vals, nan=1e6)
    rmse_arrs.append(rmse_vals)

ax.boxplot(rmse_arrs, showmeans=False, showfliers=True, labels=labels)

ax.set_title('MOPO Penalty: 0.0 - Rollout-Length: 10')
ax.set_xlabel('Experiment')
ax.set_ylabel('Overall RMSE')
# ax.set_ylim(-0.01,0.35)
# Out:
# Text(0, 0.5, 'Overall RMSE')

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

labels = []
rmse_arrs = []
for i, (exp, rex, beta) in enumerate([
    ("MP862", False, 0.0),
    ("MP863", False, 0.0),
    ("MP864", False, 0.0),
    ("MP865", True, 10.0),
    ("MP866", True, 10.0),
    ("MP867", True, 10.0),
]):
    rmse_vals = np.sqrt(training_results[exp].mse_results).flatten()
    labels.append(f'{exp} - REx: {rex} - Beta: {beta}\nMean: {np.nanmean(rmse_vals):.2f}')

    rmse_vals = np.nan_to_num(rmse_vals, nan=1e6)
    rmse_arrs.append(rmse_vals)

ax.boxplot(rmse_arrs, showmeans=False, showfliers=False, labels=labels)

ax.set_title('MOPO Penalty: 5.0 - Rollout-Length: 10')
ax.set_xlabel('Experiment')
ax.set_ylabel('Overall RMSE')
# ax.set_ylim(-0.01,0.35)
# Out:
# Text(0, 0.5, 'Overall RMSE')

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

labels = []
rmse_arrs = []
for i, (exp, rex, beta) in enumerate([
    ("MP862", False, 0.0),
    ("MP863", False, 0.0),
    ("MP864", False, 0.0),
    ("MP865", True, 10.0),
    ("MP866", True, 10.0),
    ("MP867", True, 10.0),
]):
    rmse_vals = np.sqrt(training_results[exp].mse_results).flatten()
    labels.append(f'{exp} - REx: {rex} - Beta: {beta}\nMean: {np.nanmean(rmse_vals):.2f}')

    rmse_vals = np.nan_to_num(rmse_vals, nan=1e6)
    rmse_arrs.append(rmse_vals)

ax.boxplot(rmse_arrs, showmeans=False, showfliers=True, labels=labels)

ax.set_title('MOPO Penalty: 5.0 - Rollout-Length: 10')
ax.set_xlabel('Experiment')
ax.set_ylabel('Overall RMSE')
# ax.set_ylim(-0.01,0.35)
# Out:
# Text(0, 0.5, 'Overall RMSE')
