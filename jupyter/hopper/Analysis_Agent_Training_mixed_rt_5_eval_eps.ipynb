# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/home/ajc348/rds/hpc-work/mopo')

# %%
from itertools import zip_longest

import numpy as np
import matplotlib.pyplot as plt

from dogo.results import get_results
from dogo.plot_results import plot_evaluation_returns, plot_grouped_evaluation_returns, plot_grouped_evaluation_and_dynamics_returns

# %%
plt.rc('font', size=12)
cols = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# # MOPO: 5.0 - Rollout-Length: 100.0

# %%
HO985 = get_results("HO985") # No Rex
HO986 = get_results("HO986")
HO987 = get_results("HO987")
HO988 = get_results("HO988") # REx - 5.0
HO989 = get_results("HO989")
HO990 = get_results("HO990")
HO991 = get_results("HO991") # REx - 10.0
HO992 = get_results("HO992")
HO993 = get_results("HO993")
HO994 = get_results("HO994") # REx - 20.0
HO995 = get_results("HO995")
HO996 = get_results("HO996")

# %%
plot_evaluation_returns([
    HO985,
    HO986,
    HO987,
    HO988,
    HO989,
    HO990,
    HO991,
    HO992,
    HO993,
    HO994,
    HO995,
    HO996,
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$')
# Out:
# HO985: 3410.64208984375
# HO986: 1960.6334228515625
# HO987: 3358.608642578125
# HO988: 3436.201171875
# HO989: 3476.93505859375
# HO990: 3501.580810546875
# HO991: 2660.1396484375
# HO992: 3481.205078125
# HO993: 3519.51220703125
# HO994: 3444.024169921875
# HO995: 3409.63427734375
# HO996: 3367.759765625

# %%
plot_grouped_evaluation_returns([
    ((HO985, HO986, HO987), 'No REx'),
    ((HO988, HO989, HO990), 'REx - $\\beta=5.0$'),
    ((HO991, HO992, HO993), 'REx - $\\beta=10.0$'),
    ((HO994, HO995, HO996), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', max_timestep=1000000)
# Out:
# {'No REx': {'mean': 3411, 'std': 0, 'count': 1, 'text': '3411 ± 0'},
#  'REx - $\\beta=5.0$': {'mean': 3489,
#   'std': 12,
#   'count': 2,
#   'text': '3489 ± 12'},
#  'REx - $\\beta=10.0$': {'mean': 3220,
#   'std': 396,
#   'count': 3,
#   'text': '3220 ± 396'},
#  'REx - $\\beta=20.0$': {'mean': 3444,
#   'std': 0,
#   'count': 1,
#   'text': '3444 ± 0'}}

# %%
plot_grouped_evaluation_and_dynamics_returns([
    ((HO985, HO986, HO987), 'No REx'),
    ((HO988, HO989, HO990), 'REx - $\\beta=5.0$'),
    ((HO991, HO992, HO993), 'REx - $\\beta=10.0$'),
    ((HO994, HO995, HO996), 'REx - $\\beta=20.0$'),
], title='MOPO Hyperparameters: $\\lambda=5.0$, $h=10$', max_timestep=1000000)
# Out:
# {'No REx': {'mean_eval_std': 919,
#   'mean_dyn_std': 769,
#   'outliers': 0.0,
#   'frac_inf': 0.0,
#   'diff_mean': -506,
#   'diff_std': 493,
#   'text': '-506 ± 493'},
#  'REx - $\\beta=5.0$': {'mean_eval_std': 588,
#   'mean_dyn_std': 536,
#   'outliers': 0.0,
#   'frac_inf': 0.0,
#   'diff_mean': -508,
#   'diff_std': 388,
#   'text': '-508 ± 388'},
#  'REx - $\\beta=10.0$': {'mean_eval_std': 567,
#   'mean_dyn_std': 526,
#   'outliers': 0.0,
#   'frac_inf': 0.0,
#   'diff_mean': -534,
#   'diff_std': 343,
#   'text': '-534 ± 343'},
#  'REx - $\\beta=20.0$': {'mean_eval_std': 708,
#   'mean_dyn_std': 659,
#   'outliers': 0.0,
#   'frac_inf': 0.0,
#   'diff_mean': -496,
#   'diff_std': 538,
#   'text': '-496 ± 538'}}
