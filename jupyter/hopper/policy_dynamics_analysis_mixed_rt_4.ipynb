# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.expanduser('~/rds/rds-dsk-lab-eWkDxBhxBrQ/dimorl/code/mopo'))

# %%
from dogo.visualisation.policy_dynamics_plotting import (
    plot_policy_group_values,
)

# %%
# Rollout length 5
plot_policy_group_values([
    (("HO349", "HO350", "HO351"), 'No REx\n$\\lambda=0.0$'),
    (("HO352", "HO353", "HO354"), 'REx: $\\beta=5.0$\n$\\lambda=0.0$'),
    (("HO355", "HO356", "HO357"), 'REx: $\\beta=10.0$\n$\\lambda=0.0$'),
    (("HO358", "HO359", "HO360"), 'REx: $\\beta=20.0$\n$\\lambda=0.0$'),
    (("HO277", "HO278", "HO279"), 'No REx\n$\\lambda=1.0$'),
    (("HO280", "HO281", "HO282"), 'REx: $\\beta=5.0$\n$\\lambda=1.0$'),
    (("HO283", "HO284", "HO285"), 'REx: $\\beta=10.0$\n$\\lambda=1.0$'),
    (("HO286", "HO287", "HO288"), 'REx: $\\beta=20.0$\n$\\lambda=1.0$'),
    (("HO289", "HO290", "HO291"), 'No REx\n$\\lambda=5.0$'),
    (("HO292", "HO293", "HO294"), 'REx: $\\beta=5.0$\n$\\lambda=5.0$'),
    (("HO295", "HO296", "HO297"), 'REx: $\\beta=10.0$\n$\\lambda=5.0$'),
    (("HO298", "HO299", "HO300"), 'REx: $\\beta=20.0$\n$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(20,10))
# Out:
# Labels ['No REx\n$\\lambda=0.0$', 'REx: $\\beta=5.0$\n$\\lambda=0.0$', 'REx: $\\beta=10.0$\n$\\lambda=0.0$', 'REx: $\\beta=20.0$\n$\\lambda=0.0$', 'No REx\n$\\lambda=1.0$', 'REx: $\\beta=5.0$\n$\\lambda=1.0$', 'REx: $\\beta=10.0$\n$\\lambda=1.0$', 'REx: $\\beta=20.0$\n$\\lambda=1.0$', 'No REx\n$\\lambda=5.0$', 'REx: $\\beta=5.0$\n$\\lambda=5.0$', 'REx: $\\beta=10.0$\n$\\lambda=5.0$', 'REx: $\\beta=20.0$\n$\\lambda=5.0$']
# Fake [558.44732666 439.45043945 567.79193115 505.85314941 374.61843872
#  566.40130615 379.43692017 386.35696411 506.88015747 522.16644287
#  767.26580811 520.41552734] [105.63980865 124.36561584  72.9223938  293.73516846 253.39671326
#  273.73779297  23.16183281  70.37665558  17.93745995  75.19194031
#   22.45091248 136.24584961]
# Eval [559.66255455 439.50700079 568.83833148 507.18691292 444.93944229
#  566.57055917 380.87593478 387.54795039 507.43991634 522.15217955
#  767.72551101 520.72742654] [105.400302   124.50540145  72.4582685  294.20649418 192.84303468
#  273.20759478  23.23823293  70.63329982  17.7272256   75.25948308
#   22.33594021 136.40949085]
# Real [574.75903459 437.05767354 573.96945946 494.3431477  442.43335623
#  567.8984905  384.09834003 392.34187186 509.93317672 512.63501341
#  770.33725138 525.6576013 ] [112.79588634 120.34708512  71.90857726 267.11817759 186.51790532
#  277.27885593  26.46496251  79.35264221  16.33239177  72.44468698
#   57.1818062  147.21008356]
# Diff [-16.31168758   2.39276591  -6.17755883  11.51000934 -67.81491751
#   -1.49722504  -4.6614097   -5.98488741  -3.05301925   9.53140911
#   -3.07142293  -5.24208413] [ 8.13891329  4.56337223  5.95967963 26.70360858 99.48591997  3.58164472
#   5.3389196   9.50519629  1.77939109  2.75718094 36.95743646 12.02052834]

# %%
# Rollout length 5
plot_policy_group_values([
    (("HO349", "HO350", "HO351", "HO352", "HO353", "HO354", "HO355", "HO356", "HO357", "HO358", "HO359", "HO360"), '$\\lambda=0.0$'),
    (("HO277", "HO278", "HO279", "HO280", "HO281", "HO282", "HO283", "HO284", "HO285", "HO286", "HO287", "HO288"), '$\\lambda=1.0$'),
    (("HO289", "HO290", "HO291", "HO292", "HO293", "HO294", "HO295", "HO296", "HO297", "HO298", "HO299", "HO300"), '$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(10,10))
# Out:
# Labels ['$\\lambda=0.0$', '$\\lambda=1.0$', '$\\lambda=5.0$']
# Fake [516.96008301 426.70336914 579.18200684] [190.62367249 206.59254456 134.48970032]
# Eval [517.90548555 444.98347166 579.51125836] [190.89361599 186.78325779 134.58192095]
# Real [518.05623797 446.69301466 579.6407607 ] [180.48994083 187.25035454 140.60920831]
# Diff [ -1.09610801 -19.98960991  -0.4587793 ] [18.94173563 57.20455312 20.35530243]

# %%
# Rollout length 10
plot_policy_group_values([
    (("HO361", "HO362", "HO363"), 'No REx\n$\\lambda=0.0$'),
    (("HO364", "HO365", "HO366"), 'REx: $\\beta=5.0$\n$\\lambda=0.0$'),
    (("HO367", "HO368", "HO369"), 'REx: $\\beta=10.0$\n$\\lambda=0.0$'),
    (("HO370", "HO371", "HO372"), 'REx: $\\beta=20.0$\n$\\lambda=0.0$'),
    (("HO301", "HO302", "HO303"), 'No REx\n$\\lambda=1.0$'),
    (("HO304", "HO305", "HO306"), 'REx: $\\beta=5.0$\n$\\lambda=1.0$'),
    (("HO307", "HO308", "HO309"), 'REx: $\\beta=10.0$\n$\\lambda=1.0$'),
    (("HO310", "HO311", "HO312"), 'REx: $\\beta=20.0$\n$\\lambda=1.0$'),
    (("HO313", "HO314", "HO315"), 'No REx\n$\\lambda=5.0$'),
    (("HO316", "HO317", "HO318"), 'REx: $\\beta=5.0$\n$\\lambda=5.0$'),
    (("HO319", "HO320", "HO321"), 'REx: $\\beta=10.0$\n$\\lambda=5.0$'),
    (("HO322", "HO323", "HO324"), 'REx: $\\beta=20.0$\n$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(20,10))
# Out:
# Labels ['No REx\n$\\lambda=0.0$', 'REx: $\\beta=5.0$\n$\\lambda=0.0$', 'REx: $\\beta=10.0$\n$\\lambda=0.0$', 'REx: $\\beta=20.0$\n$\\lambda=0.0$', 'No REx\n$\\lambda=1.0$', 'REx: $\\beta=5.0$\n$\\lambda=1.0$', 'REx: $\\beta=10.0$\n$\\lambda=1.0$', 'REx: $\\beta=20.0$\n$\\lambda=1.0$', 'No REx\n$\\lambda=5.0$', 'REx: $\\beta=5.0$\n$\\lambda=5.0$', 'REx: $\\beta=10.0$\n$\\lambda=5.0$', 'REx: $\\beta=20.0$\n$\\lambda=5.0$']
# Fake [ 707.68182373  598.53546143  791.13592529  816.85400391  853.5123291
#   667.37744141  737.41308594  891.86767578 3187.23999023 1593.36315918
#  1051.81433105 1182.80932617] [  45.15253067   67.35140228  129.65766907  135.95762634  451.83099365
#   134.96098328   68.28598785   91.61782837 1024.08642578 1429.59887695
#   264.91152954  343.21994019]
# Eval [ 735.64385172  602.85592542  794.71231098  820.04473882 1038.83240209
#   668.7273224   743.8570097   894.1394747  3187.55092468 1615.35434577
#  1054.85634257 1184.02949894] [  50.40265571   69.6187046   131.16152752  138.00084291  418.96113523
#   135.15694935   64.03121708   90.49606229 1023.97055787 1417.12579468
#   263.62058091  342.97363134]
# Real [ 765.55061449  598.77083556  773.37539736  839.94252857 1027.15919684
#   671.75175198  747.66759543  913.37819664 3207.59065725 1611.44524527
#  1067.26864785 1158.79705694] [  69.82974606   73.3765535   115.93344884  140.47803341  397.87306745
#   104.39526261   77.11007631  132.44193899 1018.96911913 1388.85192382
#   273.65089942  351.81474093]
# Diff [ -57.86885179   -0.23536396   17.76052794  -23.08850432 -173.64687537
#    -4.37429023  -10.25444845  -21.51048017  -20.35073823  -18.08214713
#   -15.45431679   24.01224889] [ 35.07675879  11.36393586  23.71237691   8.16717682 310.20201067
#   30.56962499   9.5192071   44.10202926  13.28452953  42.18155296
#   14.48966795  14.48056541]

# %%
# Rollout length 10
plot_policy_group_values([
    (("HO361", "HO362", "HO363", "HO364", "HO365", "HO366", "HO367", "HO368", "HO369", "HO370", "HO371", "HO372"), '$\\lambda=0.0$'),
    (("HO301", "HO302", "HO303", "HO304", "HO305", "HO306", "HO307", "HO308", "HO309", "HO310", "HO311", "HO312"), '$\\lambda=1.0$'),
    (("HO313", "HO314", "HO315", "HO316", "HO317", "HO318", "HO319", "HO320", "HO321", "HO322", "HO323", "HO324"), '$\\lambda=5.0$'),
], expected_records=10, show_penalised=False, fig_size=(10,10))
# Out:
# Labels ['$\\lambda=0.0$', '$\\lambda=1.0$', '$\\lambda=5.0$']
# Fake [728.5517578125, 792.6172485351562, 2368.135009765625] [133.15818786621094, 278.8714904785156, 1354.8033447265625]
# Eval [738.3142067345183, 851.9616175966441, 2372.0634122876518] [134.02562580240323, 287.5076522279814, 1350.5862346521478]
# Real [744.4098439945211, 854.3868784235544, 2381.1247970097834] [136.9836710383918, 277.4114306679862, 1353.601192889984]
# Diff [-15.858048035048531, -61.76962754089228, -12.98959541938142] [35.98597532476668, 189.44941579862765, 25.41857215079696]
