# %%
import os
import json
from collections import namedtuple

import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rc('font', size=16)

# %%
MOPO_RESULTS_MAP_PATH = "../dogo_results/mopo/results_map.json"
with open(MOPO_RESULTS_MAP_PATH, 'r') as f:
    mopo_results_map = json.load(f)

SEED = 1443
SCORING_BASEDIR = "../dogo_results/mopo/model_scoring"

# %%
def get_score(experiment, dataset, seed=SEED):
    with open(os.path.join(SCORING_BASEDIR, mopo_results_map[experiment]['base_dir'], mopo_results_map[experiment]['experiment_dir'], f'{dataset}_{seed}.json')) as f:
        return json.load(f)

# %%
def plot_score(results_dicts, metric, title):
    fig, ax = plt.subplots(1, 1, figsize=(10,10))

    if len(results_dicts) == 2:
        labels = ["                            All Data", ""]
    elif len(results_dicts) == 6:
        labels = ["                            All Data", "",  "                            Training Data", " ", "                            Heldout Data", "  "]
    
    barlist = ax.bar(
        labels,
        [i[metric] for i in results_dicts]
    )

    for i in range(0, len(results_dicts), 2):
        barlist[i].set_color('#1f77b4')
    barlist[0].set_label('No REx')

    for i in range(1, len(results_dicts), 2):
        barlist[i].set_color('#ff7f0e')
    barlist[1].set_label('REx')

    ax.set_title(title)
    ax.set_ylabel(metric)
    ax.set_ylim(0, 60)
    ax.legend()
    # ax.tick_params(axis='x', labelrotation=45)

    patches = ax.patches
    for rect in patches:
        label = f'{rect.get_height():.4f}'
        ax.text(
            rect.get_x() + rect.get_width() / 2, rect.get_height(), label, ha="center", va="bottom", fontdict={'size': 16}
        )

# %% [markdown]
# # MP047/MP049 and D3RLPY-PEP2

# %%
mp047_d3rlpy_pep2 = get_score("MP047", "D3RLPY-PEP2")
mp049_d3rlpy_pep2 = get_score("MP049", "D3RLPY-PEP2")

# %%
plot_score([mp047_d3rlpy_pep2, mp049_d3rlpy_pep2], 'reward_mse', 'MP047/MP049 - D3RLPY-PEP2')

# %%
plot_score([mp047_d3rlpy_pep2, mp049_d3rlpy_pep2], 'observation_mse', 'MP047/MP049 - D3RLPY-PEP2')

# %%
plot_score([mp047_d3rlpy_pep2, mp049_d3rlpy_pep2], 'log_prob', 'MP047/MP049 - D3RLPY-PEP2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/formatters.py?line=336'>337</a>     pass
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/formatters.py?line=337'>338</a> else:
# --> <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/formatters.py?line=338'>339</a>     return printer(obj)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/formatters.py?line=339'>340</a> # Finally look for special method names
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/formatters.py?line=340'>341</a> method = get_real_method(obj, self.print_method)
#
# File /rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=147'>148</a>     from matplotlib.backend_bases import FigureCanvasBase
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=148'>149</a>     FigureCanvasBase(fig)
# --> <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=150'>151</a> fig.canvas.print_figure(bytes_io, **kw)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=151'>152</a> data = bytes_io.getvalue()
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=152'>153</a> if fmt == 'svg':
#
# File /rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2314'>2315</a> try:
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2315'>2316</a>     # _get_renderer may change the figure dpi (as vector formats
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2316'>2317</a>     # force the figure dpi to 72), so we need to set it again here.
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2317'>2318</a>     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2318'>2319</a>         result = print_method(
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2319'>2320</a>             filename,
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2320'>2321</a>             facecolor=facecolor,
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2321'>2322</a>             edgecolor=edgecolor,
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2322'>2323</a>             orientation=orientation,
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2323'>2324</a>             bbox_inches_restore=_bbox_inches_restore,
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2324'>2325</a>             **kwargs)
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2325'>2326</a> finally:
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2326'>2327</a>     if bbox_inches and restore_bbox:
#
# File /rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=1639'>1640</a>     _api.warn_deprecated(
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=1640'>1641</a>         '3.3', name=name, removal='3.6',
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=1641'>1642</a>         message='%(name)s() got unexpected keyword argument "'
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=1642'>1643</a>                 + arg + '" which is no longer supported as of '
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=1643'>1644</a>                 '%(since)s and will become an error '
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=1644'>1645</a>                 '%(removal)s')
#    <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=1645'>1646</a>     kwargs.pop(arg)
# -> <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=1647'>1648</a> return func(*args, **kwargs)
#
# File /rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/_api/deprecation.py?line=404'>405</a>     deprecation_addendum = (
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/_api/deprecation.py?line=405'>406</a>         f"If any parameter follows {name!r}, they should be passed as "
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/_api/deprecation.py?line=406'>407</a>         f"keyword, not positionally.")
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/_api/deprecation.py?line=407'>408</a>     warn_deprecated(
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/_api/deprecation.py?line=408'>409</a>         since,
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/_api/deprecation.py?line=409'>410</a>         name=repr(name),
#    (...)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/_api/deprecation.py?line=412'>413</a>                  else deprecation_addendum,
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/_api/deprecation.py?line=413'>414</a>         **kwargs)
# --> <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/_api/deprecation.py?line=414'>415</a> return func(*inner_args, **inner_kwargs)
#
# File /rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:540, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=489'>490</a> @_check_savefig_extra_args
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=490'>491</a> @_api.delete_parameter("3.5", "args")
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=491'>492</a> def print_png(self, filename_or_obj, *args,
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=492'>493</a>               metadata=None, pil_kwargs=None):
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=493'>494</a>     """
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=494'>495</a>     Write the figure to a PNG file.
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=495'>496</a>
#    (...)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=537'>538</a>         *metadata*, including the default 'Software' key.
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=538'>539</a>     """
# --> <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=539'>540</a>     FigureCanvasAgg.draw(self)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=540'>541</a>     mpl.image.imsave(
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=541'>542</a>         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=542'>543</a>         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:431, in FigureCanvasAgg.draw(self)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=428'>429</a> def draw(self):
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=429'>430</a>     # docstring inherited
# --> <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=430'>431</a>     self.renderer = self.get_renderer(cleared=True)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=431'>432</a>     # Acquire a lock on the shared font cache.
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=432'>433</a>     with RendererAgg.lock, \
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=433'>434</a>          (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=434'>435</a>           else nullcontext()):
#
# File /rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:447, in FigureCanvasAgg.get_renderer(self, cleared)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=443'>444</a> reuse_renderer = (hasattr(self, "renderer")
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=444'>445</a>                   and getattr(self, "_lastKey", None) == key)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=445'>446</a> if not reuse_renderer:
# --> <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=446'>447</a>     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=447'>448</a>     self._lastKey = key
#     <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=448'>449</a> elif cleared:
#
# File /rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:93, in RendererAgg.__init__(self, width, height, dpi)
#      <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=90'>91</a> self.width = width
#      <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=91'>92</a> self.height = height
# ---> <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=92'>93</a> self._renderer = _RendererAgg(int(width), int(height), dpi)
#      <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=93'>94</a> self._filter_renderers = []
#      <a href='file:///rds/user/ajc348/hpc-work/mopo/.env_jupyter/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py?line=95'>96</a> self._update_methods()
#
# ValueError: Image size of 629x7803018 pixels is too large. It must be less than 2^16 in each direction.

# %% [markdown]
# # MP047/MP049 and SAC-PAP3

# %%
mp047_sac_pap3 = get_score("MP047", "SAC-PAP3")
mp049_sac_pap3 = get_score("MP049", "SAC-PAP3")

# %%
plot_score([mp047_sac_pap3, mp049_sac_pap3], 'reward_mse', 'MP047/MP049 - SAC-PAP3')

# %%
plot_score([mp047_sac_pap3, mp049_sac_pap3], 'observation_mse', 'MP047/MP049 - SAC-PAP3')

# %%
plot_score([mp047_sac_pap3, mp049_sac_pap3], 'log_prob', 'MP047/MP049 - SAC-PAP3')

# %% [markdown]
# # MP062/MP063 and SAC-PAP3

# %%
mp062_sac_pap3 = get_score("MP062", "SAC-PAP3")
mp063_sac_pap3 = get_score("MP063", "SAC-PAP3")

# %%
plot_score([mp062_sac_pap3, mp063_sac_pap3], 'reward_mse', 'MP062/MP063 - SAC-PAP3')

# %%
plot_score([mp062_sac_pap3, mp063_sac_pap3], 'observation_mse', 'MP062/MP063 - SAC-PAP3')

# %%
plot_score([mp062_sac_pap3, mp063_sac_pap3], 'log_prob', 'MP062/MP063 - SAC-PAP3')

# %% [markdown]
# # MP062/MP063 and D3RLPY-PEP2

# %%
mp062_d3rlpy_pep2 = get_score("MP062", "D3RLPY-PEP2")
mp063_d3rlpy_pep2 = get_score("MP063", "D3RLPY-PEP2")

# %%
plot_score([mp062_d3rlpy_pep2, mp063_d3rlpy_pep2], 'reward_mse', 'MP062/MP063 - D3RLPY-PEP2')

# %%
plot_score([mp062_d3rlpy_pep2, mp063_d3rlpy_pep2], 'observation_mse', 'MP062/MP063 - D3RLPY-PEP2')

# %%
plot_score([mp062_d3rlpy_pep2, mp063_d3rlpy_pep2], 'log_prob', 'MP062/MP063 - D3RLPY-PEP2')

# %% [markdown]
# # MP068-MP069, MP078 and D3RLPY-PEP3

# %%
mp0068_d3rlpy_pep3      = get_score("MP068", "D3RLPY-PEP3")
mp0068_d3rlpy_pep3_p0_2 = get_score("MP068", "D3RLPY-PEP3-P0-2")
mp0068_d3rlpy_pep3_p3   = get_score("MP068", "D3RLPY-PEP3-P3")

# %%
mp0069_d3rlpy_pep3      = get_score("MP069", "D3RLPY-PEP3")
mp0069_d3rlpy_pep3_p0_2 = get_score("MP069", "D3RLPY-PEP3-P0-2")
mp0069_d3rlpy_pep3_p3   = get_score("MP069", "D3RLPY-PEP3-P3")

# %%
mp0078_d3rlpy_pep3      = get_score("MP078", "D3RLPY-PEP3")
mp0078_d3rlpy_pep3_p0_2 = get_score("MP078", "D3RLPY-PEP3-P0-2")
mp0078_d3rlpy_pep3_p3   = get_score("MP078", "D3RLPY-PEP3-P3")

# %%
plot_score([mp0068_d3rlpy_pep3, mp0069_d3rlpy_pep3, mp0068_d3rlpy_pep3_p0_2, mp0069_d3rlpy_pep3_p0_2, mp0068_d3rlpy_pep3_p3, mp0069_d3rlpy_pep3_p3], 'reward_mse', 'MP068/MP069')

# %%
plot_score([mp0068_d3rlpy_pep3, mp0078_d3rlpy_pep3, mp0068_d3rlpy_pep3_p0_2, mp0078_d3rlpy_pep3_p0_2, mp0068_d3rlpy_pep3_p3, mp0078_d3rlpy_pep3_p3], 'reward_mse', 'MP068/MP078')

# %%
plot_score([mp0068_d3rlpy_pep3, mp0069_d3rlpy_pep3, mp0068_d3rlpy_pep3_p0_2, mp0069_d3rlpy_pep3_p0_2, mp0068_d3rlpy_pep3_p3, mp0069_d3rlpy_pep3_p3], 'observation_mse', 'MP068/MP069')

# %%
plot_score([mp0068_d3rlpy_pep3, mp0069_d3rlpy_pep3, mp0068_d3rlpy_pep3_p0_2, mp0069_d3rlpy_pep3_p0_2, mp0068_d3rlpy_pep3_p3, mp0069_d3rlpy_pep3_p3], 'log_prob', 'MP068/MP069')

# %% [markdown]
# # MP070-MP071 and D3RLPY-PEP4

# %%
mp0070_d3rlpy_pep4      = get_score("MP070", "D3RLPY-PEP4")
mp0070_d3rlpy_pep4_p0_3 = get_score("MP070", "D3RLPY-PEP4-P0-3")
mp0070_d3rlpy_pep4_p3   = get_score("MP070", "D3RLPY-PEP4-P4")

# %%
mp0071_d3rlpy_pep4      = get_score("MP071", "D3RLPY-PEP4")
mp0071_d3rlpy_pep4_p0_2 = get_score("MP071", "D3RLPY-PEP4-P0-3")
mp0071_d3rlpy_pep4_p4   = get_score("MP071", "D3RLPY-PEP4-P4")

# %%
mp0079_d3rlpy_pep4      = get_score("MP079", "D3RLPY-PEP4")
mp0079_d3rlpy_pep4_p0_2 = get_score("MP079", "D3RLPY-PEP4-P0-3")
mp0079_d3rlpy_pep4_p4   = get_score("MP079", "D3RLPY-PEP4-P4")

# %%
plot_score([mp0070_d3rlpy_pep4, mp0071_d3rlpy_pep4, mp0070_d3rlpy_pep4_p0_3, mp0071_d3rlpy_pep4_p0_2, mp0070_d3rlpy_pep4_p3, mp0071_d3rlpy_pep4_p4], 'reward_mse', 'MP070/MP071')

# %%
plot_score([mp0070_d3rlpy_pep4, mp0079_d3rlpy_pep4, mp0070_d3rlpy_pep4_p0_3, mp0079_d3rlpy_pep4_p0_2, mp0070_d3rlpy_pep4_p3, mp0079_d3rlpy_pep4_p4], 'reward_mse', 'MP070/MP079')

# %%
plot_score([mp0070_d3rlpy_pep4, mp0071_d3rlpy_pep4, mp0070_d3rlpy_pep4_p0_3, mp0071_d3rlpy_pep4_p0_2, mp0070_d3rlpy_pep4_p3, mp0071_d3rlpy_pep4_p4], 'observation_mse', 'MP070/MP071')

# %%
plot_score([mp0070_d3rlpy_pep4, mp0071_d3rlpy_pep4, mp0070_d3rlpy_pep4_p0_3, mp0071_d3rlpy_pep4_p0_2, mp0070_d3rlpy_pep4_p3, mp0071_d3rlpy_pep4_p4], 'log_prob', 'MP070/MP071')
